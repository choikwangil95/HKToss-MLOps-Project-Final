# %% [markdown]
# # 라이브러리 세팅

# %%
# 라이브러리 불러오기
import pandas as pd
import torch
from tqdm import tqdm
import chardet
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration, pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification
from label import id2label # Label 정보 매핑용 사전, label.py의 내용을 불러 옴
import re

# %% [markdown]
# # 모델 로딩

# %%
# 요약 모델 (digit82/kobart-summarization)
summarizer_model = 'digit82/kobart-summarization'
tokenizer = PreTrainedTokenizerFast.from_pretrained(summarizer_model)
model = BartForConditionalGeneration.from_pretrained(summarizer_model)

summarizer = pipeline(
    'summarization',
    model=model,
    tokenizer=tokenizer,
    framework='pt',
    device=0 if torch.cuda.is_available() else -1
)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels will be overwritten to 2.
# Device set to use cpu

# %%
# NER 모델 (KPF BERT)
ner_model_name = 'KPF/KPF-BERT-NER'
ner_pipeline = pipeline(
    task='ner',
    model=ner_model_name,
    tokenizer=ner_model_name,
    aggregation_strategy='simple',
    framework='pt'
)
# Out:
# Device set to use mps:0

# %%
# 종목명 사전
company_df = pd.read_csv('/Users/han-yeeun/final/eda/yeeun/KRX_전체_기업명_20250530.csv', encoding='cp949')
company_df.head()
# Out:
#            표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0  KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1  KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 2  KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 3  KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# 4  KR7282330000  282330     BGF리테일보통주   BGF리테일
#
#                             영문 종목명         상장일           시장구분 증권구분    소속부  \
# 0  Micro Contact Solution Co.,Ltd.  2008/09/23         KOSDAQ   주권  중견기업부
# 1            POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ GLOBAL   주권  우량기업부
# 2             AJ Networks Co.,Ltd.  2015/08/21          KOSPI   주권    NaN
# 3                AK Holdings, Inc.  1999/08/11          KOSPI   주권    NaN
# 4                       BGF Retail  2017/12/08          KOSPI   주권    NaN
#
#   주식종류   액면가     상장주식수
# 0  보통주   500   8312766
# 1  보통주   500  41642703
# 2  보통주  1000  45252759
# 3  보통주  5000  13247561
# 4  보통주  1000  17283906

# %% [markdown]
# # 데이터 로딩 및 전처리

# %%
# 뉴스 데이터 (1000개만 사용)
news_df = pd.read_csv('/Users/han-yeeun/final/db/news_2023_2025_with_NER.csv')
news_df = news_df.head(1000)

# %%
news_df.head(3)
# Out:
#          news_id             wdate  \
# 0  20250523_0001  2025-05-23 19:11
# 1  20250523_0002  2025-05-23 18:52
# 2  20250523_0003  2025-05-23 18:38
#
#                                               title  \
# 0              [마켓인]모태펀드 존속 불확실성 해소될까…이재명 공약에 업계 주목
# 1  [단독] 카카오페이, 2500만 회원 쓱·스마일페이 품나…간편결제 시장 빅3 경쟁 후끈
# 2                        키스트론, 일반 청약 흥행…증거금 6조원 모았다
#
#                                              article  press  \
# 0  2035년 종료 앞둬, 존속 공약에 기대감\n창업 초기자금 공백 완화 가능성에 업계...   이데일리
# 1  매각가 5000억 안팎 달할듯\n결제시장 내 입지강화 포석\n카카오페이 [사진 = ...   매일경제
# 2  5월22~23일 청약 진행, 경쟁률 총2166대1\n상장 후 예상 시가총개 643억...  머니투데이
#
#                                                  url  \
# 0  https://n.news.naver.com/mnews/article/018/000...
# 1  https://n.news.naver.com/mnews/article/009/000...
# 2  https://n.news.naver.com/mnews/article/008/000...
#
#                                                image  \
# 0  https://imgnews.pstatic.net/image/018/2025/05/...
# 1  https://imgnews.pstatic.net/image/009/2025/05/...
# 2  https://imgnews.pstatic.net/image/008/2025/05/...
#
#                                        text_combined labels_by_id
# 0  [마켓인]모태펀드 존속 불확실성 해소될까…이재명 공약에 업계 주목 2035년 종료 ...           []
# 1  [단독] 카카오페이, 2500만 회원 쓱·스마일페이 품나…간편결제 시장 빅3 경쟁 ...    ['카카오페이']
# 2  키스트론, 일반 청약 흥행…증거금 6조원 모았다 5월22~23일 청약 진행, 경쟁률...           []

# %%
# 제목 + 본문 결합
news_df['text_combined'] = (
    news_df['title'].fillna('') + ' ' + news_df['article'].fillna('')
).str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# # 함수 정의

# %%
# 종목명 정규화 사전 생성
company_dict = {}

for _, row in company_df.iterrows():
    full_name = str(row['한글 종목명']).strip()
    short_name = str(row['한글 종목약명']).strip()

    if full_name:
        company_dict[full_name] = full_name
    if short_name and short_name != full_name:
        company_dict[short_name] = full_name

# %%
def extract_stock_labels(text, company_dict, is_long=False):
    if not isinstance(text, str) or len(text.strip()) < 10:
        return []

    matched_names = set()
    try:
        if is_long:
            # 길면 문장 단위로 자르기
            sentences = re.split(r'(?<=[.!?])\s+', text)
            chunks = []
            current_chunk = ''

            for sent in sentences:
                if len(current_chunk) + len(sent) <= 512:
                    current_chunk += ' ' + sent
                else:
                    chunks.append(current_chunk.strip())
                    current_chunk = sent
            if current_chunk:
                chunks.append(current_chunk.strip())
        else:
            chunks = [text]

        # chunk마다 NER 수행
        for chunk in chunks:
            entities = ner_pipeline(chunk)
            merged_entities = []
            current_word = ''
            current_score = []
            current_label = ''

            for ent in entities:
                word = ent['word']
                score = ent['score']
                label_id = ent['entity_group']
                label_num = int(label_id.split('_')[1])
                label_name = id2label.get(label_num, "")
                key = label_name[2:] if label_name.startswith(('B-', 'I-')) else label_name

                if key.startswith('OGG_ECONOMY'):
                    if word.startswith('##'):
                        current_word += word[2:]
                        current_score.append(score)
                    else:
                        if current_word:
                            merged_entities.append((current_word, current_label, sum(current_score)/len(current_score)))
                        current_word = word
                        current_score = [score]
                        current_label = label_name
            if current_word:
                merged_entities.append((current_word, current_label, sum(current_score)/len(current_score)))

            for word, label, score in merged_entities:
                if word in company_dict:
                    matched_names.add(company_dict[word])
    except Exception as e:
        print(f'NER 오류: {e}')
    
    return list(matched_names)

# %% [markdown]
# # 요약 및 종목명 추출

# %%
# 요약 및 종목명 추출
results = []

for i, row in tqdm(news_df.iterrows(), total=len(news_df), desc='요약 + 종목 추출 중'):
    title = row['title']
    url = row['url']
    article = row['article']
    
    # 요약
    try:
        summary = summarizer(
            article,
            max_length=240,
            min_length=120,
            do_sample=False
        )[0]['summary_text']
    except Exception as e:
        print(f'요약 오류 (index {i}): {e}')
        summary = ''

    # 종목명 추출
    try:
        stocks_from_summary = extract_stock_labels(summary, company_dict, is_long=False)
        stocks_from_article = extract_stock_labels(article, company_dict, is_long=True)
        combined_stocks = list(set(stocks_from_summary) | set(stocks_from_article))
    except Exception as e:
        print(f'NER 오류 (index {i}): {e}')
        combined_stocks = []

    results.append({
        'index': i,
        '제목': title,
        '요약': summary,
        '종목명': combined_stocks,
        'url': url,
        '본문 일부': article[:300]
    })
# Out:
# 요약 + 종목 추출 중:   0%|          | 1/1000 [00:02<47:30,  2.85s/it]Your max_length is set to 240, but your input_length is only 226. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# 요약 + 종목 추출 중:   1%|          | 7/1000 [00:13<29:39,  1.79s/it]
# 요약 오류 (index 7): index out of range in self
# 요약 + 종목 추출 중:   1%|          | 8/1000 [00:14<23:13,  1.40s/it]Your max_length is set to 240, but your input_length is only 223. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=111)
# 요약 + 종목 추출 중:   1%|          | 9/1000 [00:16<27:21,  1.66s/it]Your max_length is set to 240, but your input_length is only 171. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# 요약 + 종목 추출 중:   2%|▏         | 15/1000 [00:29<32:27,  1.98s/it]
# 요약 오류 (index 15): index out of range in self
# 요약 + 종목 추출 중:   2%|▏         | 17/1000 [00:32<30:08,  1.84s/it]Your max_length is set to 240, but your input_length is only 225. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=112)
# 요약 + 종목 추출 중:   3%|▎         | 29/1000 [00:59<36:39,  2.27s/it]Your max_length is set to 240, but your input_length is only 171. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# 요약 + 종목 추출 중:   4%|▍         | 41/1000 [01:24<34:44,  2.17s/it]Your max_length is set to 240, but your input_length is only 227. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# 요약 + 종목 추출 중:   5%|▍         | 48/1000 [01:39<36:39,  2.31s/it]Your max_length is set to 240, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# 요약 + 종목 추출 중:   5%|▌         | 51/1000 [01:46<38:58,  2.46s/it]Your max_length is set to 240, but your input_length is only 222. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=111)
# 요약 + 종목 추출 중:   5%|▌         | 53/1000 [01:50<34:37,  2.19s/it]Your max_length is set to 240, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중:   6%|▌         | 58/1000 [02:01<35:25,  2.26s/it]Your max_length is set to 240, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중:   7%|▋         | 71/1000 [02:28<29:54,  1.93s/it]Your max_length is set to 240, but your input_length is only 229. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# 요약 + 종목 추출 중:   7%|▋         | 74/1000 [02:34<32:18,  2.09s/it]
# 요약 오류 (index 74): index out of range in self
# 요약 + 종목 추출 중:   8%|▊         | 85/1000 [02:57<35:11,  2.31s/it]Your max_length is set to 240, but your input_length is only 218. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=109)
# 요약 + 종목 추출 중:   9%|▊         | 87/1000 [03:01<34:01,  2.24s/it]
# 요약 오류 (index 87): index out of range in self
# 요약 + 종목 추출 중:  10%|█         | 104/1000 [03:35<32:03,  2.15s/it]
# 요약 오류 (index 104): index out of range in self
# 요약 + 종목 추출 중:  11%|█         | 107/1000 [03:39<26:15,  1.76s/it]Your max_length is set to 240, but your input_length is only 231. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=115)
# 요약 + 종목 추출 중:  13%|█▎        | 133/1000 [04:43<35:16,  2.44s/it]Your max_length is set to 240, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  14%|█▍        | 142/1000 [05:03<31:19,  2.19s/it]Your max_length is set to 240, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# 요약 + 종목 추출 중:  17%|█▋        | 171/1000 [06:09<32:20,  2.34s/it]
# 요약 오류 (index 171): index out of range in self
# 요약 + 종목 추출 중:  18%|█▊        | 177/1000 [06:20<27:28,  2.00s/it]Your max_length is set to 240, but your input_length is only 206. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=103)
# 요약 + 종목 추출 중:  20%|██        | 200/1000 [07:14<27:41,  2.08s/it]Your max_length is set to 240, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# 요약 + 종목 추출 중:  21%|██        | 211/1000 [07:37<24:03,  1.83s/it]Your max_length is set to 240, but your input_length is only 210. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=105)
# 요약 + 종목 추출 중:  22%|██▏       | 215/1000 [07:46<28:47,  2.20s/it]
# 요약 오류 (index 215): index out of range in self
# 요약 + 종목 추출 중:  22%|██▏       | 216/1000 [07:47<21:50,  1.67s/it]Your max_length is set to 240, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  22%|██▏       | 222/1000 [08:00<28:55,  2.23s/it]Your max_length is set to 240, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# 요약 + 종목 추출 중:  23%|██▎       | 229/1000 [08:15<27:21,  2.13s/it]Your max_length is set to 240, but your input_length is only 170. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# 요약 + 종목 추출 중:  23%|██▎       | 232/1000 [08:22<28:36,  2.24s/it]Your max_length is set to 240, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# 요약 + 종목 추출 중:  24%|██▍       | 242/1000 [08:43<23:12,  1.84s/it]Your max_length is set to 240, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# 요약 + 종목 추출 중:  26%|██▌       | 259/1000 [09:20<25:34,  2.07s/it]Your max_length is set to 240, but your input_length is only 231. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=115)
# 요약 + 종목 추출 중:  27%|██▋       | 269/1000 [09:41<23:57,  1.97s/it]
# 요약 오류 (index 269): index out of range in self
# 요약 + 종목 추출 중:  27%|██▋       | 270/1000 [09:41<17:49,  1.46s/it]
# 요약 오류 (index 270): index out of range in self
# 요약 + 종목 추출 중:  29%|██▉       | 294/1000 [10:34<23:01,  1.96s/it]Your max_length is set to 240, but your input_length is only 234. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=117)
# 요약 + 종목 추출 중:  30%|██▉       | 295/1000 [10:36<24:01,  2.04s/it]Your max_length is set to 240, but your input_length is only 197. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# 요약 + 종목 추출 중:  30%|██▉       | 297/1000 [10:40<22:29,  1.92s/it]Your max_length is set to 240, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# 요약 + 종목 추출 중:  30%|██▉       | 299/1000 [10:45<24:05,  2.06s/it]Your max_length is set to 240, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# 요약 + 종목 추출 중:  30%|███       | 300/1000 [10:47<24:15,  2.08s/it]Your max_length is set to 240, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  31%|███       | 311/1000 [11:11<25:04,  2.18s/it]Your max_length is set to 240, but your input_length is only 164. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=82)
# 요약 + 종목 추출 중:  32%|███▏      | 317/1000 [11:25<25:39,  2.25s/it]Your max_length is set to 240, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# 요약 + 종목 추출 중:  32%|███▎      | 325/1000 [11:41<23:16,  2.07s/it]Your max_length is set to 240, but your input_length is only 155. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# 요약 + 종목 추출 중:  33%|███▎      | 327/1000 [11:45<24:28,  2.18s/it]Your max_length is set to 240, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# 요약 + 종목 추출 중:  34%|███▍      | 341/1000 [12:17<25:29,  2.32s/it]Your max_length is set to 240, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# 요약 + 종목 추출 중:  34%|███▍      | 342/1000 [12:18<22:44,  2.07s/it]Your max_length is set to 240, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# 요약 + 종목 추출 중:  34%|███▍      | 343/1000 [12:20<22:18,  2.04s/it]Your max_length is set to 240, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# 요약 + 종목 추출 중:  35%|███▍      | 349/1000 [12:32<21:01,  1.94s/it]Your max_length is set to 240, but your input_length is only 233. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=116)
# 요약 + 종목 추출 중:  36%|███▌      | 355/1000 [12:43<20:31,  1.91s/it]Your max_length is set to 240, but your input_length is only 228. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# 요약 + 종목 추출 중:  36%|███▌      | 356/1000 [12:45<21:28,  2.00s/it]Your max_length is set to 240, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# 요약 + 종목 추출 중:  36%|███▌      | 358/1000 [12:49<22:51,  2.14s/it]Your max_length is set to 240, but your input_length is only 123. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# 요약 + 종목 추출 중:  36%|███▋      | 365/1000 [13:04<22:20,  2.11s/it]Your max_length is set to 240, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# 요약 + 종목 추출 중:  38%|███▊      | 377/1000 [13:29<24:23,  2.35s/it]Your max_length is set to 240, but your input_length is only 193. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중:  38%|███▊      | 379/1000 [13:34<24:01,  2.32s/it]Your max_length is set to 240, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  38%|███▊      | 385/1000 [13:48<23:43,  2.31s/it]Your max_length is set to 240, but your input_length is only 155. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# 요약 + 종목 추출 중:  39%|███▉      | 388/1000 [13:55<23:18,  2.29s/it]Your max_length is set to 240, but your input_length is only 222. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=111)
# 요약 + 종목 추출 중:  39%|███▉      | 389/1000 [13:57<23:03,  2.26s/it]Your max_length is set to 240, but your input_length is only 228. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# 요약 + 종목 추출 중:  40%|███▉      | 399/1000 [14:20<23:58,  2.39s/it]Your max_length is set to 240, but your input_length is only 128. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# 요약 + 종목 추출 중:  42%|████▏     | 415/1000 [14:55<20:30,  2.10s/it]
# 요약 오류 (index 415): index out of range in self
# 요약 + 종목 추출 중:  42%|████▏     | 418/1000 [15:00<18:54,  1.95s/it]
# 요약 오류 (index 418): index out of range in self
# 요약 + 종목 추출 중:  42%|████▏     | 419/1000 [15:00<14:12,  1.47s/it]Your max_length is set to 240, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  46%|████▌     | 456/1000 [16:20<22:10,  2.45s/it]
# 요약 오류 (index 456): index out of range in self
# 요약 + 종목 추출 중:  46%|████▌     | 461/1000 [16:30<20:11,  2.25s/it]Your max_length is set to 240, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# 요약 + 종목 추출 중:  47%|████▋     | 469/1000 [16:48<19:38,  2.22s/it]Your max_length is set to 240, but your input_length is only 218. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=109)
# 요약 + 종목 추출 중:  47%|████▋     | 474/1000 [16:58<19:31,  2.23s/it]Your max_length is set to 240, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# 요약 + 종목 추출 중:  48%|████▊     | 477/1000 [17:05<20:04,  2.30s/it]Your max_length is set to 240, but your input_length is only 171. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# 요약 + 종목 추출 중:  48%|████▊     | 478/1000 [17:07<18:40,  2.15s/it]Your max_length is set to 240, but your input_length is only 171. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# 요약 + 종목 추출 중:  48%|████▊     | 479/1000 [17:09<18:39,  2.15s/it]Your max_length is set to 240, but your input_length is only 201. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=100)
# 요약 + 종목 추출 중:  49%|████▉     | 492/1000 [17:38<19:37,  2.32s/it]
# 요약 오류 (index 492): index out of range in self
# 요약 + 종목 추출 중:  51%|█████     | 509/1000 [18:13<17:22,  2.12s/it]Your max_length is set to 240, but your input_length is only 205. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=102)
# 요약 + 종목 추출 중:  52%|█████▏    | 519/1000 [18:33<14:25,  1.80s/it]
# 요약 오류 (index 519): index out of range in self
# 요약 + 종목 추출 중:  52%|█████▏    | 520/1000 [18:33<10:39,  1.33s/it]
# 요약 오류 (index 520): index out of range in self
# 요약 + 종목 추출 중:  52%|█████▏    | 522/1000 [18:36<11:33,  1.45s/it]Your max_length is set to 240, but your input_length is only 217. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=108)
# 요약 + 종목 추출 중:  53%|█████▎    | 530/1000 [18:53<16:58,  2.17s/it]Your max_length is set to 240, but your input_length is only 238. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  53%|█████▎    | 531/1000 [18:54<14:33,  1.86s/it]Your max_length is set to 240, but your input_length is only 151. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# 요약 + 종목 추출 중:  54%|█████▎    | 536/1000 [19:05<17:30,  2.26s/it]Your max_length is set to 240, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  54%|█████▍    | 538/1000 [19:08<15:39,  2.03s/it]Your max_length is set to 240, but your input_length is only 194. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# 요약 + 종목 추출 중:  54%|█████▍    | 542/1000 [19:18<18:05,  2.37s/it]Your max_length is set to 240, but your input_length is only 229. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# 요약 + 종목 추출 중:  55%|█████▍    | 549/1000 [19:36<21:23,  2.85s/it]Your max_length is set to 240, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# 요약 + 종목 추출 중:  55%|█████▌    | 551/1000 [19:41<20:29,  2.74s/it]Your max_length is set to 240, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# 요약 + 종목 추출 중:  55%|█████▌    | 552/1000 [19:44<19:38,  2.63s/it]Your max_length is set to 240, but your input_length is only 155. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# 요약 + 종목 추출 중:  55%|█████▌    | 553/1000 [19:46<18:46,  2.52s/it]Your max_length is set to 240, but your input_length is only 184. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# 요약 + 종목 추출 중:  56%|█████▌    | 560/1000 [20:02<17:00,  2.32s/it]Your max_length is set to 240, but your input_length is only 193. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중:  56%|█████▌    | 561/1000 [20:04<15:59,  2.19s/it]Your max_length is set to 240, but your input_length is only 217. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=108)
# 요약 + 종목 추출 중:  57%|█████▋    | 572/1000 [20:31<17:19,  2.43s/it]Your max_length is set to 240, but your input_length is only 202. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=101)
# 요약 + 종목 추출 중:  58%|█████▊    | 581/1000 [20:52<16:19,  2.34s/it]Your max_length is set to 240, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# 요약 + 종목 추출 중:  59%|█████▉    | 594/1000 [21:22<16:12,  2.40s/it]
# 요약 오류 (index 594): index out of range in self
# 요약 + 종목 추출 중:  60%|█████▉    | 595/1000 [21:23<12:03,  1.79s/it]Your max_length is set to 240, but your input_length is only 222. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=111)
# 요약 + 종목 추출 중:  60%|█████▉    | 596/1000 [21:25<13:00,  1.93s/it]Your max_length is set to 240, but your input_length is only 150. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# 요약 + 종목 추출 중:  60%|██████    | 600/1000 [21:33<13:24,  2.01s/it]Your max_length is set to 240, but your input_length is only 205. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=102)
# 요약 + 종목 추출 중:  61%|██████    | 611/1000 [21:57<12:41,  1.96s/it]Your max_length is set to 240, but your input_length is only 237. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=118)
# 요약 + 종목 추출 중:  61%|██████▏   | 614/1000 [22:03<12:09,  1.89s/it]
# 요약 오류 (index 614): index out of range in self
# 요약 + 종목 추출 중:  64%|██████▍   | 642/1000 [23:03<14:48,  2.48s/it]Your max_length is set to 240, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# 요약 + 종목 추출 중:  65%|██████▍   | 647/1000 [23:14<13:19,  2.26s/it]Your max_length is set to 240, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# 요약 + 종목 추출 중:  65%|██████▍   | 648/1000 [23:16<12:54,  2.20s/it]Your max_length is set to 240, but your input_length is only 188. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# 요약 + 종목 추출 중:  65%|██████▍   | 649/1000 [23:18<12:43,  2.18s/it]Your max_length is set to 240, but your input_length is only 224. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=112)
# 요약 + 종목 추출 중:  65%|██████▌   | 654/1000 [23:30<13:10,  2.29s/it]Your max_length is set to 240, but your input_length is only 160. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# 요약 + 종목 추출 중:  66%|██████▌   | 660/1000 [23:44<13:05,  2.31s/it]Your max_length is set to 240, but your input_length is only 208. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=104)
# 요약 + 종목 추출 중:  66%|██████▌   | 661/1000 [23:45<10:58,  1.94s/it]Your max_length is set to 240, but your input_length is only 238. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  67%|██████▋   | 671/1000 [24:05<10:42,  1.95s/it]Your max_length is set to 240, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  67%|██████▋   | 674/1000 [24:10<10:09,  1.87s/it]Your max_length is set to 240, but your input_length is only 200. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=100)
# 요약 + 종목 추출 중:  68%|██████▊   | 681/1000 [24:26<12:04,  2.27s/it]Your max_length is set to 240, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# 요약 + 종목 추출 중:  68%|██████▊   | 684/1000 [24:33<12:00,  2.28s/it]Your max_length is set to 240, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  68%|██████▊   | 685/1000 [24:35<11:45,  2.24s/it]Your max_length is set to 240, but your input_length is only 239. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=119)
# 요약 + 종목 추출 중:  69%|██████▉   | 693/1000 [24:53<11:54,  2.33s/it]Your max_length is set to 240, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# 요약 + 종목 추출 중:  71%|███████   | 708/1000 [25:24<09:57,  2.04s/it]Your max_length is set to 240, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# 요약 + 종목 추출 중:  71%|███████   | 711/1000 [25:30<09:42,  2.02s/it]Your max_length is set to 240, but your input_length is only 202. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=101)
# 요약 + 종목 추출 중:  71%|███████▏  | 714/1000 [25:35<09:13,  1.93s/it]Your max_length is set to 240, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# 요약 + 종목 추출 중:  72%|███████▏  | 717/1000 [25:40<08:35,  1.82s/it]Your max_length is set to 240, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# 요약 + 종목 추출 중:  73%|███████▎  | 726/1000 [26:01<10:37,  2.33s/it]Your max_length is set to 240, but your input_length is only 180. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# 요약 + 종목 추출 중:  73%|███████▎  | 728/1000 [26:04<08:36,  1.90s/it]Your max_length is set to 240, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# 요약 + 종목 추출 중:  73%|███████▎  | 730/1000 [26:06<07:05,  1.58s/it]Your max_length is set to 240, but your input_length is only 216. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=108)
# 요약 + 종목 추출 중:  73%|███████▎  | 734/1000 [26:15<08:45,  1.98s/it]Your max_length is set to 240, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# 요약 + 종목 추출 중:  74%|███████▍  | 738/1000 [26:23<09:01,  2.07s/it]Your max_length is set to 240, but your input_length is only 189. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# 요약 + 종목 추출 중:  75%|███████▍  | 747/1000 [26:43<09:06,  2.16s/it]Your max_length is set to 240, but your input_length is only 202. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=101)
# 요약 + 종목 추출 중:  76%|███████▌  | 757/1000 [27:05<08:58,  2.21s/it]Your max_length is set to 240, but your input_length is only 205. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=102)
# 요약 + 종목 추출 중:  78%|███████▊  | 775/1000 [27:44<08:18,  2.22s/it]Your max_length is set to 240, but your input_length is only 227. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=113)
# 요약 + 종목 추출 중:  78%|███████▊  | 780/1000 [27:54<07:24,  2.02s/it]Your max_length is set to 240, but your input_length is only 222. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=111)
# 요약 + 종목 추출 중:  78%|███████▊  | 782/1000 [27:58<07:09,  1.97s/it]Your max_length is set to 240, but your input_length is only 141. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# 요약 + 종목 추출 중:  79%|███████▊  | 786/1000 [28:05<06:28,  1.81s/it]
# 요약 오류 (index 786): index out of range in self
# 요약 + 종목 추출 중:  79%|███████▉  | 794/1000 [28:20<07:30,  2.19s/it]
# 요약 오류 (index 794): index out of range in self
# 요약 + 종목 추출 중:  84%|████████▎ | 837/1000 [29:52<06:36,  2.43s/it]
# 요약 오류 (index 837): index out of range in self
# 요약 + 종목 추출 중:  84%|████████▍ | 839/1000 [29:55<05:29,  2.04s/it]Your max_length is set to 240, but your input_length is only 229. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=114)
# 요약 + 종목 추출 중:  85%|████████▍ | 847/1000 [30:14<06:07,  2.40s/it]
# 요약 오류 (index 847): index out of range in self
# 요약 + 종목 추출 중:  85%|████████▌ | 851/1000 [30:20<04:51,  1.95s/it]
# 요약 오류 (index 851): index out of range in self
# 요약 + 종목 추출 중:  85%|████████▌ | 852/1000 [30:20<03:34,  1.45s/it]
# 요약 오류 (index 852): index out of range in self
# 요약 + 종목 추출 중:  85%|████████▌ | 854/1000 [30:23<03:42,  1.52s/it]
# 요약 오류 (index 854): index out of range in self
# 요약 + 종목 추출 중:  86%|████████▌ | 856/1000 [30:26<03:34,  1.49s/it]
# 요약 오류 (index 856): index out of range in self
# 요약 + 종목 추출 중:  86%|████████▋ | 863/1000 [30:40<04:39,  2.04s/it]
# 요약 오류 (index 863): index out of range in self
# 요약 + 종목 추출 중:  87%|████████▋ | 872/1000 [31:00<04:55,  2.31s/it]Your max_length is set to 240, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# 요약 + 종목 추출 중:  88%|████████▊ | 876/1000 [31:07<04:08,  2.00s/it]
# 요약 오류 (index 876): index out of range in self
# 요약 + 종목 추출 중:  88%|████████▊ | 879/1000 [31:12<03:42,  1.84s/it]Your max_length is set to 240, but your input_length is only 234. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=117)
# 요약 + 종목 추출 중:  88%|████████▊ | 883/1000 [31:21<04:26,  2.28s/it]Your max_length is set to 240, but your input_length is only 216. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=108)
# 요약 + 종목 추출 중:  89%|████████▊ | 886/1000 [31:28<04:23,  2.31s/it]Your max_length is set to 240, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# 요약 + 종목 추출 중:  89%|████████▉ | 892/1000 [31:42<04:14,  2.36s/it]Your max_length is set to 240, but your input_length is only 197. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# 요약 + 종목 추출 중:  89%|████████▉ | 893/1000 [31:44<04:05,  2.30s/it]
# 요약 오류 (index 893): index out of range in self
# 요약 + 종목 추출 중:  90%|█████████ | 901/1000 [32:00<03:55,  2.38s/it]Your max_length is set to 240, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# 요약 + 종목 추출 중:  90%|█████████ | 903/1000 [32:04<03:36,  2.23s/it]Your max_length is set to 240, but your input_length is only 128. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# 요약 + 종목 추출 중:  91%|█████████ | 911/1000 [48:50<1:48:15, 72.99s/it] Your max_length is set to 240, but your input_length is only 236. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=118)
# 요약 + 종목 추출 중:  92%|█████████▏| 918/1000 [49:06<11:09,  8.17s/it]  Your max_length is set to 240, but your input_length is only 148. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
# 요약 + 종목 추출 중:  92%|█████████▏| 919/1000 [49:08<08:34,  6.35s/it]Your max_length is set to 240, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# 요약 + 종목 추출 중:  92%|█████████▏| 923/1000 [49:17<04:04,  3.17s/it]Your max_length is set to 240, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# 요약 + 종목 추출 중:  92%|█████████▎| 925/1000 [49:20<03:14,  2.59s/it]Your max_length is set to 240, but your input_length is only 207. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=103)
# 요약 + 종목 추출 중:  93%|█████████▎| 931/1000 [55:50<1:06:27, 57.78s/it] Your max_length is set to 240, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# 요약 + 종목 추출 중:  93%|█████████▎| 934/1000 [55:57<23:18, 21.19s/it]  Your max_length is set to 240, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# 요약 + 종목 추출 중:  94%|█████████▎| 935/1000 [55:58<16:40, 15.39s/it]Your max_length is set to 240, but your input_length is only 179. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# 요약 + 종목 추출 중:  94%|█████████▎| 936/1000 [56:01<12:12, 11.44s/it]Your max_length is set to 240, but your input_length is only 215. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=107)
# 요약 + 종목 추출 중:  94%|█████████▍| 941/1000 [56:11<03:39,  3.72s/it]Your max_length is set to 240, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# 요약 + 종목 추출 중:  94%|█████████▍| 943/1000 [56:14<02:30,  2.64s/it]Your max_length is set to 240, but your input_length is only 153. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=76)
# 요약 + 종목 추출 중:  95%|█████████▍| 946/1000 [56:22<02:17,  2.54s/it]Your max_length is set to 240, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중:  95%|█████████▍| 949/1000 [56:29<02:03,  2.41s/it]Your max_length is set to 240, but your input_length is only 233. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=116)
# 요약 + 종목 추출 중:  95%|█████████▌| 950/1000 [56:31<02:01,  2.42s/it]Your max_length is set to 240, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# 요약 + 종목 추출 중:  95%|█████████▌| 951/1000 [56:33<01:56,  2.37s/it]Your max_length is set to 240, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# 요약 + 종목 추출 중:  95%|█████████▌| 953/1000 [56:39<01:56,  2.49s/it]Your max_length is set to 240, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# 요약 + 종목 추출 중:  96%|█████████▌| 960/1000 [56:54<01:18,  1.97s/it]Your max_length is set to 240, but your input_length is only 200. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=100)
# 요약 + 종목 추출 중:  96%|█████████▌| 961/1000 [56:55<01:09,  1.77s/it]Your max_length is set to 240, but your input_length is only 208. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=104)
# 요약 + 종목 추출 중:  96%|█████████▋| 965/1000 [57:05<01:16,  2.20s/it]Your max_length is set to 240, but your input_length is only 219. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=109)
# 요약 + 종목 추출 중:  97%|█████████▋| 974/1000 [57:25<00:59,  2.30s/it]Your max_length is set to 240, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# 요약 + 종목 추출 중:  98%|█████████▊| 985/1000 [57:50<00:33,  2.24s/it]Your max_length is set to 240, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# 요약 + 종목 추출 중:  99%|█████████▊| 987/1000 [57:55<00:29,  2.28s/it]Your max_length is set to 240, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# 요약 + 종목 추출 중: 100%|█████████▉| 995/1000 [58:11<00:09,  1.99s/it]Your max_length is set to 240, but your input_length is only 230. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=115)
# 요약 + 종목 추출 중: 100%|██████████| 1000/1000 [58:20<00:00,  3.50s/it]

# %%
# results → DataFrame으로 변환
result_df = pd.DataFrame(results)

# 요약 및 종목명 확인용 출력
for i, row in result_df.iterrows():
    print(f'\n=== 뉴스 {i+1} ===')
    print('제목:', row['제목'])
    print('요약:', row['요약'])
    print('종목명:', row['종목명'])
    print('url:', row['url'])
    print('본문 일부:', row['본문 일부'], '...')
# Out:
# === 뉴스 1 ===
# 제목: [마켓인]모태펀드 존속 불확실성 해소될까…이재명 공약에 업계 주목
# 요약: 정부 출자사업의 대표격인 모태펀드의 존속을 둘러싼 논란 속에서 이재명 더불어민주당 대선 후보가 예산 확대와 존속기간 연장을 골자로 한 공약을 내놓으며 업계의 시선이 쏠리고 있다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/018/0006022208
# 본문 일부: 2035년 종료 앞둬, 존속 공약에 기대감
# 창업 초기자금 공백 완화 가능성에 업계 안도
# VC, "정책 연속성 중요…불확실성 줄어야"
# 퇴직연금도 벤처로…BDC 등 활성화 방안 포함
# 이 기사는 2025년05월23일 17시10분에
# 마켓인 프리미엄 콘텐츠
# 로 선공개 되었습니다.
# [이데일리 마켓in 송재민 기자] 정부 출자사업의 대표격인 모태펀드의 존속을 둘러싼 논란 속에서 이재명 더불어민주당 대선 후보가 예산 확대와 존속기간 연장을 골자로 한 공약을 내놓으며 업계의 시선이 쏠리고 있다. 모태펀드의 조기 종료 우려가 제기되던 가운데, 이번  ...
#
# === 뉴스 2 ===
# 제목: [단독] 카카오페이, 2500만 회원 쓱·스마일페이 품나…간편결제 시장 빅3 경쟁 후끈
# 요약: 카카오페이가 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 네이버페이·토스페이에 대항하기 위해 신세계이마트 산하 간편결제사업부 인수에 나섰다.
# 종목명: ['카카오페이보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497731
# 본문 일부: 매각가 5000억 안팎 달할듯
# 결제시장 내 입지강화 포석
# 카카오페이 [사진 = 연합뉴스]
# 국내 대표 전자결제사업자인 카카오페이가 신세계이마트 산하 간편결제사업부 인수에 나섰다. 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 해석된다.
# 23일 정보기술(IT)·투자은행(IB) 업계에 따르면 카카오페이가 SSG닷컴 쓱페이와 G마켓 스마일페이 인수를 위해 신세계이마트 측과 협상을 진행 중인 것으로 파악됐다. 업계에서는 매각가가 5000억원 안팎에 달할 것으로 전망했다.
# 카카오페이는 약 2500만명의 이용자를 보유한 쓱페이·스 ...
#
# === 뉴스 3 ===
# 제목: 키스트론, 일반 청약 흥행…증거금 6조원 모았다
# 요약: 고려제강그룹 계열인 와이어 제조기업 키스트론이 공모주 청약을 23일 마무리했으며, 최종 경쟁률은 총 2166.01대1로 집계되었다.                                                                                                     최종 경쟁률은 총 2166.01대1로  집계되었으며  최종 청약 건수는 19만1049건으로, 청약 금액의 절반을 미리 내는 청약증거금은 약 6조1400억원이 모됬다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/008/0005198487
# 본문 일부: 5월22~23일 청약 진행, 경쟁률 총2166대1
# 상장 후 예상 시가총개 643억원
# 고려제강그룹 계열인 와이어 제조기업 키스트론이 일반투자자 대상으로 진행된 공모주 청약을 23일 마무리했다. 총 2166대1의 경쟁률을 기록, 청약 증거금 6조원을 모으는 데 성공했다.
# 지난 22일부터 이날까지 양간 일반 청약을 진행한 결과 최종 경쟁률은 총 2166.01대1로  집계됐다. 청약 건수는 19만1049건으로, 청약 금액의 절반을 미리 내는 청약증거금은 약 6조1400억원이 모였다.
# 키스트론은 앞선 수요예측에서 경쟁률 1141대1의 경쟁률 ...
#
# === 뉴스 4 ===
# 제목: 골드만삭스 차기 CEO, 이재용·김병주·이창용 만났다
# 요약: 글로벌 금융업계에서 차기 CEO로 유력시되는 존 월드론은 23일 서울에서 이 총재, 이 회장, 김 회장, 김 대표 등을 잇따라 만나 의견을 교환한 것으로 보이며 이는 차기 CEO의 신호탄으로 해석된다.
# 종목명: ['삼성전자보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497729
# 본문 일부: [사진=연합뉴스]
# 세계 2위 투자은행(IB)인 골드만삭스의 사장 겸 최고운영책임자(COO)인 존 월드론이 방한해 이창용 한국은행 총재, 이재용 삼성전자 회장, 김병주 MBK파트너스 회장 등과 각각 회동했다. 한국의 금융당국, 기업 및 금융계와의 협력 방안을 논의한 것으로 풀이된다.
# 23일 투자은행 업계에 따르면, 월드론 COO는 이날 서울에서 이 총재, 이 회장, 김 회장, 김 대표 등을 잇따라 만나 의견을 교환한 것으로 전해졌다.
# 월드론 COO는 현재 글로벌 금융업계에서 차기 골드만삭스 최고경영자(CEO)로 유력시되는 인물이다.  ...
#
# === 뉴스 5 ===
# 제목: 흔들리는 미국…달러 패권 붕괴에 '스테이블코인' 선택한 美
# 요약: 김경태 상상인증권 연구원은 미국의 달러 패권 강화를 위해 스테이블코인을 선택했다는 분석을 내놓았으며, 이는 실물경제 침투와 도입이 확산할 경우엔 달러화에 대응한 원화 기반 스테이블코인의 필요성이 증대될 것이라고 말했다.
# 종목명: ['상상인증권보통주']
# url: https://n.news.naver.com/mnews/article/008/0005198483
# 본문 일부: /사진=게티이미지뱅크
# 미국 정부가 달러의 기축통화 지위를 위협하는 금에 대응하기 위해 스테이블코인을 선택했다는 분석이 나왔다. 스테이블코인이 실물경제에 미치는 영향력이 커진다면 원화 스테이블코인의 필요성도 높아질 수밖에 없다는 진단이다.
# 23일 김경태 상상인증권 연구원은 "실물 자산과 1대1 고정 연동된 자산인 스테이블코인은 은행의 중앙화 원장에서 블록체인 기반 디지털 원장으로의 전환을 위한 핵심이다. 정부의 감시로부터 자유로운 거래와 국제 송금 비용 절감, 절차 및 효율성 향상에서 큰 이점을 가지고 있다"라고 설명했다.
# 김 연구원 ...
#
# === 뉴스 6 ===
# 제목: 텔콘RF제약, 유·무상증자 결정…"재무안정성 확보·유동성 강화"
# 요약: 텔콘RF제약은 안정적인 경영 환경 구축과 재무구조 개선을 위해 277억원 규모의 주주배정 후 실권주 일반공모 유상증자를 결정했다고 23일 밝혔으며 신주배정주식수는 0.9007151195, 예정발행가는 2560원이다.
# 종목명: ['텔콘알에프제약']
# url: https://n.news.naver.com/mnews/article/008/0005198481
# 본문 일부: 텔콘RF제약은 안정적인 경영 환경 구축과 재무구조 개선을 위해 277억원 규모의 주주배정 후 실권주 일반공모 유상증자를 결정했다고 23일 밝혔다. 1주당 신주배정주식수는 0.9007151195, 예정발행가는 2560원이다. 신주배정 기준일은 7월 7일, 청약 예정일은 8월 8~11일이다.
# 회사 관계자는 "최근 통신부품 시장 침체로 통신부품(RF) 사업부문이 경영 부담을 겪고 있어 거래처 다각화와 고수익 제품 개발을 통해 수익구조 개선을 추진 중"이라며 "재무안정성과 유동성 확보가 여전히 절실한 상황"이라고 설명했다.
# 유상증자 자금은 ...
#
# === 뉴스 7 ===
# 제목: [단독] 전자결제 강자 카카오페이 쓱·스마일 페이 인수 추진
# 요약: 카카오페이가 SSG닷컴 쓱페이와 G마켓 스마일페이 인수를 위해 신세계이마트 측과 협상을 진행 중인 것으로 파악되어, 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 해석된다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 종목명: ['신세계보통주', '카카오페이보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497721
# 본문 일부: 국내 대표 전자결제사업자인 카카오페이가 신세계이마트 산하 간편결제사업부 인수에 나섰다. 네이버페이·토스페이에 대항해 시장 점유율을 늘리려는 포석으로 해석된다. 23일 정보기술(IT)·투자은행(IB) 업계에 따르면 카카오페이가 SSG닷컴 쓱페이와 G마켓 스마일페이 인수를 위해 신세계이마트 측과 협상을 진행 중인 것으로 파악됐다. 업계에서는 매각가가 5000억원 안팎에 달할 것으로 전망했다.
# 카카오페이는 약 2500만명의 이용자를 보유한 쓱페이·스마일페이를 인수할 경우 사업 외연을 확대할 수 있다. 매각 작업에 정통한 업계 고위 관계자 ...
#
# === 뉴스 8 ===
# 제목: “이 단기 실적 안 좋을 때 사야죠”...비행기 타기 전에 사둔다는 이 주식
# 요약:
# 종목명: ['강원랜드보통주', '대신증권보통주', '파라다이스보통주', '아시아나항공 보통주', '대한항공보통주', '하나투어보통주', '호텔신라보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497712
# 본문 일부: 큰장 기다리는 韓美 여행주
# 시장점유율 1위 부킹홀딩스
# 올 최고 유망주 익스피디아
# 실적 반등 노리는 하나투어
# [사진 = 챗GPT]
# # 매년 해외여행 계획과 함께 여행 플랫폼 주식을 사모으는 김 모씨(37). 최근 사상 최고가를 찍은 글로벌 여행 플랫폼 부킹홀딩스 주식을 일부 팔고 국내 여행 업체 하나투어를 샀다. 하나투어는 지난 5월 8일 실적이 급감했다는 공시를 내놓으면서 주가가 하락하자 저점 매수 기회로 삼은 것.
# 김씨는 “중장기 투자자에게 단기 실적 악재는 저가 매수 기회”라며 “실적 발표 이후 주가가 7% 이상 하락해 기분 좋 ...
#
# === 뉴스 9 ===
# 제목: 어센트EP, 화장품 ODM 4위 업체 인수
# 요약: 국내 화장품펀드 운용사 어센트에쿼티파트너스가 국내 화장품 연구개발생산(ODM) 4위 업체인 씨앤씨인터내셔널의 최대주주가 되었고, 기존 경영진이 계속 경영을 맡을 예정이기 때문에, 기존 경영진(창업주 2세 배수아 대표)이 계속 경영을 맡을 예정이기 때문에, 기존 경영진(창업주 2세 배수아 대표)이 계속 경영을 맡을 예정이다.
# 종목명: ['신세계보통주', '씨앤씨인터내셔널']
# url: https://n.news.naver.com/mnews/article/009/0005497674
# 본문 일부: 씨앤씨인터 경영은 계속 유지
# 국내 사모펀드 운용사 어센트에쿼티파트너스(이하 어센트EP)가 국내 화장품 연구개발생산(ODM) 4위 업체인 씨앤씨인터내셔널의 최대주주가 됐다.
# 23일 투자은행(IB) 업계에 따르면 어센트EP는 유증으로 발행되는 신주와 구주를 합쳐 씨앤씨인터내셔널 지분 약 40%를 확보할 예정이다. 기존 씨앤씨인터내셔널의 대주주였던 배은철 회장(및 특수관계인)은 지분율이 66.03%서 30%대로 낮아져 2대 주주가 된다. 어센트EP가 이번에 투자할 총금액은 2850억원이다. 이 중 신세계그룹이 금액 일부를 투자할 것으로  ...
#
# === 뉴스 10 ===
# 제목: 조현준 효성重 지분 4.9% 美 테크펀드 2600억 매각
# 요약: 효성 효성 회장이 상속세 재원 마련을 위해 효성중공업 지분 4.90%를 미국의 글로벌 테크 펀드에 매각했다고 23일 공시했다.
# 종목명: ['효성중공업보통주', '효성보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497676
# 본문 일부: 조현준 효성 회장이 상속세 재원 마련을 위해 효성중공업 지분 4.90%를 미국의 글로벌 테크 펀드에 매각했다. 효성중공업은 조 회장이 상속세 재원을 마련하기 위해 시간 외 매매로 효성중공업 주식 45만6903주를 매도했다고 23일 공시했다. 매각 단가는 56만8100원이며, 거래 규모는 약 2596억원이다.
# 이번 지분 매각으로 조 회장의 효성중공업 지분율은 14.89%에서 9.99%로 낮아졌다. 효성중공업 최대주주는 효성(주)(지분율 32.47%)이다.
# 조 회장의 지분을 매입한 곳은 미국의 톱티어 장기 투자사(테크 펀드)로 알려졌다 ...
#
# === 뉴스 11 ===
# 제목: 몸집 키우는 카카오…'간편결제 빅3' 흔드나
# 요약: 카카오페이가 이마트 측에서 쓱페이·스마일페이 인수를 추진하고 있는 건 국내 간편결제 시장에서 영향력을 확대하기 위한 차원이라고 밝혔으며 이마트는 이마트닷컴을 통해 간편결제 관련 자산을 매각할 예정이다.                                                                                                                                                                                      전자금융업자가 간편지급 시장의 50.7%를 차지하고
# 종목명: ['신세계보통주', '카카오페이보통주', '이마트보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497672
# 본문 일부: 카카오페이, 신세계 페이 품나
# 이커머스 결제 강화 점유 확대
# 압도적 1위 네이버에 도전장
# 매각가 5천억원 안팎 달할 듯
# 카카오페이가 신세계 이마트 측에서 쓱페이·스마일페이 인수를 추진하고 나선 건 국내 간편결제 시장에서 영향력을 확대하기 위한 차원이다.
# 미리 계좌·카드를 등록만 해놓으면 간편하게 물건·서비스를 결제할 수 있는 간편결제 시장은 해마다 가파른 성장세를 보이며 전자금융 업계의 중요한 먹거리로 급부상 중이다.
# 23일 한국은행 등에 따르면 국내 간편지급(간편결제) 서비스 시장의 일평균 이용 금액은 지난해 기준 9594억원에  ...
#
# === 뉴스 12 ===
# 제목: 조현준 효성 회장, 상속세 마련 위해 효성重 지분 2600억 매각
# 요약: 효성 회장이 상속세 재원 마련을 위해 보유중인 효성중공업 지분 4.90%를 미국의 글로벌 테크 펀드에 매각했다.   가맹관계 구축을 목적으로 협의를 진행해왔으며 장기적 관점의 투자로 풀이된다.
# 종목명: ['효성중공업보통주', '효성보통주']
# url: https://n.news.naver.com/mnews/article/011/0004489018
# 본문 일부: 미국 테크펀드에 지분 4.9% 처분
# "장기투자 목적···협력관계 강화할 것"
# 조현준 효성 회장. 사진 제공=효성
# [서울경제]
# 조현준 효성 회장이 상속세 재원 마련을 위해 효성중공업 지분 4.90%를 미국의 글로벌 테크 펀드에 매각했다. 해당 펀드는 기술 분야별 성장주에 투자하는 대형 펀드로, 장기 투자 관점에서 효성중공업 주식을 매입한 것으로 전해졌다.
# 23일 투자은행(IB) 업계에 따르면 조 회장은 전날 효성중공업 주식 45만 6903주(4.90%)를 시간외매매(블록딜)로 처분했다. 효성중공업은 조 회장이 상속세 재원 마련을 위해 ...
#
# === 뉴스 13 ===
# 제목: [ETF줌인] 국내 유일 獨 우량주 집중 투자…반년새 32% 뛰어 美지수 압도
# 요약: 독일 단일시장인 독일이 인공지능(AI)·방산·금융 등 대표 산업군의 성장 기대로 상승 곡선을 그리고 있어 투자자들은 독일 단일시장인 독일 단일시장인 독일에 집중 투자할 수 있게 되었다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/011/0004489009
# 본문 일부: ■KIWOOM 독일DAX ETF
# [서울경제]
# 독일 증시가 인공지능(AI)·방산·금융 등 대표 산업군의 성장 기대로 상승 곡선을 그리고 있다. 올 초 도널드 트럼프 미국 대통령 당선 이후에는 전 세계 관세 부과 정책에 따른 불확실성 확대로 국내외 변동 장세가 길어지자 미국 증시에서 이탈된 투자 자금이 유입되며 반사 이익을 누리고 있다.
# 23일 한국거래소에 따르면 국내에서 유일하게 독일 단일 국가에 집중적으로 투자할 수 있는 키움투자자산운용의 ‘KIWOOM 독일DAX’ 상장지수펀드(ETF)는 전날 종가 기준으로 올해 21.34%의 수익 ...
#
# === 뉴스 14 ===
# 제목: 한 달새 47% 뛴 두산, 엔비디아 덕에 날았다
# 요약: AI가속기 소재로 최대 실적 예상되는 (주)두산 주가가 최근 강세를 보이고 있다.
# 종목명: ['대신증권보통주', '두산보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135820
# 본문 일부: AI가속기 소재로 최대 실적
# 증권가, 줄줄이 목표가 높여
# 두산그룹 지주사인 ㈜두산 주가가 최근 강세다. 올해 호실적이 예상되는 데다 대선 수혜주로 부각되면서다.
# 23일 유가증권시장에서 ㈜두산 주가는 6.81% 오른 43만9000원에 거래를 마쳤다. 장중 44만1500원을 기록하며 52주 신고가도 경신했다. 지난 한 달간 47.56% 급등했다. 이 기간 외국인이 1080억원어치 순매수하며 주가를 끌어올렸다.
# ㈜두산의 자체 사업인 전자소재(전자BG) 부문이 올해 역대 최대 실적을 낼 것으로 전망된 게 첫 번째 배경으로 꼽힌다. 전자BG ...
#
# === 뉴스 15 ===
# 제목: "시장 커지는데 인력풀 제자리"…운용사 ETF인재 쟁탈전 격화
# 요약: 최창규 삼성자산운용 VP는 다음주부터 미래에셋자산운용으로 출근할 예정이며 최 VP는 NH투자증권에서 파생상품 부문 ‘스타 애널리스트’로 이름을 알렸으며 미래에셋운용에서는 ETF 운용 부문 내 신설되는 상품리서치본부장을 맡는다.
# 종목명: ['엔에이치투자증권보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135818
# 본문 일부: 삼성서 미래, 미래서 키움으로
# 업계 '뺏고 뺏기는' 경쟁 치열
# 상장지수펀드(ETF) 시장에서 인력 쟁탈전이 가열되고 있다. 시장은 빠르게 성장하는데 인력 풀은 한정적인 상황이 계속되고 있어서다.
# 23일 금융투자업계에 따르면 최창규 삼성자산운용 VP는 다음주부터 미래에셋자산운용으로 출근할 예정이다. 최 VP는 NH투자증권에서 파생상품 부문 ‘스타 애널리스트’로 이름을 알렸다. 2021년 삼성운용으로 이직한 뒤 유튜브 등을 활용한 ETF 마케팅을 담당해 왔다. 미래에셋운용에서는 ETF 운용 부문 내 신설되는 상품리서치본부장을 맡는다.  ...
#
# === 뉴스 16 ===
# 제목: "반갑다 약달러, 고맙다 AI" … 날아오르는 여행株
# 요약:
# 종목명: ['강원랜드보통주', '대신증권보통주', '파라다이스보통주', '아시아나항공 보통주', '대한항공보통주', '하나투어보통주', '호텔신라보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497618
# 본문 일부: 큰장 기다리는 韓美 여행주
# 원본보기
# 매년 해외여행 계획과 함께 여행 플랫폼 주식을 사 모으는 김 모씨(37). 최근 사상 최고가를 찍은 글로벌 여행 플랫폼 부킹홀딩스 주식을 일부 팔고 국내 여행 업체 하나투어를 샀다. 하나투어가 지난 5월 8일 실적이 급감했다는 공시를 내놓으면서 주가가 하락하자 저점 매수 기회로 삼은 것. 김씨는 "중장기 투자자에게 단기 실적 악재는 저가 매수 기회"라며 "실적 발표 이후 주가가 7% 이상 하락해 기분 좋게 사고 있다"고 말했다. 그의 주식 포트폴리오엔 부킹홀딩스를 비롯해 익스피디아, 에어비앤비 등 ...
#
# === 뉴스 17 ===
# 제목: 밥값은 3만원…40년 넘게 이어진 여의도 '블록 모임'의 비밀 [돈앤톡]
# 요약: 부국증권과 신영증권, IBK투자증권, 코스콤, 한국예탁결제원, 한국증권금융 등 증권사와 증권 유관기관의 수장들이 모여 같은 블록 안에 모여 있다는 이유로 '블록 모임'이라는 이름을 붙였다.
# 종목명: ['한양증권보통주', '대신증권보통주', 'SK증권보통주', '신영증권보통주', '부국증권보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135767
# 본문 일부: 신영·IBK·한양·한국증권금융 등
# 예탁원 일대 블록 수장들 모임
# 업계 얘기부터 사적 고민까지 정보 공유
# /사진=연합뉴스
# 지난달 14일 서울 여의도 모 증권사 건물의 중식당. 점심시간답게 식당 안은 북적였지만 한쪽 테이블에선 좀처럼 한 데 모이기 힘든 얼굴들이 있었습니다. 증권업계 사장들입니다. "미국 금융시장이 앞으로 어떻게 될 것 같나"는 우려 섞인 질문부터 "MZ 직원들과의 소통이 어렵다"는 하소연까지 그날 점심 메뉴만큼 다양한 이야기들이 오갔습니다.
# 여의도에는 40년 넘게 계속되는 5060세대 모임이 있습니다. 가입 조건은 단 ...
#
# === 뉴스 18 ===
# 제목: SSG닷컴, 'SSG페이' 분할..신설 법인 '플래티넘페이먼츠' 출범
# 요약: SSG마켓은 간편결제 서비스인 'SSG페이'를 물적분할해 새로운 법인 '플래티넘페이먼츠'를 설립하여 고객과 협력사의 결제 데이터 및 자금을 보다 안정적으로 관리할 수 있게 되었다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/008/0005198386
# 본문 일부: SSG페이 로고. /사진제공=SSG닷컴
# SSG닷컴이 간편결제 서비스인 'SSG페이'를 물적분할해 새로운 법인 '플래티넘페이먼츠'를 설립한다. 분할 기일은 오는 7월 1일로, 신설 법인은 SSG닷컴의 자회사로 편입될 예정이다.
# 이와 관련해 SSG닷컴은 23일 공시를 통해 "간편결제 서비스의 전문성을 강화하고 범용성을 높여 경영 효율성을 제고하기 위한 결정"이라고 분할 배경을 설명했다.
# 이번 분할로 SSG닷컴은 독립된 간편결제사업자를 통해 고객과 협력사의 결제 데이터 및 자금을 보다 안정적으로 관리할 수 있게 된다. 또 페이 서비스와  ...
#
# === 뉴스 19 ===
# 제목: BNP파리바 “李 당선 시 확장적 재정 기조... 금리인하 신중해질 것"
# 요약: 더불어민주당 이재명 후보가 대통령 선거에서 승리할 경우 한국은행이 공격적인 금리인하에 신중해질 것이라는 전망이 나왔다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/014/0005353867
# 본문 일부: [과천=뉴시스] 이영환 기자 = 제21대 대통령선거를 11일 앞둔 23일 경기 과천시 중앙선거관리위원회에 날짜가 표시되고 있다. 사진=뉴시스화상
# [파이낸셜뉴스] 더불어민주당 이재명 후보가 대통령 선거에서 승리할 경우 한국은행이 공격적인 금리인하에 신중해질 것이라는 전망이 23일 나왔다.
# 윤지호 BNP파리바 이코노미스트는 '한국 대선: 경제 및 시장 영향' 보고서를 통해 "이재명 후보가 당선될 경우 경제 성장을 목표로 하는 확장적 재정정책을 추진할 가능성이 크다"며 "대규모 2차 추경 가능성이 크기 때문에 한국은행은 기준금리 인하에  ...
#
# === 뉴스 20 ===
# 제목: 바이오니아, 회백모 및 탈모 개선용 miRNA 기술 일본 특허 등록 완료
# 요약: 바이오니아 바이오니아는 자체 개발한 miRNA 기반 기술이 회백모(흰머리)와 탈모를 동시에 개선할 수 있는 신규 약학 및 화장료 조성물로서 일본에서 특허 등록 결정을 받았다고 23일 밝혔다.
# 종목명: ['바이오니아']
# url: https://n.news.naver.com/mnews/article/009/0005497543
# 본문 일부: [사진제공 = 바이오니아]
# 바이오니아는 자체 개발한 miRNA 기반 기술이 회백모(흰머리)와 탈모를 동시에 개선할 수 있는 신규 약학 및 화장료 조성물로서 일본에서 특허 등록 결정을 받았다고 23일 밝혔다.
# 이번에 등록 결정된 특허는 miRNA(마이크로RNA)를 유효성분으로 활용해 모발의 회백색화를 개선하고, 탈모를 예방 및 완화할 수 있는 조성물에 관한 것이다. 바이오니아는 miR-3139, miR-3189, miR-3199, miR-8485를 선별하고, 자사의 독자적인 SAMiRNA 플랫폼 기술을 접목해 이중가닥 miRNA 기반 ...
#
# === 뉴스 21 ===
# 제목: 핀텔, 자율주행 사업 본격 진출
# 요약: 핀텔은 국토교통부가 지원하는 '새만금 자율운송 상용차 실증지원 인프라 조성사업'의 일환인 '자율운송상용차 실증지원 자율주행 도로인프라 구축용역'에 참여기업으로 선정되었으며 이 사업은 국내에서 처음으로 상용차 자율주행의 상용화 가능성을 검증하고, 관련 생태계를 조성하는 데 목적이 있다.
# 이번 사업에서 핀텔은 교차로, 사고 다발 구간 등 주요 교통 분기점에 신호정보 연계 인프라를 구축하고, 교통사고 위험이 높은 구간과 교통 집중 관리 지점을 실시간으로 모니터링해 교통량을 분석·제공하는 시스템을 구현할 예정이라고 밝혔다.
# 종목명: ['핀텔']
# url: https://n.news.naver.com/mnews/article/015/0005135749
# 본문 일부: 자율주행 도로인프라 구축용역 핵심 참여기업 선정
# 이 기사는 05월 23일 14:02
# 마켓인사이트
# 에 게재된 기사입니다.
# 코스닥 인공지능(AI) 기업 핀텔이 자율주행 시장에 본격적으로 진출한다.
# 핀텔은 산업통상자원부, 전북특별자치도, 군산시가 지원하는 ‘새만금 자율운송 상용차 실증지원 인프라 조성사업’의 일환인 ‘자율운송상용차 실증지원 자율주행 도로인프라 구축용역’에 핵심 참여기업으로 선정됐다고 23일 밝혔다. 이 사업은 국내에서 처음으로 상용차 자율주행의 상용화 가능성을 검증하고, 관련 생태계를 조성하는 데 목적이 있다.
# 이번 사업 ...
#
# === 뉴스 22 ===
# 제목: 베어링 독일 펀드, 연초 이후 100억원 이상 자금 유입
# 요약: 지난 1990년부터 운용된 '베어링 독일 역외펀드'에 재간접으로 투자하는 베어링자산운용의 연초 이후 베어링 독일 펀드로 유입된 자금이 100억원을 돌파했다고 밝혔다.
# 종목명: ['미래에셋증권보통주', '삼성증권보통주']
# url: https://n.news.naver.com/mnews/article/014/0005353839
# 본문 일부: [파이낸셜뉴스] 베어링자산운용은 연초 이후 베어링 독일 펀드로 유입된 자금이 100억원을 돌파했다고 23일 밝혔다.
# 베어링 독일 펀드는 국내에서 유일한 독일 주식 액티브 펀드로, 지난 1990년부터 운용된 ‘베어링 독일 역외펀드’에 재간접으로 투자하는 구조다. 독일 경제의 구조적 변화와 기업 경쟁력에 주목해 장기적인 성장 기회를 선별적으로 포착하는 전략을 구사한다.
# 대부분의 글로벌 증시가 미국 트럼프 행정부 출범 이후 변동성을 보인 반면, 독일 증시는 상대적으로 강세를 이어가고 있다. 프랑크푸르트 증시의 DAX 지수는 연초 이후 2 ...
#
# === 뉴스 23 ===
# 제목: 美 IRA 세액공제 축소 추진에 태양광株 급락...전망은
# 요약: 미국의 인플레이션감출법(IRA) 세액 공제 조기 폐지 추진에 따라 태양광 관련주가 급락하고 있으며 전문가들은 긍정적·부정적 요인이 혼재한다는 분석을 내놓았다.
# 종목명: ['오씨아이홀딩스보통주', '한화솔루션보통주', 'OCI보통주']
# url: https://n.news.naver.com/mnews/article/014/0005353838
# 본문 일부: 한화큐셀의 미국 텍사스주 태양광 발전소 자료사진(한화큐셀 제공) /사진=뉴스1
# ''
# [파이낸셜뉴스] 미국의 인플레이션감출법(IRA) 세액 공제 조기 폐지 추진에 태양광 관련주가 급락하고 있다. 올해 실적이 개선될 것이라는 전망이 나오면서도 중장기적인 측면에서 보수적인 접근을 해야한다는 조언이 나온다.
# 23일 한국거래소에 따르면 한화솔루션은 오후 1시 55분 현재 11.11% 하락한 2만9600원에 거래 중이다. OCI홀딩스와 OCI도 각각 3.99%, 3.87% 하락한 6만4900원, 5만2200원에 거래되고 있다.
# 태양광 관려주의 ...
#
# === 뉴스 24 ===
# 제목: 엣지파운드리, 로봇 IR센서 주목…국산화 주도 정책
# 요약: 엣지파운드리는 22일 대전 대덕특구에 위치한 엣지파운드리를 방문해 정책 간담회를 열고 비수도권 반도체 육성 전략 및 로봇산업 10대 정책을 발표했다.
# 종목명: ['엣지파운드리']
# url: https://n.news.naver.com/mnews/article/277/0005597425
# 본문 일부: 로봇산업 기술이 인지능력을 좌우하는 'IR 센서(적외선 센서)' 기술로 무게추가 옮겨지는 가는 가운데 엣지파운드리는 23일 IR센서가 로봇산업 정책의 전면에 등장했다 밝혔다.
# 안도걸 더불어민주당 의원은 22일 대전 대덕특구에 위치한 엣지파운드리를 방문해 정책 간담회를 열고 비수도권 반도체 육성 전략 및 로봇산업 10대 정책을 발표했다. 이날 행사는 이재명 대통령 후보가 강조해온 '기술주권 확보' 및 '지역 산업 대전환' 전략의 구체적 실현 가능성을 현장에서 점검하고자 마련된 자리다.
# 엣지파운드리는 IR 센서 및 열화상 모듈을 개발· ...
#
# === 뉴스 25 ===
# 제목: '코스닥 도전' GC지놈 "2028년 매출 700억 달성하겠다"
# 요약: GC녹십자의 자회사 GC지놈은 혈액 등에 존재하는 세포유리DNA(cfDNA)를 검출하고 분석해 질병을 스크리닝하는 기술을 갖고 있으며 2028년 매출 700억원 달성 가능하다고 밝혔다.
# 종목명: ['삼성증권보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135739
# 본문 일부: GC지놈, IPO 기자 간담회
# 유전자 검사 서비스 업체
# 29~30일 일반 투자자 청약
# 6월 11일 상장 예정
# 주관사 삼성증권, 환매청구권 부여
# 기창석 GC지놈 대표./사진=진영기 한경닷컴 기자
# "보수적으로 계산했습니다. 2028년 매출 700억원 달성 가능합니다."
# 기창석 GC지놈 대표는 23일 서울 여의도 콘래드호텔에서 기자간담회를 열고 상장 후 성장 전략을 발표했다. 2013년 설립된 GC지놈(지씨지놈)은 GC녹십자의 자회사다. 건강검진, 산전·신생아 검사, 암 정밀진단, 유전희귀질환 정밀진단 등 300종 이상의 다양한 유전자  ...
#
# === 뉴스 26 ===
# 제목: GC지놈 "2028년 매출 700억 목표…암 조기진단 패러다임 바꿔"[IPO 출사표]
# 요약: 암 조기진단 시장의 패러다임을 바꾸고 있는 GC지놈은 독자적인 액체생검 기술과 임상유전체 분석 역량을 바탕으로 암 조기진단 시장의 패러다임을 바꾸고 있다.
# 종목명: ['삼성증권보통주']
# url: https://n.news.naver.com/mnews/article/018/0006021538
# 본문 일부: AI 기반 비침습 산전검사·다중암 조기진단 기술 보유
# 1분기 당기순익 흑자전환…6월 초 코스닥 시장 상장
# "공모자금으로 암 전주기 확장 R&D·글로벌 진출 투자"
# [이데일리 신하연 기자] “GC지놈은 독자적인 액체생검 기술과 임상유전체 분석 역량을 바탕으로 암 조기진단 시장의 패러다임을 바꾸고 있습니다. 상장을 통해 글로벌 탑 티어 액체생검·임상유전체 분석 선도 기업으로 도약할 것입니다.”
# 원본보기
# 기창석 GC지놈 대표가 23일 서울 여의도 콘래드 호텔에서 열린 IPO 간담회에서 인사말을 하고 있다. (사진=GC지놈)
# 기창석 GC지 ...
#
# === 뉴스 27 ===
# 제목: 사모펀드 어센트EP, 화장품 ODM 4위 업체 씨앤씨인터내셔널 인수
# 요약: 국내 화장품 ODM 4위 업체인 씨앤씨인터내셔널이 유증으로 발행되는 신주와 구주를 합쳐 씨앤씨인터내셔널 지분 약 40%를 확보할 예정이며, 기존 경영진은 계속 경영을 맡을 예정이다.
# 종목명: ['신세계보통주', '씨앤씨인터내셔널']
# url: https://n.news.naver.com/mnews/article/009/0005497535
# 본문 일부: 기존 경영진은 유지할 예정
# 신세계그룹 투자참여 추진
# [본 기사는 05월 23일(14:32) ‘
# 레이더M
# ’에 보도 된 기사입니다]
# 식물성 PDRN과 콜라겐을 복합화한 고기능 세럼 제형 /씨앤씨인터내셔널
# 국내 사모펀드 운용사 어센트에쿼티파트너스(이하 어센트EP)가 국내 화장품 ODM 4위 업체인 씨앤씨인터내셔널을 최대주주가 됐다.
# 23일 투자은행(IB) 업계에 따르면, 어센트EP는 유증으로 발행되는 신주와 구주를 합쳐 씨앤씨인터내셔널 지분 약 40%를 확보할 예정이다. 기존 씨앤씨인터내셔널 대주주였던 배은철 회장(및 특수관계인)은 지 ...
#
# === 뉴스 28 ===
# 제목: 나신평 "삼성바이오로직스 인적분할…신용도 영향 '제한적'"
# 요약: 나이스신용평가는 23일 삼성바이오로직스의 인적 분할 계획이 발표되었으며 이에 따라 회사의 신용도에 미치는 영향은 제한적이라고 밝혔다.
# 종목명: ['삼성바이오로직스보통주']
# url: https://n.news.naver.com/mnews/article/277/0005597371
# 본문 일부: 나이스신용평가는 23일 삼성바이오로직스의 인적 분할이 신용도에 끼치는 영향은 제한적이라고 밝혔다.
# 삼성바이오로직스는 전날 22일 인적 분할 계획을 공시했다. 바이오의약품 개발 및 상업화 사업을 분할해 신설법인(삼성에피스홀딩스)을 설립하고, 존속법인(삼성바이오로직스㈜은 바이오의약품 위탁개발생산(CDMO) 사업을 영위할 예정이다. 삼성에피스홀딩스는 삼성바이오에피스 및 바이오 관련 신사업을 영위하는 신설 자회사를 100% 지배하는 지주사로서 자회사 관리와 신규투자 등을 담당하게 된다.
# 나신평은 분할 전 발행된 회사채의 신용도에 즉각적인  ...
#
# === 뉴스 29 ===
# 제목: 하이브랩, 박정재 CFO 영입 "IPO준비 및 기업가치 제고 박차"
# 요약: 하이브랩은 최근 코스닥 상장사인 아이티센 대표집행임원(CEO), 아이티센그룹 부사장을 역임했던 박정재 대표(50사진 정부를 대표자문책임자(CFO)를 최고재무책임자(CFO)로 선임했다고 밝히며 재무, 전략기획, 회계, 인사, 총무, 법무 및 기업설명(IR) 관련 업무 전반을 총괄한다.
# 종목명: ['소프트센', '넷마블보통주', '크래프톤보통주', '카카오보통주', '롯데쇼핑 보통주', 'NHN보통주', '에스디엔']
# url: https://n.news.naver.com/mnews/article/014/0005353801
# 본문 일부: [파이낸셜뉴스] 하이브랩은 최근 코스닥 상장사인 아이티센 대표집행임원(CEO), 아이티센그룹 부사장을 역임했던 박정재 대표(
# 사진
# )를 최고재무책임자(CFO)로 선임했다고 23일 밝혔다.
# 박 CFO는 자본시장 내 기업공개(IPO)와 인수합병(M&A) 전문가로 꼽힌다. 회계사 출신으로 롯데쇼핑을 거쳐 나우회계법인, SDN, 아이티센그룹 부사장 등을 역임했다. SDN, 아이티센, 시큐센 등 3개사의 IPO업무를 주도적으로 담당해 국내 자본시장에 성공적으로 상장하는데 중요한 역할을 한 바 있다. 또 IT업계에서 쌍용정보통신, 콤텍시스템, ...
#
# === 뉴스 30 ===
# 제목: 리드코프, 이재명·김문수 소상공인 특화은행 공약 '4인뱅' 설립 탄력 기대↑ [특징주]
# 요약: 리드코프가 대선을 앞두고 유력 후보들이 '서민·소상공인 특화은행' 설립을 공약하면서 영향을 받아 장중 강세다.
# 종목명: ['리드코프']
# url: https://n.news.naver.com/mnews/article/014/0005353797
# 본문 일부: 금융위원회. 뉴스1 제
# [파이낸셜뉴스] 리드코프가 제4인터넷전문은행 출범 기대감에 장중 강세다. 대선을 앞두고 유력 후보들이 '서민·소상공인 특화은행' 설립을 공약하면서 영향을 받은 것으로 풀이된다.
# 23일 오후 1시 30분 현재 리드코프는 전 거래일 대비 6.69% 오른 5420원에 거래되고 있다.
# 금융위원회는 내달 제4인터넷전문은행(이하 4인뱅) 예비인가 사업자를 선정할 계획이다. 지난 3월 예비인가 신청을 낸 컨소시엄은 한국소호뱅크, 소소뱅크, 포도뱅크, AMZ뱅크 등 4곳이다.
# 실제 금융업계에서는 한국신용데이터(KCD)가 최 ...
#
# === 뉴스 31 ===
# 제목: NH-Amundi자산운용, 저소득층 청소년 가정에 쌀 180포대 기부
# 요약: 전국사무금융노조가 사회배려계층에 실질적 도움을 주기 위해 설립한 공익재단인 공익재단인인 NH-Amundi자산운용은 저소득층 청소년 가정을 돕기 위해 1000만원 상당의 쌀 180포대를 사무금융우분투재단에 기부했다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/009/0005497491
# 본문 일부: 범농협 ‘쌀 소비 촉진 운동’ 동참
# 원본보기
# 사진=NH-Amundi자산운용 제공.
# NH-Amundi자산운용이 저소득층 청소년 가정을 돕기 위해 1000만원 상당의 쌀 180포대를 사무금융우분투재단에 기부했다.
# 사무금융우분투재단은 전국사무금융노조가 사회배려계층에 실질적 도움을 주기 위해 설립한 공익재단이다.
# NH-Amundi운용이 기부한 쌀은 서울 15개 자치구에 위치한 교육복지센터를 이용하는 청소년가정, 장애인가정, 은둔고립청년가정에 전달될 예정이다.
# NH-Amundi운용 측은 “농업인들이 쌀 소비감소, 쌀값 하락 등으로 어려움을  ...
#
# === 뉴스 32 ===
# 제목: KKR, 대규모 블록딜로 6200억 확보…HD현대마린솔루션 주가 6% ‘뚝’
# 요약: 글로벌 사모펀드 운용사 KKR이 HD현대마린솔루션 보유 지분에 대한 블록딜에 참여한 KKR은 전날 장 마감 이후 HD현대마린솔루션 보유 지분에 대한 블록딜에 참여할 예정이었으나 수요예측이 끝나 수요예측이 끝나고, 지분 426만주(9.5%)에 대해 주당 14만5500원 수준으로 블록딜을 성공적으로 마무리하여 블록딜을 성공적으로 마무리하였으며 KKR은 지분 426만주(9.5%)에 대해 주당 14만5500원 수준으로 블록딜을 성공적으로 마무리하였으며, KKR은 지난해 12월 3일 KKR은 HD현대마린솔루션의 코스피 상장 당시 구주 매출과 지난 2월 블록딜에 나섰지만 윤석열 전 대통령의 비상계엄 선포로 거래가 무산되어 KKR은 올해 2월 블록딜을 재추진해 지분 4.49%(200만주)를 처분하고 2950억원을 확보하였다.
# 종목명: ['에이치디현대보통주', '에이치디현대마린솔루션보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497486
# 본문 일부: KKR 로고
# 글로벌 사모펀드 운용사 KKR(콜버그크래비스로버츠)이 HD현대마린솔루션 지분을 시간 외 대량매매(블록딜)로 매각하는 데 성공했다.
# 블록딜 여파로 HD현대마린솔루션 주가는 장 초반 하락 중이다.
# 23일 한국거래소에 따르면 오전 9시18분 기준 HD현대마린솔루션은 전 거래일 보다 9900원(-6.16%) 하락한 15만900원에 거래되고 있다.
# KKR은 전날 장 마감 이후 HD현대마린솔루션 보유 지분에 대한 블록딜에 나섰다.
# 전날 종가(16만800원)에서 할인율 7.96~9.83%이 적용된 14만5000원~14만8000원 사 ...
#
# === 뉴스 33 ===
# 제목: 삼성운용, ‘KODEX 신재생에너지액티브’ 장∙단기 수익률 1위
# 요약: 국내 재생 에너지·친환경 산업에 투자하는 국내 재생 에너지·친환경 산업 전반에 투자하는 'KODEX 신재생에너지액티브' 상장지수펀드(ETF)가 장∙단기 수익률 1위를 기록해 국내 주식형 액티브 ETF 61개 가운데 가장 높았다고 밝혔다.  가맹운용사는 위탁운용을 담당하고 있으며 투자종목과 비중을 적극적으로 조정할 수 있는 액티브 운용의 경쟁력을 입증한 셈이라고 밝혔다.
# 종목명: ['한화솔루션보통주', '에이치디현대일렉트릭보통주', 'SK오션플랜트보통주', '두산에너빌리티보통주']
# url: https://n.news.naver.com/mnews/article/009/0005497485
# 본문 일부: 1개월 수익률 24.45%, 3년은 86.21%
# 국내 주식형 액티브 ETF 중 1위
# 친환경 에너지 산업에 대한 성장세가 기대되는 가운데 국내 재생 에너지·친환경 산업 전반에 투자하는 ‘KODEX 신재생에너지액티브’ 상장지수펀드(ETF)가 장∙단기 수익률 1위를 기록했다.
# 삼성자산운용은 KODEX 신재생에너지액티브 ETF의 1개월 수익률 전일 기준 24.45%, 3년 86.21%를 기록하며 국내 주식형 액티브 ETF 61개 가운데 가장 높았다고 23일 밝혔다.
# 투자금도 급증했다. 이 ETF의 순자산은 998억원으로 지난 한 달 동안  ...
#
# === 뉴스 34 ===
# 제목: 마스턴투자운용, 미래 성장 동력 확보 위한 경력직 추가 채용 나서
# 요약: 마스턴투자운용이 미래 성장 동력 확보를 위한 2025년 상반기 경력사원 공개 채용에 나섰으며 채용이 얼어붙은 금융투자업계에서 마스턴투자운용의 연이은 인재 영입은 시장 경쟁력 강화를 위한 적극적인 행보로 평가받고 있으며 채용 홈페이지에서 지원접수를 가능하며 이후 1차 면접, 2차 면접을 거쳐 최종 합격자가 선발된다고 밝혔다.                                                                               지원접수는 마스턴투자운용 채용 홈페이지에서 가능하며 이후 1차 면접, 2차 면접을 거쳐 최종 합격자가 선발되며 자세한 요건은 채용 공고를 통해 확인할 수 있다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/009/0005497483
# 본문 일부: 마스턴투자운용 CI
# 대체투자 전문 자산운용사 마스턴투자운용이 미래 성장 동력 확보를 위한 2025년 상반기 경력사원 공개 채용에 나섰다
# 마스턴투자운용은 지난 21일부터 6월 1일까지 경력직 채용 모집 절차를 진행한다고 23일 밝혔다.
# 모집 부문은 △국내 개발 및 CM(Capital Market) △해외 투자운용 △리츠 △인프라 △법무 △감사 △총무 등 총 8개다.
# 이번 경력사원 채용은 앞선 지난 3월 이루어진 경력직 채용 이후 추가로 진행되는 것으로 다양한 분야의 전문 역량을 보유한 인재 확보를 통해 시장 변화에 신속하게 대응할 수 ...
#
# === 뉴스 35 ===
# 제목: 틱톡 철수 시나리오...메타·구글 ‘반사이익’ 노린다
# 요약: 미국 정부의 틱톡(TikTok) 규제 움직임이 구체화되면서 메타(META)와 구글(Google) 등 숏폼 기반의 광고 플랫폼을 보유한 기업들이 최대 수혜주로 주목받고 있다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 종목명: []
# url: https://n.news.naver.com/mnews/article/014/0005353776
# 본문 일부: 틱톡 CI. 뉴시스 제공
# [파이낸셜뉴스] 미국 정부의 틱톡(TikTok) 규제 움직임이 구체화되면서, 틱톡 공백에 따른 반사이익 기대가 증시에서도 감지되고 있다. 특히 메타(META)와 구글(Google) 등 숏폼 기반의 광고 플랫폼을 보유한 기업들이 최대 수혜주로 주목받고 있다.
# 23일 증권업계에 따르면 도널드 트럼프 미국 대통령이 취임 후 두 차례에 걸쳐 틱톡 금지 관련 행정명령을 내렸다. 이 가운데 지난 4월에는 틱톡 금지 시행을 75일 연기하는 두 번째 명령에도 서명했다. 오는 6월 19일까지 틱톡의 모회사인 바이트댄스(By ...
#
# === 뉴스 36 ===
# 제목: 한텍, 두산에너빌과 원전 핵심부품 공동 제작..美SMR 확대 행정명령 초읽기 [특징주]
# 요약: 도널드 트럼프 미국 대통령이 이르면 23일(현지시간) 원자로 승인 절차를 간소화하고 핵연료 공급망을 강화하는 내용의 행정명령에 서명할 예정으로 국내 주식시장에서 관련주들이 일제히 강세를 보이고 있다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 종목명: ['한텍', '두산에너빌리티보통주']
# url: https://n.news.naver.com/mnews/article/014/0005353773
# 본문 일부: 도널드 트럼프 미국 대통령이 워싱턴DC 인근 트럼프 내셔널 골프클럽에서 열린 암호화폐 만찬에 참석한 뒤 워싱턴 백악관 사우스 론(South Lawn)에 도착하고 있다. 뉴시스 제
# [파이낸셜뉴스] 도널드 트럼프 미국 대통령이 이르면 23일(현지시간) 원자로 승인 절차를 간소화하고 핵연료 공급망을 강화하는 내용의 행정명령에 서명할 예정이라고 알려지면서 국내 주식시장에서 관련주들이 일제히 강세를 보이고 있다.
# 23일 오후 12시 46분 현재 한텍은 전 거래일 대비 7.54% 오른 3만2800원에 거래 중이다.
# 이날 로이터 등 주요 외신에 ...
#
# === 뉴스 37 ===
# 제목: [마켓인]두나무앤파트너스, 美 음료 자동화 제조 로봇 스타트업 '보트리스타'에 92억원 투자
# 요약: 두나무의 투자 전문 자회사 두나무앤파트너스는 미국에 본사를 둔 음료 자동화 로봇 스타트업 보트리스타의 시리즈C 라운드에 92억원을 투자하였으며 이번 투자로 글로벌 F&B 기업 졸리비 그룹을 비롯해 다수의 전략적 투자자가 공동 출자하여 프리미엄 음료 제조에 더욱 용이해질 것으로 기대한다고 밝혔다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/018/0006021474
# 본문 일부: 시리즈C 라운드서 92억원 투자
# 졸리비 그룹 등 다수 SI 공동 참여
# 융합 시스템 기반 프리미엄 음료 기기
# [이데일리 마켓in 송재민 기자]두나무의 투자 전문 자회사 두나무앤파트너스가 미국에 본사를 둔 음료 자동화 로봇 스타트업 보트리스타의 시리즈C 라운드에 92억원을 투자했다고 밝혔다. 이번 라운드에는 글로벌 F&B 기업 졸리비 그룹을 비롯해 다수의 전략적 투자자가 공동 참여했다.
# 보트리스타 션 쉬우 대표. (사진=두나무앤파트너스)
# 보트리스타가 개발한 차세대 음료 자동화 로봇의 핵심은 다양한 점도의 액체를 정밀하게 토출하는 기술로 ...
#
# === 뉴스 38 ===
# 제목: SM 첫 영국 보이그룹 디어앨리스, 두 번째 싱글 '스위트' 발매
# 요약: 23일 0, 23일 0시 각종 글로벌 음악 플랫폼에서 음원 공개되고 있는 에스엠과 카카오엔터테인먼트의 첫 영국 보이그룹 '디어앨리스'가 유쾌하면서도 사랑스러운 곡 '스위트'를 공개했다.
# 종목명: ['에스엠엔터테인먼트']
# url: https://n.news.naver.com/mnews/article/008/0005198316
# 본문 일부: 에스엠엔터테인먼트(이하 SM)와 카카오엔터테인먼트의 첫 영국 보이그룹 '디어앨리스(dearALICE)'가 새 싱글로 컴백했다.
# 디어앨리스의 두 번째 싱글 '스위트'(Sweet)는 23일 0시(이하 현지시간) 각종 글로벌 음악 플랫폼에서 음원 공개됐다. 여름 시즌에 어울리는 유쾌하면서도 사랑스러운 곡으로 글로벌 팬들의 뜨거운 반응을 얻고 있다.
# 신곡 '스위트'는 2000년대 초를 풍미한 팝스타 더 넵튠스), 저스틴 팀버레이크의 음악에서 영감을 얻은 세련된 업비트 팝 곡이다. 독특한 퍼커션과 펑키한 기타 연주가 멤버들의 소울풀한 보컬과 ...
#
# === 뉴스 39 ===
# 제목: 원전은 키우고, 태양광 세액공제는 줄이고…美 정책에 엇갈린 주가
# 요약: 트럼프 미국 미국 대통령의 에너지 관련 정책에 원자력과 태양광 주(株)들의 희비가 엇갈리고 있다.
# 종목명: ['키움증권보통주', '한신기계공업보통주', '한화솔루션보통주', '태웅', '두산에너빌리티보통주']
# url: https://n.news.naver.com/mnews/article/008/0005198308
# 본문 일부: [오늘의 포인트]
# 원본보기
# 원자력발전소 증기
# 도널드 트럼프 미국 대통령의 에너지 관련 정책에 원자력과 태양광 주(株)들의 희비가 엇갈렸다. 트럼프 대통령이 원자력 산업을 활성화하기 위한 행정명령에 조만간 서명할 것이라는 소식에 원자력 주는 동반 상승 중이다. 반대로 친환경 에너지 세제 혜택이 줄어들 가능성이 커지면서 태양광 주는 하락하고 있다.
# 23일 오전 10시58분 현재 한국거래소(KRX)에서 원자력 대표주인 두산에너빌리티는 전날 대비 1500원(3.92%) 오른 3만9750원을 기록하고 있다.
# 원자력 관련 주들은 대부분 급등세 ...
#
# === 뉴스 40 ===
# 제목: 오르비텍, KAI와 'KF-21' 기계가공품 공급계약 체결
# 요약: 원자력 및 항공 정밀부품 전문기업 오르비텍이 한국항공우주산업(KAI)으로부터 차세대 전투기 KF-21 기종의 기계가공품 공급계약을 수주했다고 밝히며 이번 계약을 계기로 오르비텍은 항공사업부의 생산능력 강화를 위한 대규모 설비 투자를 단행하였다.
# 종목명: ['오르비텍']
# url: https://n.news.naver.com/mnews/article/014/0005353747
# 본문 일부: "초대형 5축 장비 도입"
# 오르비텍 CI
# [파이낸셜뉴스] 원자력 및 항공 정밀부품 전문기업 오르비텍이 한국항공우주산업(KAI)으로부터 차세대 전투기 KF-21(보라매) 기종의 기계가공품 공급계약을 수주했다고 23일 밝혔다. 이번 계약을 계기로 오르비텍은 항공사업부의 생산능력 강화를 위한 대규모 설비 투자를 단행한다.
# KF-21은 한국이 독자 개발 중인 4.5세대급 전투기로, 미래 공군 전력의 핵심 축으로 주목받고 있는 차세대 전투기다. 고도의 정밀성과 내구성이 요구되는 기체 구조물 및 부품의 생산에는 고성능 가공 설비가 필수적이다. ...
#
# === 뉴스 41 ===
# 제목: 케이씨티, ‘CBDC 한강’ 실험 본격화…특수단말기 공급 이력 부각 [특징주]
# 요약: 한국은행이 중앙은행 발행 디지털화폐(CBDC)의 실험을 본격화하고 있다는 소식에 케이씨티가 장중 강세다.
# 종목명: ['케이씨티']
# url: https://n.news.naver.com/mnews/article/014/0005353745
# 본문 일부: 이창용 한국은행 총재가 지난 15일 세종시 한국개발연구원(KDI)에서 열린 KDI-한국은행 공동 심포지엄 '초고령사회의 빈곤과 노동: 정책 방향을 묻다'에서 환영사를 하고 있다. 연합뉴스 제공
# [파이낸셜뉴스] 케이씨티가 장중 강세다. 한국은행이 중앙은행 발행 디지털화폐(CBDC)의 실험을 본격화하고 있다는 소식에 영향을 받은 것으로 풀이된다.
# 23일 오전 11시 5분 현재 케이씨티는 전 거래일 대비 15.97% 오른 3050원에 거래되고 있다.
# 이날 관련 업계에 따르면 한국은행 이창용 총재는 최근 KB국민은행, 신한은행, 하나은행, ...
#
# === 뉴스 42 ===
# 제목: 오르비텍, KAI와 KF-21 기계 가공품 공급 계약… 초대형 5축 장비 도입
# 요약: 오르비텍이 한국항공우주산업(KAI)으로부터 차세대 전투기 KF-21 기종의 기계가공품 공급계약을 수주하였고 이번 수주에 대응하기 위해 초대형 5축 가공 장비를 신규 도입했다.
# 종목명: ['오르비텍']
# url: https://n.news.naver.com/mnews/article/008/0005198295
# 본문 일부: 원자력 및 항공 정밀부품 전문 기업 오르비텍이 한국항공우주산업(KAI)으로부터 차세대 전투기 KF-21(보라매) 기종의 기계가공품 공급계약을 수주했다.
# 이번 계약을 계기로 오르비텍은 항공사업부의 생산능력 강화를 위한 대규모 설비 투자를 단행한다. KF-21은 한국이 독자 개발 중인 4.5세대급 전투기로, 미래 공군 전력의 핵심 축으로 주목받고 있는 차세대 전투기다.
# 회사 관계자는 "고도의 정밀성과 내구성이 요구되는 기체 구조물 및 부품의 생산에는 고성능 가공 설비가 필수적인데, 오르비텍은 이번 공급계약을 통해 해당 분야의 기술력과  ...
#
# === 뉴스 43 ===
# 제목: 에스엠, 에이티투메이저 소속사 그레이트엠엔터 투자…2대 주주 올라
# 요약: 23일 공개한SM은 6인조 보이그룹 '82MAJOR'가 소속된 그레이트엠엔터테인먼트(이하 그레이트엠)의 2대 주주가 된다고 밝히며 지분양수도 계약을 통해 오는 27일 지분 취득을 완료할 예정이다.
# 종목명: ['에스엠엔터테인먼트']
# url: https://n.news.naver.com/mnews/article/008/0005198284
# 본문 일부: 원본보기
# 에스엠엔터테인먼트( 이하 SM)가 6인조 보이그룹 '82MAJOR'(에이티투메이저)가 소속된 그레이트엠엔터테인먼트(이하 그레이트엠)의 2대 주주가 된다고 23일 밝혔다.
# SM은 지분양수도 계약을 통해 오는 27일 그레이트엠 지분 취득을 완료할 예정이다. 이번 투자는 FNC엔터테인먼트에서 다수의 프로젝트를 성공으로 이끈 김영선 대표의 프로듀싱 능력과 82MAJOR가 추구하는 음악적 방향성이 SM의 멀티 레이블 전략과 시너지를 낼 수 있다는 판단 하에 진행했다.
# 이는 'SM 3.0' 전략의 핵심 요소 중 하나인 멀티 레이블 전 ...
#
# === 뉴스 44 ===
# 제목: [마켓칼럼] 관세 영향 완화된 시장…미용·엔터·방산·원전에 '주목'
# 요약: 미국 관세 관세정책 이슈로 인해 국내 증시가 큰 폭의 등락을 반복한 이후 5월 들어서 기업실적발표와 맞물려 시장이 어느 정도 안정을 찾아가는 모양새이며 미국 원전 확대로 인해 국내 원전업체들의 주가가 상승폭이 컸다.                                                                                              5월~20일까지의 국내기업의 수출은 320억 달러로 전년 대비 2.4% 감소하였고
# 종목명: []
# url: https://n.news.naver.com/mnews/article/015/0005135663
# 본문 일부: ※한경 마켓PRO 텔레그램을 구독하시면 프리미엄 투자 콘텐츠를 보다 편리하게 볼 수 있습니다. 텔레그램에서 ‘마켓PRO’를 검색하면 가입할 수 있습니다.
# 김대현 하나증권 용산WM 센터장
# 지난4월 트럼프의 관세정책 이슈로 큰 폭의 등락을 반복한 이후 5월 들어서 기업실적발표와 맞물려 시장이 어느 정도 안정을 찾아가는 모양새다. 국내 증시도 어느덧 2600선으로 올라왔다. 5월~20일까지의 국내기업의 수출은 320억 달러로 전년 대비 2.4% 감소했다. 반도체와 선박 수출은 견조했지만, 자동차와 석유제품 수출이 감소했는데, 미국 관세  ...
#
# === 뉴스 45 ===
# 제목: 코스피, 개인 매수 속 2600선 공방…원전주 강세
# 요약: 코스피가 강보합권에서 2600선을 놓고 공방을 벌이고 있으며 코스피는 전일 대비 6.87포인트(0.26%) 오른 2600.54에 거래되고 있으며 코스피200선물을 3530억원어치 순매수하였으며, 외국인과 기관은 각각 406억원어치와 272억원어치를 팔고 있다.
# 종목명: ['에스케이하이닉스보통주', '휴젤', 'LG에너지솔루션보통주', '에코프로', '삼성바이오로직스보통주', '클래시스', 'KB금융지주 보통주', '기아보통주', '펩트론', '삼성전자보통주', '에코프로비엠', '한화에어로스페이스보통주', '현대자동차보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135652
# 본문 일부: 사진=연합뉴스
# 코스피가 강보합권에서 2600선을 놓고 공방을 벌이고 있다.
# 23일 오전 10시34분 현재 코스피는 전일 대비 6.87포인트(0.26%) 오른 2600.54에 거래되고 있다. 장 초반부터 2600선을 중간에 놓고 등락을 거듭하고 있다.
# 개인이 유가증권시장에서 730억원어치 주식을 사는 반면, 외국인과 기관은 각각 406억원어치와 272억원어치를 팔고 있다. 다만 외국인은 코스피200선물을 3530억원어치 순매수 중이다.
# 시가총액 상위 종목은 대체로 하락하고 있다.
# 삼성전자는 보합이고, SK하이닉스는 1.7% 상승 중이 ...
#
# === 뉴스 46 ===
# 제목: KICPA 회계정책연구원, 개원 1주년 기념 세미나 개최
# 요약: 지난 21일 KICPA 회계정책연구원은 개원 1주년을 맞아 회계정책연구원의 연구 성과를 공유하고, 회계정책연구원의 주요 사업인 CPA BSI 연구사업 발전 방향을 논의하는 세미나를 개최했다고 밝혔다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 종목명: []
# url: https://n.news.naver.com/mnews/article/014/0005353714
# 본문 일부: 지난 21일 서울 서대문구 충정빌딩 9층에서 열린 회계정책연구원 1주년 기념 세미나에서 (앞줄 오른쪽 두 번째부터) 김갑순 한국회계학회장, 한정석 서울대학교 교수, 최운열 회계정책연구원 이사장(한국공인회계사회 회장), 태현수 금융위원회 회계제도 팀장, 최훈 회계정책연구원 초빙연구위원과 회계관련 주요 인사들이 파이팅을 외치며 기념 촬영을 하고 있다.
# [파이낸셜뉴스]KICPA 회계정책연구원은 개원 1주년을 맞아 지난 21일 'CPA BSI의 발전적 방향에 관한 제언'을 주제로 세미나를 개최했다고 23일 밝혔다.
# 이번 세미나는 한정석 서 ...
#
# === 뉴스 47 ===
# 제목: 어제라도 살걸…'또 최고가' 비트코인, 11.2만달러 눈앞
# 요약: 비트코인이 간밤에 강세를 이어가면서 다시 한 번 최고가를 경신하였고  미국 내 제도적 흐름도 긍정적 요인으로 작용하였다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/008/0005198266
# 본문 일부: [특징주]
# /사진=게티이미지뱅크
# 가상자산 대장주인 비트코인이 간밤에 강세를 이어가면서 다시 한 번 최고가를 경신했다.
# 23일 오전 10시10분 기준으로 가상자산 시황 플랫폼 코인마켓캡에서 비트코인은 전일 대비 0.96% 오른 11만1332.03달러를 나타낸다. 이날 오전에는 11만1970.17달러까지 오르면서 전날에 이어 다시 역대 최고가를 경신했다. 국내에서는 1억5400만원대에 거래 중이다.
# 국내 가상자산 거래소에서 비트코인은 아직 역대 최고가에 닿지 못했다. 업비트를 기준으로 비트코인 사상 최고가는 도널드 트럼프 미국 대통령이 ...
#
# === 뉴스 48 ===
# 제목: 엔켐 "BYD 밸류체인 진입, 핵심 소재사 2곳 전략적 지분 투자"
# 요약: 글로벌 이차전지 전해액 선도기업 엔켐이 중국 전기차 기업 BYD 밸류체인 진입 가능성 확대와 더불어 중국 전역으로 사업 거점을 강화할 전략적 교두보를 마련했다.
# 종목명: ['엔켐']
# url: https://n.news.naver.com/mnews/article/014/0005353698
# 본문 일부: 엔켐 CI
# [파이낸셜뉴스] 글로벌 이차전지 전해액 선도기업 엔켐이 중국 전기차 기업 BYD 밸류체인 진입 가능성 확대와 더불어 중국 전역으로 사업 거점을 강화할 전략적 교두보를 마련했다.
# 엔켐은 첨가제 등 이차전지 핵심소재 사업을 전문적으로 영위하는 중국 기업 2곳과 전략적 지분 투자 계약을 체결했다고 23일 밝혔다.
# 엔켐이 투자를 단행한 기업은 ‘TCFG(천성불규 청두 과학기술유한공사)’, ‘회창홍푸 첨단신소재유한회사’다. TCFG와는 5% 지분 인수 계약을 체결했으며, 회창홍푸와는 매출 실적과 연계해 최대 30%까지 단계적 지분 ...
#
# === 뉴스 49 ===
# 제목: 금투협 부산지회, 토큰증권 발행 실무 과정 개설
# 요약: 한국금융투자협회 부산지회는 오는 7월 15일부터 23일까지 부산국제금융연수원에서 금융회사 직원 등을 대상으로 토큰증권 발행 실무 집합과정을 개설한다고 밝혔다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/014/0005353696
# 본문 일부: 금융투자협회 제공.
# [파이낸셜뉴스]한국금융투자협회 부산지회는 부산 남구 부산국제금융연수원에서 금융회사 직원 등을 대상으로 오는 7월 15일부터 23일까지 토큰증권(STO) 발행 실무 집합과정을 개설한다고 22일 밝혔다.
# 이번 과정은 최근 이슈인STO에 대한 구조, 발행 및 유통 규제, 조각투자 사례 등에 대한 강의로 금융업계 비즈니스 발굴에 필요한 전문지식을 습득할 수 있도록 구성됐다. 특히, STO 관련 법적, 기술적, 제도적 이슈에 대한 각 분야 현업 전문가들의 사례 중심 강의를 통해 디지털 금융 관련 실무역량을 크게 향상시킬  ...
#
# === 뉴스 50 ===
# 제목: HD현대마린솔루션, 2대주주 블록딜에 주가 약세
# 요약: 미국계 사모펀드 운용사 KKR이 보유한 HD현대마린솔루션의 지분 426만주를 4억5000만달러(6224억원)에 블록딜로 처분한 영향으로 코스피 시장에서 HD현대마린솔루션이 전일 대비 6800원(4.23%) 내린 15만4000원에 거래되고 있다.
# 종목명: ['에이치디현대보통주', '에이치디현대마린솔루션보통주']
# url: https://n.news.naver.com/mnews/article/008/0005198234
# 본문 일부: [특징주]
# 원본보기
# /사진=임종철 디자인 기자
# 선박 보수 서비스 기업인 HD현대마린솔루션이 2대 주주의 블록딜 소식에 주가 약세를 보인다.
# 23일 오전 9시40분 기준 한국거래소 코스피 시장에서 HD현대마린솔루션은 전일 대비 6800원(4.23%) 내린 15만4000원에 거래되고 있다. 개장 직후 8% 가까이 하락해 14만7900원까지 내리기도 했다.
# 2대 주주인 미국계 사모펀드 운용사 KKR이 지분을 시간 외 대량매매(블록딜)로 처분한 영향으로 보인다.
# 업계에 따르면 KKR은 전일 장 마감 후 HD현대마린솔루션의 지분 426만주를 ...
#
# === 뉴스 51 ===
# 제목: 삼일PwC, 베트남 철수 韓기업 '원스톱 자문' 개시
# 요약: 삼일PwC는 최근 베트남 시장에서 철수하는 기업을 위해 원스톱 통합 자문서비스를 시작했다고 밝히며 최근 베트남의 투자 환경 변화, 시장 경쟁 심화, 인건비 상승 등의 요인으로 인해 최근 철수하는 기업을 위해 원스톱 통합 자문서비스를 시작했다고 전했다.
# 종목명: ['현대홈쇼핑보통주']
# url: https://n.news.naver.com/mnews/article/014/0005353669
# 본문 일부: 삼일PwC 제공.
# [파이낸셜뉴스] 삼일PwC는 최근 베트남 시장에서 철수(U-turn)를 고려하는 기업을 위해 원스톱 통합 자문서비스를 시작했다고 23일 밝혔다. 매수자 발굴부터 실사, 거래 구조 설계, 계약 협상, 송금 절차 및 세무 이슈 대응에 이르기까지 전 과정에 걸친 맞춤형 솔루션을 제공할 예정이다.
# 최근 몇 년 새 베트남에 진출했던 일부 한국 기업이 사업 철수를 결정하거나 매각을 검토하는 사례가 늘고 있다. 2023년 이후 SK매직의 베트남 법인 청산, 동원F&B의 철수, 현대홈쇼핑의 지분 매각 시도 등이 대표적인 예다.
#  ...
#
# === 뉴스 52 ===
# 제목: "트럼프 수혜 테마 진입한다" 기대에…원전주 '들썩'
# 요약: 도널드 트럼프 미국 대통령이 조만간 원자력 산업 활성화를 위한 행정명령에 서명할 것이라는 소식이 전해지면서 원자력 발전 관련 종목들이 강세를 보이고 있다.
# 종목명: ['한국전력기술 보통주', '비에이치아이', '한전KPS 보통주', '두산에너빌리티보통주']
# url: https://n.news.naver.com/mnews/article/015/0005135618
# 본문 일부: 사진=EPA
# 원자력 발전 관련 종목들이 강세를 보이고 있다. 도널드 트럼프 미국 대통령이 조만간 원자력 산업 활성화를 위한 행정명령에 서명할 것이라는 소식이 전해지면서다.
# 23일 오전 9시42분 현재 두산에너빌리티는 전일 대비 1350원(3.53%) 오른 3만9600원에, 한전KPS는 1350원(3.31%) 상승한 4만2150원에, 한전기술은 2300원(3.77%) 뛴 6만3300원에 각각 거래되고 있다.
# 우리기술(15%), 서전기전(4.55%), 우진(5.22%), 비에이치아이(5.26%) 등도 큰 폭으로 오르고 있다.
# 간밤 뉴욕 ...
#
# === 뉴스 53 ===
# 제목: 나인테크 "맥신 상용화 속도…전고체 배터리 활용 전망"
# 요약: 이차전지 및 반도체 장비 전문업체 나인테크가 차세대 소재 '맥신(MXene)'의 상용화에 속도를 내고 있으며 신규 법인설립을 완료하고 관련 생산 시설을 구축했다고 밝혔다.
# 종목명: ['나인테크']
# url: https://n.news.naver.com/mnews/article/277/0005597205
# 본문 일부: 이차전지 및 반도체 장비 전문업체 나인테크가 차세대 소재 '맥신(MXene)'의 상용화에 속도를 내고 있다.
# 나인테크는 맥신 사업화를 전담할 신규 법인설립을 완료하고 관련 생산 시설을 구축했다고 23일 밝혔다. 회사가 추진 중인 맥신 기반 첨단 소재 사업은 소재 사업 포트폴리오 다각화 전략의 일환이다.
# 나인테크는 디스플레이, 반도체, 이차전지 장비를 기반으로 성장한 기업으로, 최근 소재 분야로의 확장을 핵심 중장기 전략으로 설정했다. 맥신을시작으로 첨단 기능성 소재 사업을 본격화하며, 안정적인 수익 다각화 및 글로벌 기술 경쟁력 확 ...
#
# === 뉴스 54 ===
# 제목: 하나증권, ‘중국 AI 산업의 성장 잠재력’ 글로벌 세미나 개최
# 요약: 하나증권은 오는 29일 오후 7시 서울 여의도 IFC에서 홍콩을 대표하는 상장지수펀드 운용사로, 항셍 테크 상품 운용에 강점이 있는 CSOP 자산운용사의 투자전략부 케리장 상무를 초청해 ‘중국 AI 산업의 성장 잠재력’ 글로벌 세미나를 진행한다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/014/0005353663
# 본문 일부: 항셍 테크 운용 강점 CSOP사 케리장 상무 초청
# 원본보기
# [파이낸셜뉴스] 하나증권은 ‘중국 AI 산업의 성장 잠재력’ 글로벌 세미나를 오는 29일 오후 7시 서울 여의도 IFC에서 진행한다고 23일 밝혔다.
# 이번 세미나는 홍콩을 대표하는 상장지수펀드(ETF) 운용사로, 항셍 테크 상품 운용에 강점이 있는 CSOP 자산운용사의 투자전략부 케리장 상무를 초청해 진행한다. 1부에는 ‘중국 AI 및 기술 산업 전망’을, 2부에는 ‘중국 정부 지원 정책 및 관련 투자 기회’를 주제로 강연이 이뤄질 예정이다.
# 이번 세미나는 선착순 150명  ...
#
# === 뉴스 55 ===
# 제목: SGC에너지, ‘에이로봇-엔비디아 투자 검토’ 수혜..지분 보유 소식에↑ [특징주]
# 요약: 국내 휴머노이드 로봇 전문기업 에이로봇이 엔비디아의 직접 투자 검토 대상으로 거론된다는 소식에 장중 오름세인 가운데, 22일 오전 9시 36분 현재 SGC에너지는 전 거래일 대비 3.23% 오른 2만4000원에 거래되고 있다.
# 종목명: ['SGC에너지보통주']
# url: https://n.news.naver.com/mnews/article/014/0005353662
# 본문 일부: 원본보기
# 젠슨 황 엔비디아 최고경영자(CEO)가 21일 타이베이 만다린 오리엔탈 호텔에서 열린 ‘글로벌 미디어 Q&A’ 행사에서 발언하고 있다. 뉴시스 제
# [파이낸셜뉴스] SGC에너지가 엔비디아발 호재에 장중 오름세다. 국내 휴머노이드 로봇 전문기업 에이로봇이 엔비디아의 직접 투자 검토 대상으로 거론된다는 소식에 영향을 받은 것으로 풀이된다.
# 23일 오전 9시 36분 현재 SGC에너지는 전 거래일 대비 3.23% 오른 2만4000원에 거래되고 있다.
# 에이로봇은 대만 타이베이에서 열리고 있는 스타트업 기업 행사 ‘이노벡스(Innove ...
#
# === 뉴스 56 ===
# 제목: 씨앤씨인터내셔널, 대규모 유상증자 부담에 약세
# 요약: 어센트에쿼티파트너스에 피인수되는 과정에서 1450억원 규모의 제3자 배정 유상증자가 이뤄지는 데 따른 지분가치 희석 때문으로 진단되며 급락하고 있다.
# 종목명: ['씨앤씨인터내셔널']
# url: https://n.news.naver.com/mnews/article/015/0005135598
# 본문 일부: 원본보기
# 배수아 씨앤씨인터내셔널 대표. /사진=임형택 기자
# 씨앤씨인터내셔널이 급락하고 있다. 어센트에쿼티파트너스에 피인수되는 과정에서 1450억원 규모의 제3자 배정 유상증자가 이뤄지는 데 따른 지분가치 희석 때문으로 보인다.
# 23일 오전 9시26분 현재 씨앤씨인터내셔널은 전일 대비 4300원(9.01%) 하락한 4만3400원에 거래되고 있다.
# 개장 전 대규모 유상증자를 공시한 영향으로 풀이된다. 씨앤씨인터내셔널은 전날 이사회를 열고 어센트에쿼티파트너스를 대상으로 1450억원 규모의 제3자 배정 유상증자를 결정했다고 공시했다.
# 관련 ...
#
# === 뉴스 57 ===
# 제목: 뮤직카우 "빅뱅 태양 노래, 공연 저작권료 전월 대비 200배 늘어"
# 요약: 음악 투자 플랫폼 뮤직카우가 지난 4월 저작권료 배당금을 정산하며 빅뱅 출신 가수 태양의 '메이크 러브'(Make Love) 공연 매체 저작권료가 전월 대비 200배 이상 증가했다고 밝혔다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/008/0005198226
# 본문 일부: 음악 투자 플랫폼 뮤직카우가 지난 4월 저작권료 배당금을 정산하며 빅뱅 출신 가수 태양의 '메이크 러브'(Make Love) 공연 매체 저작권료가 전월 대비 200배 이상 증가했다고 23일 밝혔다. /사진제공=뮤직카우
# 음악 투자 플랫폼 뮤직카우가 지난 4월 저작권료 배당금을 정산하며 빅뱅 출신 가수 태양의 '메이크 러브'(Make Love) 공연 매체 저작권료가 전월 대비 200배 이상 증가했다고 23일 밝혔다.
# 뮤직카우는 '2025년 4월 정산 노트'를 공개하면서 글로벌 아티스트의 월드투어 및 인기 걸그룹의 재결합 콘서트 등 영향 ...
#
# === 뉴스 58 ===
# 제목: 1.7만원→3.7만원…코스닥 데뷔 인투셀 '따블' 돌파
# 요약: 코스닥 상장 첫날인 23일 오전 9시23분 기준 코스닥 시장에서 바이오 기업 인투셀은 공모가 대비 2배인 3만3800원에 거래되는 중이며 ADC 플랫폼 개발에 주력하고 있는 기업이다.
# 종목명: ['인투셀']
# url: https://n.news.naver.com/mnews/article/008/0005198223
# 본문 일부: [특징주]
# 머니투데이,특징주,삽화,일러스트,증권부 /사진=임종철
# 인투셀이 코스닥 상장 첫날인 23일 '따블'(공모가 대비 2배)을 달성했다.
# 이날 오전 9시23분 기준 코스닥 시장에서 바이오 기업 인투셀은 공모가(1만7000원) 대비 1만6800원(98.8%) 오른 3만3800원에 거래되는 중이다. 앞서 장 시작과 함께 시초가가 118.2% 뛴 3만7100원에 형성됐지만 현재 상승폭을 일부 반납했다.
# 인투셀은 ADC(항체약물접합체) 플랫폼 개발에 주력하고 있는 기업이다. 리가켐바이오의 공동 창업자이자 핵심 플랫폼 기술 '콘쥬올' 발 ...
#
# === 뉴스 59 ===
# 제목: 롯데관광개발, 하반기 실적 성장 가속화 기대…목표가 상향-유안타
# 요약: 롯데관광개발이 중국 방문객 수 증가로 올해 시장 기대치를 상회할 실적 개선을 보일 수 있다고 23일 분석하며 투자의견 '매수'를 유지하고 목표주가는 기존 1만3000원에서 1만5000원으로 상향 조정하였다.                             투자의견 '매수'를 유지하고 목표주가는 기존 1만3000원에서 1만5000원으로 상향 조정하였다.                                                                                         김정욱 연구원은 중국인 방문객 수가 유의미하게 증가세를 보여 올해 한중 관계 개선으로 한국을 방문하는 중국 관광객 수가 본격적으로 가속화될 것이라고 진단하였다.
# 종목명: ['롯데관광개발 보통주', '유안타증권보통주']
# url: https://n.news.naver.com/mnews/article/008/0005198222
# 본문 일부: 제주 드림타워./사진제공=롯데관광개발
# 유안타증권은 롯데관광개발이 중국 방문객 수 증가로 올해 시장 기대치를 상회할 실적 개선을 보일 수 있다고 23일 분석했다. 투자의견 '매수'를 유지하고 목표주가는 기존 1만3000원에서 1만5000원으로 상향 조정했다.
# 이환욱 유안타증권 연구원은 "롯데관광개발의 1분기 매출액은 전년 동기 대비 14% 증가한 1219억원, 영업이익은 같은 기간 130억원으로 1분기 기준 역대 최대 실적을 달성했다"고 했다.
# 이 연구원은 "제주도 외국인 입도객 수의 회복세보다 드림타워 방문객 수 증가세가 빨라 외형 ...
#
# === 뉴스 60 ===
# 제목: "주주환원 확대 기대"BGF리테일 목표가↑-흥국
# 요약: 흥국증권이 BGF리테일의 부진한 실적과 BGF에코머트리얼즈 등 종속법인의 더딘 실적 개선으로 주가 재평가가 전망된다며 목표주가를 4700원으로 상향 조정했다.
# 종목명: ['BGF리테일보통주', '비지에프에코머티리얼즈']
# url: https://n.news.naver.com/mnews/article/014/0005353643
# 본문 일부: CU 점포 전경.(BGF리테일 제공). /사진=뉴스1
# [파이낸셜뉴스] 기업 밸류업 프로그램에 발맞춰 주주환원 강화에 대한 노력이 추가될 경우 주가 재평가가 전망된다며 흥국증권이 BGF리테일의 목표주가를 4700원으로 상향했다. 투자의견은 '매수'로 유지했다.
# 23일 박종렬 흥국증권 연구원은 "BGF리테일의 부진한 실적과 BGF에코머트리얼즈 등 종속법인의 더딘 실적 개선으로 올해도 EBIT(이자·세금전이익) 증익은 제한적일 전망"이라며 이같이 분석했다.
# 올해 1·4분기 연결기준 매출액은 1059억원으로 작년 동기 대비 9.2% 증가했 ...
#
# === 뉴스 61 ===
# 제목: 삼일PwC, 베트남 철수 기업 위한 '원스톱 자문 서비스' 시작
# 요약: 삼일PwC가 최근 베트남 시장에서 철수하는 기업을 위해 원스톱 통합 자문 서비스를 시작했다고 밝히며 최근 몇 년 새 일부 한국 기업이 인건비 상승과 경쟁 심화 등으로 사업 철수를 결정하거나 매각을 검토하는 사례가 늘고 있다고 전했다.
# 종목명: ['현대홈쇼핑보통주']
# url: https://n.news.naver.com/mnews/article/008/0005198219
# 본문 일부: 삼일PwC가 최근 베트남 시장에서 철수를 고려하는 기업을 위해 원스톱 통합 자문서비스를 시작했다. /사진제공=삼일PwC
# 삼일PwC가 최근 베트남 시장에서 철수를 고려하는 기업을 위해 원스톱 통합 자문 서비스를 시작했다고 23일 밝혔다. 매수자 발굴부터 실사, 거래 구조 설계, 계약 협상, 송금 절차 및 세무 이슈 대응에 이르기까지 전 과정에 걸친 맞춤형 솔루션을 제공할 예정이다.
# 최근 몇 년 새 베트남에 진출했던 일부 한국 기업이 인건비 상승과 경쟁 심화 등으로 사업 철수를 결정하거나 매각을 검토하는 사례가 늘고 있다. 2023년  ...
#
# === 뉴스 62 ===
# 제목: 두나무, 2025 서울국제정원박람회에 디지털 치유정원관 조성
# 요약: 두나무가 서울시 동작구 보라매공원에서 열리는 '2025 서울국제정원박람회'에 몰입형 힐링 공간 '세컨포레스트 : 디지털 치유정원'을 조성하여 관람객들에게 실제 숲에 온 듯한 몰입감을 선사한다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/008/0005198214
# 본문 일부: 두나무가 서울시 동작구 보라매공원에서 열리는 '2025 서울국제정원박람회'에 몰입형 힐링 공간 '세컨포레스트 : 디지털 치유정원'을 조성했다. /사진제공=두나무
# 두나무가 서울시 동작구 보라매공원에서 열리는 '2025 서울국제정원박람회'에 몰입형 힐링 공간 '세컨포레스트 : 디지털 치유정원'을 조성했다고 23일 밝혔다.
# 디지털 치유정원은 두나무가 '누구나 누릴 수 있는 숲과 정원'을 모토로 선보이는 가상의 숲이자 도심형 정원이다. 디지털 기술을 바탕으로 미디어 파사드(Media Facade) 형식의 가상 숲을 구현, 직업 혹은 신체적 ...
#
# === 뉴스 63 ===
# 제목: HLB파나진 "바이오스퀘어, 퀀텀팩 적용 표준물질 미국 특허 등록"
# 요약: HLB파나진은 자회사 바이오스퀘어가 면역진단 플랫폼 '퀀텀팩(QuantumPACK)' 기반의 모든 분석장비 및 진단 제품에 적용되는 표준물질에 대한 조성물 특허를 미국 특허청(USPTO) 등록 완료했다고 밝혔다.
# 종목명: ['에이치엘비파나진']
# url: https://n.news.naver.com/mnews/article/008/0005198212
# 본문 일부: HLB파나진은 자회사 바이오스퀘어가 면역진단 플랫폼 '퀀텀팩(QuantumPACK)' 기반의 모든 분석장비 및 진단 제품에 적용되는 표준물질에 대한 조성물 특허를 미국 특허청(USPTO) 등록 완료했다고 23일 밝혔다.
# 이번에 등록된 특허는 양자점(Quantum Dot) 함유 나노입자를 포함하는 면역진단용 바이오 분석기기의 검증용 표준물질 조성물과 이를 이용한 표준 스트립에 관한 것으로, 바이오스퀘어의 면역진단 기술 정확성과 신뢰도를 뒷받침하는 핵심 기술이다.
# 표준물질은 다수의 분석기기를 통해 검출을 진행할 때 요구되는 발광 신호  ...
#
# === 뉴스 64 ===
# 제목: [클릭e종목]"BGF, 실적 모멘텀 둔화…주주환원 확대 기대"
# 요약: 흥국증권 연구원은 23일 BGF에 대해 1분기 실적은 연결 기준 매출 1059억원, 영업이익 52억원으로 전년 동기 대비 각각 9.2% 증가, 41.6% 감소하며 시장 기대치를 크게 밑돌았다며 실적 모멘텀이 다소 부진할 전망이라고 진단했다.
# 종목명: ['BGF리테일보통주', 'BGF보통주', '비지에프에코머티리얼즈']
# url: https://n.news.naver.com/mnews/article/277/0005597165
# 본문 일부: 흥국증권은 23일 BGF에 대해 "올해도 실적 모멘텀이 다소 부진할 전망"이라며 "주주가치 제고를 위한 적극적인 노력이 필요하다"고 평가했다.
# 박종렬 흥국증권 연구원은 "1분기 실적은 연결 기준 매출 1059억원, 영업이익 52억원으로 전년 동기 대비 각각 9.2% 증가, 41.6% 감소하며 시장 기대치를 크게 밑돌았다"며 "외형이 비교적 큰 폭으로 증가한 것은 연결 자회사인 BGF에코머트리얼즈(대원케미칼 인수 및 연결 편입)의 매출 증가 때문"이라고 분석했다. 이어 "높은 외형 성장에도 영업이익이 감소한 것은 별도 부문과 지분법이 ...
#
# === 뉴스 65 ===
# 제목: 대구 상장법인 올해 1분기 매출액 2.2%↓ 영업이익은 0.7%↑
# 요약: 대구상공회의소에 따르면 대구지역 상장법인의 2025년 1분기 매출액은 전년 동기 대비 2.2%(4천869억원) 오르고 영업이익은 소폭 증가한 것으로 나타났으며 대구지역 상장법인의 올해 1분기 매출액과 당기순이익은 감소하고 영업이익은 소폭 증가한 것으로 나타났다.                                       대구의 상장법인 55개사의 2025년 1분기 매출액은 21조3천939억원으로 전년 동기 대비 2.2%(4천869억원)이고 영업이익은 전년 동기 대비 0.7%(81억원) 늘고 당기순이익은 7천210억원으로 8.1%(635억원) 늘어날 것으로 예상된다.
# 종목명: ['아이엠금융지주보통주', '에스엘보통주', '한국가스공사보통주']
# url: https://n.news.naver.com/mnews/article/001/0015406402
# 본문 일부: (대구=연합뉴스) 김현태 기자 = 대구지역 상장법인의 올해 1분기 매출액과 당기순이익은 감소하고 영업이익은 소폭 증가한 것으로 조사됐다.
# 원본보기
# [김토일 제작] 일러스트
# 23일 대구상공회의소에 따르면 대구의 상장법인 55개사(코스피 22개사·코스닥 33개사)의 2025년 1분기 매출액은 21조3천939억원으로 전년 동기 대비 2.2%(4천869억원) 감소했다.
# 영업이익은 1조2천407억원으로 0.7%(81억원) 늘고 당기순이익은 7천210억원으로 8.1%(635억원) 줄었다.
# 매출액 1~3위는 한국가스공사(12조8천107억원),  ...
#
# === 뉴스 66 ===
# 제목: '인적분할' 삼바, 경쟁력 확보 가능…"에피스 기업가치는 다소 우려"-DB
# ...
# 본문 일부: 국내 첫 'PQC IPSec VPN KISA 신속확인서' 획득
# 보안 패러다임의 진화...양자내성암호 솔루션 시장 혁신 예고
# KX넥스지 제공.
# [파이낸셜뉴스] KX의 보안 솔루션 자회사인 ‘KX넥스지’가 양자컴퓨터의 공격에도 안전한 'PQC IPSec VPN(Post-Quantum Cryptography Internet Protocol Security Virtual Private Network)'으로 양자내성암호 솔루션 시장의 혁신을 예고하고 있다.
# KX넥스지는 한국인터넷진흥원(Korea Internet & Security Agenc ...
#
# === 뉴스 980 ===
# 제목: "JYP엔터, 2분기 스키즈 등 아티스트 활동 집중…목표가↑"-흥국
# 요약: JYP엔터테인먼트에 대해 김 연구원은 올 2분기는 메인 아티스트의 활동이 집중된 구간이며 앨범 판매량과 콘서트 모객 수가 지속적으로 늘어날것으로 전망하며 투자의견을 '매수'로 상향조정했다.
# 종목명: []
# url: https://n.news.naver.com/mnews/article/015/0005132632
# 본문 일부: 스트레이 키즈/사진=JYP엔터테인먼트
# 흥국증권은 16일 JYP엔터테인먼트(JYP Ent.)에 대해 "올 2분기는 메인 아티스트의 활동이 집중된 구간"이라며 "앨범 판매량과 콘서트 모객 수가 지속적으로 늘어날 것"으로 전망했다. 이에 목표주가를 기존 8만5000원에서 10만원으로 올렸고 투자의견은 '매수'를 유지했다.
# 이 증권사 김지현 연구원은 "올 2분기부터 스트레이 키즈(스키즈)의 월드투어가 23회차 반영된다"며 "지난 1분기 실적 이후에는 대표 아티스트의 컴백 활동이 지속될 예정"이라고 말했다.
# 이어 "스키즈의 월드투어 'dom ...
#
# === 뉴스 981 ===
# 제목: '역대 실적'에 "주가 더오른다"…IBK·KB·한화證 삼양식품 목표가↑[줍줍 리포트]
# 요약: 16일 1분기 주요 증권사들이 올해 1분기 사상 최대 실적을 낸 IBK투자증권과 KB증권, 한화투자증권의 목표가를 일제히 상향 조정하고 IBK투자증권은 기존 108만 원에서 145만 원으로 34.3% 대폭 상향 조정했으며, KB증권과 한화투자증권도 각각 105만 원에서 125만 원으로, 120만 원에서 170만 원으로 크게 올리며, IBK투자증권은 기존 108만 원에서 145만 원으로 34.3% 대폭 상향 조정했다.
# 종목명: ['한화투자증권보통주', '삼양식품보통주']
# url: https://n.news.naver.com/mnews/article/011/0004486033
# 본문 일부: IBK 108만원→145만원, 한화 120만원→170만원
# 연합뉴스
# [서울경제]
# 전날 올해 1분기 사상 최대 실적을 낸
# 삼양식품(003230)
# 에 대해 16일 국내 주요 증권사들이 목표가를 줄줄이 상향하고 나섰다. IBK투자증권은 기존 108만 원에서 145만 원으로 34.3% 대폭 상향 조정했으며, KB증권과 한화투자증권도 각각 105만 원에서 125만 원으로, 120만 원에서 170만 원으로 크게 올렸다.
# 류은애 KB증권 연구원은 이날 보고서에서 “1분기 면·스낵 수출은 전년 동기 대비 32.2% 증가했다”며 “우호적인 달러와 위 ...
#
# === 뉴스 982 ===
# 제목: "비용 효율화로 하이트진로 깜짝 실적…가격 인상도 긍정적"-신한
# 요약: 하이트진로가 원부자재 가격 인상 등으로 인해 오는 28일 테라·켈리 등 주요 맥주 제품의 출고 가격을 평균 2.7% 인상한다고 밝혔다.
# 종목명: ['하이트진로보통주']
# url: https://n.news.naver.com/mnews/article/008/0005194926
# 본문 일부: [서울=뉴시스] 김진아 기자 = 맥주 성수기인 여름철을 앞두고 하이트진로가 테라·켈리 등 주요 맥주 제품의 출고 가격을 평균 2.7% 인상한다.   하이트진로는 13일 "원부자재 가격 인상 등으로 인해 오는 28일 테라·켈리 등 주요 맥주류 제품의 출고가를 조정한다"고 밝혔다. 사진은 13일 서울 시내의 한 대형마트에 진열된 하이트진로의 테라와 켈리 맥주. 2025.05.13. bluesoda@newsis.com /사진=김진아
# 신한투자증권은 16일 하이트진로가 마케팅 비용 효율화에 힘입어 올해 1분기 어닝 서프라이즈를 기록했다고 분 ...
#
# === 뉴스 983 ===
# 제목: "현대로템, 동유럽 중심으로 성장세 지속될 것"- 대신
# 요약: 16일 대대신증권은 16일 현대로템에 대해 해외시장 중심으로 앞으로 높은 성장세가 이어질 것이라고 예측하였으며, 1분기 매출액은 지난해 동기 대비 57.3% 늘어난 1조1761억원이며 영업이익률은 17.3%를 달성했다고 밝혔다.
# 종목명: ['대신증권보통주', '현대로템보통주']
# url: https://n.news.naver.com/mnews/article/008/0005194925
# 본문 일부: (서울=뉴스1) 임세영 기자 = 강인선 외교부 제2차관이 지난 2일 15개국 주한 외교단과 함께 창원의 현대로템을 방문, K2 전차 등 앞에서 기념촬영을 하고 있다. (외교부 제공, 재판매 및 DB 금지) 2025.4.3/뉴스1  Copyright (C) 뉴스1. All rights reserved. 무단 전재 및 재배포,  AI학습 이용 금지. /사진=(서울=뉴스1) 임세영 기자
# 대신증권은 16일 현대로템에 대해 해외시장 중심으로 앞으로 높은 성장세가 이어질 것이라고 예측했다.
# 올해 1분기 현대로템의 매출액은 지난해 동기 대비 5 ...
#
# === 뉴스 984 ===
# 제목: 한국금융지주, 금리 인하에 발행어음 마진 개선…목표가 19%↑-유안타
# 요약: 1분기 시장 기대치를 상회하는 실적을 발표한 한국금융지주가 금리인하기를 맞아 실적이 더욱 개선될 것이라는 분석이 나오며 IB 부문 수익이 전년 동기 대비 23.5% 증가하면서 IB 부문 수익이 전년 동기 대비 23.5% 증가했다.  가맹금 및 트레이딩 부문 손익이 증가하면서 IB 부문 수익이 전년 동기 대비 23.5% 증가했다.
# 종목명: ['유안타증권보통주', '한국투자금융지주보통주']
# url: https://n.news.naver.com/mnews/article/008/0005194923
# 본문 일부: 1분기 시장 기대치를 상회하는 실적을 발표한 한국금융지주가 금리인하기를 맞아 실적이 더욱 개선될 것이라는 분석이 나왔다.
# 우도형 유안타증권 연구원은 "한국금융지주 투자의견은 Buy(매수), 목표주가는 기존 대비 18.9% 상향한 11만3000원을 제시한다"며 "1분기 이익 증가에 따라 ROE(자기자본이익률)를 상향 조정했기 때문이다"고 밝혔다.
# 한국금융지주의 지난 1분기 지배주주순이익은 4584억원으로 시장 컨센서스를 35.4% 상회했다. IB(기업금융) 및 트레이딩 부문 손익이 증가하면서다. IB 부문 수익은 전년 동기 대비 23 ...
#
# === 뉴스 985 ===
# 제목: "과소평가해서 미안하다"…주가 '불기둥'
# 요약: 삼양식품의 올해 1분기 매출이 전세계에서 고르게 성장해 사상 최대 이익을 내자 16일 증권가에서 목표주가를 잇따라 상향 조정하고 있으며 과소평가해서 미안하다" 등의 반응이 줄을 이으면서 목표주가는 최대 170만원까지 치솟았다.
# 종목명: ['엔에이치투자증권보통주', '한화투자증권보통주', '삼양식품보통주']
# url: https://n.news.naver.com/mnews/article/215/0001209455
# 본문 일부: 삼양식품의 올해 1분기 매출이 전세계에서 고르게 성장해 사상 최대 이익을 내자 16일 증권가에서 목표주가를 잇따라 상향 조정하고 있다.
# "새로운 역사" "과소평가해서 미안하다" 등 반응이 줄을 이으면서 목표주가는 최대 170만원까지 치솟았다. 삼양식품은 전날 종가는 99만1천원이다.
# 전날 삼양식품은 올해 1분기 연결기준 영업이익이 1천340억원으로 작년 같은 기간 대비 67% 증가했다고 밝혔다. 분기 영업이익이 1천억원을 넘은 것은 최초로 컨센서스(시장 추정치 평균) 1천50억원을 28%가량이나 상회했다.
# 한유정 한화투자증권 연구원 ...
#
# === 뉴스 986 ===
# 제목: 한투증권 "기업들 1분기 실적 양호…연간 이익 추정치 상향"
# 요약: 16일 한국염동찬 연구원은 한국투자증권은 기업들이 1분기 양호한 실적을 발표하면서 연간 이익 추정치가 상향 조정됐다고 밝혔다.                한국투자증권은 기업들이 1분기 실적은 전반적으로 양호한 모습을 보였으며 연간 이익 추정치가 상향 조정됐다고 전했다.
# 종목명: ['한국전력공사보통주']
# url: https://n.news.naver.com/mnews/article/001/0015391915
# 본문 일부: [연합뉴스TV 제공]
# (서울=연합뉴스) 임은진 기자 = 한국투자증권은 기업들이 1분기 양호한 실적을 발표하면서 연간 이익 추정치가 상향 조정됐다고 16일 밝혔다.
# 염동찬 연구원은 "한국 상장 기업의 1분기 실적은 전반적으로 양호한 모습을 보였다"며 "과반수의 기업이 예상치를 상회하는 실적을 발표했고 예상치 대비 전체 실적 역시 양호했다"고 전했다.
# 이에 따라 그는 "2월까지 하향 조정되던 한국 기업 실적 추정치는 상향 조정으로 전환됐다"며 "실적 상향 조정은 IT와 산업재가 주도하고 있다"고 짚었다.
# 다만 그는 주가 흐름은 IT보다 ...
#
# === 뉴스 987 ===
# 제목: 메리츠증권 "현대로템, 수출국 추가 확보 기대…목표가↑"
# 요약: 메리츠증권이 16일 현대로템에 대해 수출국을 추가로 확보할 것이라는 기대가 크다며 목표주가를 14만원에서 16만원으로 상향 조정했다.
# 종목명: ['현대로템보통주']
# url: https://n.news.naver.com/mnews/article/001/0015391912
# 본문 일부: 현대로템
# [촬영 이충원] 2020년 대한민국 방위산업전
# (서울=연합뉴스) 곽윤아 기자 = 메리츠증권은 16일 현대로템에 대해 수출국을 추가로 확보할 것이라는 기대가 크다며 목표주가를 14만원에서 16만원으로 상향 조정했다. 전날 종가는 11만1천300원이다.
# 현대로템의 올해 1분기 매출액은 1조1천800억원으로 시장 컨센서스(전망치)를 8% 하회했다. 영업이익은 2천929억원으로 시장 예상을 8.7% 웃돌았다.
# 올해 1분기 다수의 휴일로 조업일수가 줄고, 지난해 폴란드에 K2 14대를 조기 납품한 영향으로 매출액은 시장 기대에 못  ...
#
# === 뉴스 988 ===
# 제목: "리노공업, 고부가 제품 수요 개선…목표가↑"-신한
# 요약: 16일 신한금융투자증권은 리노공업에 대해 고부가 제품 수요가 개선되고 있다며 목표주가를 기존 5만6000원에서 5만7000원으로 상향 조정했다.                          투자의견은 '매수'를 담고  증권사 오강호 연구원은 리노공업의 올 1분기 매출액(784억원)은 시장 추정치를 4% 웃돌았다며 "주요 제품인 리노핀과 리노소켓의 가격·수량이 전년 동기 대비 상승·확대된 게 전체 실적을 견인했다"고 말했다.
# 종목명: ['리노공업']
# url: https://n.news.naver.com/mnews/article/015/0005132627
# 본문 일부: 사진=한경DB
# 신한투자증권은 16일 리노공업에 대해 "고부가 제품 수요가 개선되고 있다"며 목표주가를 기존 5만6000원에서 5만7000원으로 상향 조정했다. 투자의견은 '매수'를 유지했다.
# 이 증권사 오강호 연구원은 "리노공업의 올 1분기 매출액(784억원)은 시장 추정치를 4% 웃돌았다"며 "주요 제품인 리노핀과 리노소켓의 가격·수량이 전년 동기 대비 상승·확대된 게 전체 실적을 견인했다"고 분석했다.
# 이어 "이번 실적에서 확인된 가격 상승 포인트가 리노소켓 부문이란 점에 주목한다"며 "리노소켓과 리노핀의 고부가 칩 개발에 따른 ...
#
# === 뉴스 989 ===
# 제목: "과소평가 미안해" 삼양식품 호실적에 목표가 줄상향…170만원도
# 요약: 삼양식품이 올해 1분기 해외를 포함한 전 지역에서 성장하며 사상 최대 이익을 내자 16일 증권가에서는 목표주가 상향 조정이 줄이고, 과소평가해서 미안하다" 등의 환호가 나왔고 목표주가는 최대 170만원으로 치솟았다.
# 종목명: ['키움증권보통주', '한화투자증권보통주', '삼양식품보통주', '엔에이치투자증권보통주', '교보증권보통주', '유안타증권보통주']
# url: https://n.news.naver.com/mnews/article/001/0015391910
# 본문 일부: 삼양식품
# [삼양식품 제공. 재판매 및 DB금지]
# (서울=연합뉴스) 조민정 기자 = 삼양식품이 올해 1분기 해외를 포함한 전 지역에서 성장하며 사상 최대 이익을 내자 16일 증권가에서는 목표주가 상향 조정이 줄 이었다.
# "새로운 역사" "과소평가해서 미안하다" 등 환호가 나왔고 목표주가는 최대 170만원으로 치솟았다. 삼양식품은 전날 종가는 99만1천원이다.
# 삼양식품은 올해 1분기 연결기준 영업이익이 1천340억원으로 작년 같은 기간 대비 67% 증가했다고 전날 밝혔다. 분기 영업이익이 1천억원을 넘은 것은 처음으로, 컨센서스(시장  ...
#
# === 뉴스 990 ===
# 제목: FSN, 매출 863억·영업이익 41억…1분기 역대 최대 실적
# 요약: FSN이 1분기 연결기준 매출 863억원, 영업이익 41억원, 상각전 영업이익(E TDA) 63억원 등 창사 이래 최대 1분기 실적을 기록했다.
# 종목명: ['에프에스엔']
# url: https://n.news.naver.com/mnews/article/008/0005194916
# 본문 일부: FSN이 광고·커머스 업계의 계절적 비수기에도 불구하고 자회사 부스터즈 등 브랜드 사업 부문의 고성장에 힘입어 창사 이래 최대 1분기 실적을 기록했다고 16일 밝혔다.
# FSN은 1분기 연결기준 매출 863억원, 영업이익 41억원, 상각전 영업이익(EBITDA) 63억원을 기록했다. 매출은 전년 동기 대비 약 125% 증가했고 영업이익은 62억원 이상 늘어났다. 1분기 실적 기준으로 2021년 이후 4년 만에 흑자전환이다. 하이퍼코퍼레이션 및 테크 계열사 등 사업별 분리 운영 중인 법인을 제외한 FSN의 실적은 매출 677억원, 영업 ...
#
# === 뉴스 991 ===
# 제목: '인니·베트남' 넘어 '싱가포르'로 영토 넓힌 롯데마트
# 요약: 롯데마트는 싱가포르 최대 유통업체 'NTUC FairPrice(이하 페어프라이스)'의 대형 할인점 '페어프라이스 엑스트라 비보시티점'에 K그로서리 전문 매장 'EXPRESS(익스프레스) 1호점'을 오픈한다고 15일 밝혔다.                                                    롯데마트는 싱가포르에 진출하여 싱가포르 시장에 진출하여 현지 유통사와의 상생경영을 통해 해외사업 확장 의지를 다질 예정이다.
# 종목명: ['롯데지주보통주', '오뚜기보통주', 'CJ보통주']
# url: https://n.news.naver.com/mnews/article/008/0005194915
# 본문 일부: 현지 1위 유통사 매장 내 '숍인숍' 형태..오픈 기념식에 3세 오너 신유열 참석
# 싱가포르 롯데마트 EXPRESS의 델리 특화 매장 '요리하다 키친'에서 악수를 나누고 있는 비풀 차울라 NTUC 페어프라이스 대표이사와 강성현 롯데마트·슈퍼 대표이사. /사진제공=롯데마트
# 롯데마트가 PB(자체 브랜드)를 앞세워 싱가포르 시장에 진출한다. 2008년 해외 진출 이후 17년만에 동남아 지역에서 인도네시아와 베트남에 이은 새로운 국가로 사업 영토를 넓힌 것이다.
# 이와 관련해 롯데마트는 싱가포르 최대 유통업체 'NTUC FairPrice(이하 ...
#
# === 뉴스 992 ===
# 제목: ‘아이스크림의 계절’ 코앞인데...빙그레 목표가 하향, 왜?
# 요약: 16일 IBIBK투자증권은 1분기 실적에 대해 1분기 이익추정치를 밑돈 실적에 따라 목표주가를 기존 12만원에서 11만원으로 하향 조정하였다만 연결법인 실적은 성장세를 이어갔다며 투자의견은 매수를 유지하는 반면 목표주가는 기존 12만원에서 11만원으로 하향 조정하였다.                                                                                                 빙그레가 1분기 실적에 대한 기저효과도 올 1분기 부진의 원인이 됐다고 진단하였다.
# 종목명: ['빙그레보통주']
# url: https://n.news.naver.com/mnews/article/009/0005493484
# 본문 일부: 여름철 빙과 생산하는 공장 [사진 출처 = 연합뉴스]
# IBK투자증권은 16일 빙그레에 대해 1분기 이익추정치를 밑돈 실적에 따라 목표주가를 기존 12만원에서 11만원으로 하향 조정했다.
# 다만 연결법인 실적은 성장세를 이어갔다며 투자의견은 매수를 유지했다.
# 빙그레의 1분기 영업이익은 전년동기대비 36.1% 감소한 135억원으로 컨센서스(197억원)를 하회했다.
# 우려했던 코코아·커피 등 원재료 가격 상승 외에도, 통상임금 적용에 따른 인건비 증가 영향이 컸던 영향으로 풀이된다.
# IBK투자증권은 빙그레가 지난해 기록한 높은 실적에 대한  ...
#
# === 뉴스 993 ===
# 제목: “엔씨소프트, 1분기 영업이익 시장 기대치 하회”…목표가↓
# 요약: 엔씨소프트가 올해 1분기 연결 기준 매출액이 전년동기대비 9.5% 감소하였고 내년 매출 목표 가이던스를 최소 2조원으로 발표하였으나 실적 성장에 대한 자신감을 드러냈다.
# 종목명: ['엔씨소프트보통주']
# url: https://n.news.naver.com/mnews/article/009/0005493483
# 본문 일부: 경기 성남시 판교 엔씨소프트 사옥. [사진 제공 = 엔씨소프트]
# IBK투자증권은 16일 엔씨소프트에 대해 올해 1분기 영업이익이 시장 기대치를 하회했다며 목표주가를 기존 27만원에서 23만5000원으로 하향 조정했다. 다만 내년 매출 목표 가이던스(전망치)를 최소 2조원으로 발표한 만큼 신작 출시가 기대된다며 투자의견은 ‘매수’를 유지했다.
# 엔씨소프트는 올해 1분기 연결 기준 매출액이 3603억원으로 전년동기대비 9.5% 감소했다. 같은 기간 영업이익은 52억원으로 79.7% 감소했다. 매출과 영업이익 모두 컨센서스(증권사 전망치  ...
#
# === 뉴스 994 ===
# 제목: [클릭e종목]"영원무역, 관세 불확실성 속 방어력 돋보여"
# 요약: SK증권은 16일 영원무역에 대해 1분기 매출액 8113억원, 영업이익 823억원을 기록하였으며 이는 전년 동기 대비 각각 14.3%, 15.9% 증가한 수준이라고 밝혔다.
# 종목명: ['SK증권보통주', '영원무역보통주']
# url: https://n.news.naver.com/mnews/article/277/0005593441
# 본문 일부: SK증권은 16일 영원무역에 대해 "관세 불확실성이 지속되고 있는 가운데 실적 방어력이 두드러진다"며 투자의견 '매수'와 목표주가 6만2000원을 유지했다.
# 영원무역은 1분기 매출액 8113억원, 영업이익 823억원을 기록했다. 전년 동기 대비 각각 14.3%, 15.9% 증가한 수준이다. 영업이익 기준 시장 기대치(757억원)를 웃돌았다. 형권훈 SK증권 연구원은 "주요 OEM 부문이 재고조정 마무리 이후 회복세를 보였고, 룰루레몬·아크테릭스 등 브랜드파워가 높은 고객사 수주를 바탕으로 실적을 방어했다"고 설명했다.
# OEM 부문은 ...
#
# === 뉴스 995 ===
# 제목: "미안합니다"…'불닭' 열풍에 증권맨들 '급사과'한 이유 [종목+]
# 요약: 하반기 밀양 신공장이 가동되면 삼양식품의 실적은 기대치를 크게 웃돌고 '불닭볶음면' 열풍도 길게 이어질 것이란 전망이다.                                                                   하반기 밀양 신공장이 가동되면 실적 개선세가 더 빨라질 것이란 전망과 더불어 하반기 밀양 신공장이 가동되면 실적 개선세가 더 빨라질 것이란 분석도 제기됬다.
# 종목명: ['한화투자증권보통주', '유안타증권보통주', '삼양식품보통주']
# url: https://n.news.naver.com/mnews/article/015/0005132625
# 본문 일부: '불닭' 열풍에 증권가도 환호
# "삼양식품, 170만원도 가능"
# 삼양식품 1분기 영업익1340억
# 전년비 67% 급증
# 목표주가 상향 릴레이
# 사진=연합뉴스
# 증권사들이 앞다퉈 삼양식품의 목표주가를 높이고 있다. 1분기 실적이 기대치를 크게 웃돌았고, '불닭볶음면' 열풍도 길게 이어질 것이란 전망이다. 하반기 밀양 신공장이 가동되면 성장세가 더 빨라질 것이란 분석도 제기된다.
# 16일 금융투자업계에 따르면 한화투자증권은 삼양식품 목표주가를 종전 120만원에서 170만원으로 대폭 상향했다. 전날 종가 99만1000원을 고려한 상승 여력은 71. ...
#
# === 뉴스 996 ===
# 제목: 신영증권, '1분기 실적부진' 피에스케이홀딩스 목표가↓
# 요약: 신영증권은 올해 1분기 실적이 크게 부진했던 피에스케이홀딩스의 목표주가를 목표주가를 6만1천원에서 5만5천원으로 하향 조정하고, 피에스케이홀딩스의 1분기 매출액과 영업이익은 각각 312억원, 95억원으로, 신영증권 추정치를 각각 30%, 50%가량 하회하는 것으로 집계했다.  신영증권에 따르면 올해 1분기 실적이 크게 부진했던 피에스케이홀딩스의 목표주가를 6만1천원에서 5만5천원으로 하향 조정하고, 올해 피에스케이홀딩스의 영업이익은 전년 대비 8.3% 감소한 811억원에 그칠 것으로 신영증권 연구원은 전망했다.
# 종목명: ['신영증권보통주', '피에스케이홀딩스']
# url: https://n.news.naver.com/mnews/article/001/0015391904
# 본문 일부: (서울=연합뉴스) 조성흠 기자 = 신영증권은 올해 1분기 실적이 크게 부진했던 피에스케이홀딩스의 목표주가를 6만1천원에서 5만5천원으로 하향 조정했다.
# 피에스케이홀딩스의 1분기 매출액과 영업이익은 각각 312억원, 95억원으로, 신영증권 추정치를 각각 30%, 50%가량 하회했다.
# 박상욱 신영증권 연구원은 "주요 메모리 고객사의 고대역폭 메모리(HBM) 투자 지연 및 경쟁 심화로 실적이 부진한 것으로 파악된다"고 말했다.
# 올해 상반기로 예상됐던 글로벌 메모리 3사의 HBM 생산능력(CAPA) 증설 시점은 최근 들어 하반기로 미뤄지고 ...
#
# === 뉴스 997 ===
# 제목: NH투자 "솔브레인, 美 관세 등 주가 하방 리스크 점차 해소"
# 요약: NH투자증권은 16일 반도체 소재 기업 솔브레인에 대해 미국의 관세 문제 등 주가 하방 압력으로 작용하던 일부 리스크가 해소되고 있다며 투자의견 '매수'와 목표주가 25만원을 제시했다.
# 종목명: ['엔에이치투자증권보통주', '솔브레인']
# url: https://n.news.naver.com/mnews/article/001/0015391903
# 본문 일부: 솔브레인 로고
# [솔브레인 제공]
# (서울=연합뉴스) 김태균 기자 = NH투자증권은 반도체 소재 기업 솔브레인에 대해 16일 "미국의 관세 문제 등 주가 하방 압력으로 작용하던 일부 리스크가 해소되고 있다"며 투자의견 '매수'와 목표주가 25만원을 유지했다.
# 솔브레인의 전날 종가는 17만9천800원이었다.
# 솔브레인은 반도체, 디스플레이, 이차전지 제조에 쓰이는 화학물질을 공급하는 곳으로, 주력 상품은 NAND(메모리칩의 일종) 공정에 쓰이는 고선택비인산(HSN) 식각액이다.
# 식각액은 반도체 질화막에서 필요 없는 부분을 제거하는 역할을  ...
#
# === 뉴스 998 ===
# 제목: [클릭 e종목]"아이티센글로벌, 한국 유일 금 기반 스테이블코인 사업 진행"
# 요약: KB증권은 아이티센글로벌이 가상 자산에 대한 정책 등으로 인해 향후 디지털 자산 발행 및 운영사업자로서 기업가치가 부각될 것으로 보고 투자의견과 목표주가는 제시하지 않았고 아이티센글로벌이 가상 자산에 대한 정책 등으로 인해 부각될 것으로 보이고 투자의견과 목표주가는 제시하지 않았고 케이B증권은 아이티센글로벌에 대해 한국 유일 금 기반의 스테이블코인 사업 진행, 향후 디지털자산 발행 및 운영사업자로서 기업가치가 부각된다고 16일 전망했다.            김희국 KB증권 연구원은 "아이티센글로벌은 종속회사 크레더를 통해 한국 최초로 센골드의 e금과 연동된 스테이블코인 'GPC 사업을 진행하고 있으며 향후 화폐연동 기반 스테이블코인 발행 사업을 준비할 것으로 예상된다"고 말했다.
# 종목명: ['아이티센글로벌']
# url: https://n.news.naver.com/mnews/article/277/0005593439
# 본문 일부: KB증권은 아이티센글로벌에 대해 한국 유일 금 기반의 스테이블코인 사업 진행, 향후 디지털자산 발행 및 운영사업자로서 기업가치가 부각된다고 16일 전망했다. 투자의견과 목표주가는 제시하지 않았다.
# KB증권은 아이티센글로벌이 가상 자산에 대한 정책 등으로 인해 부각될 것으로 예상했다.
# 임상국 KB증권 연구원은 "최근 대선 후보의 원화 기반 스테이블코인 필요성 언급 등 향후 디지털 자산에 대한 정책 및 법안 추진이 빨라질 것으로 기대한다"며 "스테이블코인은 법정화폐, 금, 암호화폐 등을 기반으로 가치가 고정된 디지털 자산으로 기존 비트 ...
#
# === 뉴스 999 ===
# 제목: [클릭 e종목] "내수·해외 순항 농심…관세 영향도 제한적"
# 요약: 농심은 1분기 깜짝 호실적을 거둔 농심이 2분기 이후에도 준수한 실적을 이어갈 것이라는 전망이 나온다.  가맹점과 해외법인 매출도 전년 동기 대비 2.9% 증가하였고 중국법인 영업이익률이 유베이와의 총판계약 효과로 2.7%포인트 개선된 점이 고무적이라는 후문이다.
# 종목명: ['농심보통주']
# url: https://n.news.naver.com/mnews/article/277/0005593432
# 본문 일부: 1Q 시장 전망 뛰어넘은 실적 달성
# 가격인상 본격화…2Q부터 우상향 기대감
# 올해 1분기 깜짝 호실적을 거둔 농심이 2분기 이후에도 준수한 실적을 이어갈 것이라는 전망이 나온다. 내수와 미국 내 가격을 인상했고 '신라면 툼바' 제품 해외 출시 등 상승 동력이 풍부하다는 평가다.
# 16일 KB증권은 이같은 배경에 농심의 투자의견 '매수'와 목표주가 52만원을 유지했다. 전날 종가는 41만5000원이었다.
# 농심은 올해 1분기 연결 기준 매출 8930억원, 영업이익 561억원을 기록했다. 전년 동기 대비 매출은 2.3% 늘었고 영업이익은 8 ...
#
# === 뉴스 1000 ===
# 제목: "엔씨소프트, 내년 매출 목표 2조…실현 가능성 높아"-IBK
# 요약: 엔씨소프트는 신작 7종 이상을 출시하면서 내년 매출 목표로 2조원 이상을 제시하였으나 증권사들은 기대작 아이온2는 기존 PC 아이온의 한계를 보완하고 레이드 콘텐츠 중심의 차별화를 꾀하며 리니지와는 비즈니스 모델 및 콘텐츠 구조에서 명확히 구분될 것으로 발표하였다.
# 종목명: ['엔씨소프트보통주']
# url: https://n.news.naver.com/mnews/article/015/0005132623
# 본문 일부: 경기 성남시에 위치한 '엔씨소프트 판교 R&D 센터'의 모습./사진=엔씨소프트
# IBK투자증권은 16일 엔씨소프트에 대해 "사측이 제시한 내년 매출 2조원 이상의 가이던스(전망치)는 실현 가능성이 높다"고 판단했다. 투자의견 '매수'와 목표주가 23만5000원은 유지했다.
# 이 증권사 이승훈 연구원은 "엔씨소프트의 흥행 가능성이 가장 높은 지식재산권(IP) 신작 게임이 오는 4분기 출시될 예정"이라며 "회사가 제시한 가이던스의 실현 가능성이 높다"고 봤다.
# 엔씨소프트는 신작 7종 이상을 출시하면서 내년 매출 목표로 2조원 이상을 제시했 ...

# %%
# 종목명이 1개 이상 매칭된 뉴스의 수
matched_count = sum(1 for r in results if r['종목명'])

# 전체 뉴스 수
total_count = len(results)

# 매칭률 계산
matched_ratio = matched_count / total_count * 100

# 출력
print(f'종목명이 매칭된 뉴스 수: {matched_count}개 / {total_count}개')
print(f'매칭률: {matched_ratio:.2f}%')
# Out:
# 종목명이 매칭된 뉴스 수: 796개 / 1000개
# 매칭률: 79.60%
