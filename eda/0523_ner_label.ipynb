# %%
# 라이브러리 불러오기
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
from tqdm import tqdm
import time
from label import id2label # Label 정보 매핑용 사전, label.py의 내용을 불러 옴

# %%
# NER 모델 및 토크나이저 불러오기
model_name = 'KPF/KPF-BERT-NER'
ner_pipeline = pipeline(
    task='ner',
    model=model_name,
    tokenizer=model_name,
    aggregation_strategy='simple',
    framework='pt'
)
# Out:
# Device set to use mps:0

# %%
# 종목명 사전 불러오기
company_df = pd.read_csv('../fastapi/datas/KRX_기업명_20250521.csv')
company_names = set(company_df['종목명'].dropna().unique())

# %%
# 뉴스 데이터 불러오기 및 제목 + 본문 결합
news_df = pd.read_csv('../fastapi/datas/mknews_with_id_embedding.csv')
news_df['text_combined'] = (
    news_df['title'].fillna('') + ' ' + news_df['content'].fillna('')
).str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
# 텍스트 자르기
def split_text(text, max_length=500):
    return [text[i:i+max_length] for i in range(0, len(text), max_length)]

# %%
# WordPiece 병합 + 라벨 기반 종목 추출
def extract_stock_labels_by_label_id(text):
    chunks = split_text(text, max_length=500)
    matched_names = set()
    
    for chunk in chunks:
        entities = ner_pipeline(chunk)

        # WordPiece 병합 처리
        merged_entities = []
        current_word = ''
        current_score = []
        current_label = ''
        for ent in entities:
            word = ent['word']
            score = ent['score']
            label_id = ent['entity_group']
            label_num = int(label_id.split('_')[1])
            label_name = id2label.get(label_num, "")
            key = label_name[2:] if label_name.startswith(('B-', 'I-')) else label_name
            
            # 경제 조직 라벨로 제한 (OGG_ECONOMY 포함)
            if key.startswith('OGG_ECONOMY'):
                if word.startswith('##'):
                    current_word += word[2:]
                    current_score.append(score)
                else:
                    if current_word:
                        merged_entities.append((current_word, current_label, sum(current_score)/len(current_score)))
                    current_word = word
                    current_score = [score]
                    current_label = label_name
        if current_word:
            merged_entities.append((current_word, current_label, sum(current_score)/len(current_score)))

        for word, label, score in merged_entities:
            if word in company_names:
                matched_names.add(word)

    return list(matched_names)

# %%
# 전체 뉴스(9005건)에 적용
results = []
start_time = time.time()

progress = tqdm(enumerate(news_df['text_combined']), total=len(news_df), desc='전체 뉴스 종목명 라벨링 중')

for idx, text in progress:
    try:
        matched = extract_stock_labels_by_label_id(text)
    except Exception as e:
        print(f'오류 (인덱스 {idx}): {e}')
        matched = []
    results.append(matched)

    # 평균 시간 및 남은 시간 계산
    elapsed = time.time() - start_time
    avg_time = elapsed / (idx + 1)
    remaining = avg_time * (len(news_df) - idx - 1)

    # 진행률 바에 부가 정보 추가
    progress.set_postfix({
        '진행': f'{idx+1}/{len(news_df)}',
        '평균': f'{avg_time:.2f}s',
        '남은시간': f'{remaining:.1f}s'
    })

news_df['labels_by_id'] = results
# Out:
# 전체 뉴스 종목명 라벨링 중:   0%|          | 0/9005 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 전체 뉴스 종목명 라벨링 중: 100%|██████████| 9005/9005 [16:17<00:00,  9.22it/s, 진행=9005/9005, 평균=0.11s, 남은시간=0.0s]

# %%
# 결과 확인
for i, row in news_df.iterrows():
    print(f'\n=== 뉴스 {i+1} ===')
    print('제목:', row['title'])
    print('출력된 종목:', row['labels_by_id'])
# Out:
# === 뉴스 1 ===
# 제목: 배터리도 증시 대피처 아니었다…한달 동안 -23% 빠진 LG엔솔
# 출력된 종목: ['LG에너지솔루션', 'NH투자증권']
#
# === 뉴스 2 ===
# 제목: “돈 못갚는 사람, 돈 못빌리는 사람 는다”…불황주 우울한 급등
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 3 ===
# 제목: 삼성전자 4분기 실적 ‘한파주의보’…“내년 상반기가 더 문제”
# 출력된 종목: ['삼성증권', '다올투자증권', 'SK하이닉스', '삼성전자', '유진투자증권']
#
# === 뉴스 4 ===
# 제목: 코리아에셋투자증권, 소외 아동 위한 ‘산타 봉사’ 진행
# 출력된 종목: []
#
# === 뉴스 5 ===
# 제목: ‘부동산 스트레스’ 침체 걱정에 뉴욕증시 하락 마감…시장의 눈은 PCE 물가로 [월가월부]
# 출력된 종목: []
#
# === 뉴스 6 ===
# 제목: “새주인을 찾습니다”…케이카, 사흘 연속 상승세
# 출력된 종목: ['케이카']
#
# === 뉴스 7 ===
# 제목: [단독]네이버, 자이언트스텝 지분 블록딜...포쉬마크 인수 대금 마련?
# 출력된 종목: []
#
# === 뉴스 8 ===
# 제목: 씽크풀, ‘2022 벤처창업진흥 유공 포상’ 국무총리 표창 수상
# 출력된 종목: []
#
# === 뉴스 9 ===
# 제목: 한발 물러난 컬리…오아시스, ‘이커머스 1호 상장’ 주인공되나
# 출력된 종목: ['신세계', '이마트']
#
# === 뉴스 10 ===
# 제목: "경기 바닥일때 사자"… 화학·철강株 '활활'
# 출력된 종목: ['현대제철', 'POSCO홀딩스', '효성티앤씨']
#
# === 뉴스 11 ===
# 제목: “강남 용산 빼고 부동산규제 다 푼다는데”…증권가 건설株 ‘갸우뚱’
# 출력된 종목: ['대우건설', '삼성증권', '현대건설', 'GS건설']
#
# === 뉴스 12 ===
# 제목: “땡큐, 폴란드”…해외 수주 기대감에 되살아난 방산주
# 출력된 종목: ['한국항공우주', '현대로템', '삼성증권', 'SK증권', 'LIG넥스원', '한화에어로스페이스']
#
# === 뉴스 13 ===
# 제목: 날개 꺾였던 게임株 옥석가리기 본격화
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 14 ===
# 제목: 투자 경험 많다던 김부장, 수익률은 김대리보다 낮았다
# 출력된 종목: ['LG화학', '카카오', 'NH투자증권', 'KT', '삼성전자', '한화솔루션']
#
# === 뉴스 15 ===
# 제목: 큐브엔터 (여자)아이들, 美 ‘미디어베이스 탑 40’ 진입…누드 39위 등극
# 출력된 종목: []
#
# === 뉴스 16 ===
# 제목: “영업이익 50%까지 늘 수 있다” SM자회사 디어유 주가 급등
# 출력된 종목: ['엔씨소프트']
#
# === 뉴스 17 ===
# 제목: 아웃도어王과 세 명의 딸
# 출력된 종목: ['영원무역', '영원무역홀딩스']
#
# === 뉴스 18 ===
# 제목: KB證, 해외주식 글로벌원마켓 누적약정 50조원 돌파
# 출력된 종목: []
#
# === 뉴스 19 ===
# 제목: OCI·호텔신라 … 공매도 버티니 '볕들 날'
# 출력된 종목: ['DL', '크래프톤', '명신산업', '호텔신라', '롯데관광개발', 'HMM', 'LG이노텍', '아모레퍼시픽', 'OCI', '두산퓨얼셀']
#
# === 뉴스 20 ===
# 제목: 국민연금 따라 전주에 사무소
# 출력된 종목: []
#
# === 뉴스 21 ===
# 제목: 바이오니아, 현장 분자진단장비 IRON-qPCR·진단키트 수출 물꼬텄다
# 출력된 종목: []
#
# === 뉴스 22 ===
# 제목: 2360 넘어선 코스피…증권가 이 기업 목표주가 ‘쑥’
# 출력된 종목: ['한화투자증권', 'LG에너지솔루션', 'SK이노베이션', 'NH투자증권', '크래프톤', '호텔신라', 'LG이노텍', '한미약품', '아모레퍼시픽', '기아']
#
# === 뉴스 23 ===
# 제목: “공매도 덕에” 연초 토끼랠리에 주가 더 오른다
# 출력된 종목: ['DL', '크래프톤', '명신산업', '호텔신라', '롯데관광개발', 'HMM', 'LG이노텍', '아모레퍼시픽', 'OCI', '두산퓨얼셀']
#
# === 뉴스 24 ===
# 제목: 씨에스윈드, 美 풍력주 급등에 강세
# 출력된 종목: ['유진투자증권', '씨에스윈드']
#
# === 뉴스 25 ===
# 제목: TYM 통합 북미법인 출범 기념 ‘TYM Next Generation’ 개최
# 출력된 종목: ['TYM']
#
# === 뉴스 26 ===
# 제목: “회계법인 ‘가치평가’ 책임에 형사처벌은 과도”
# 출력된 종목: []
#
# === 뉴스 27 ===
# 제목: 코나아이, 디 올 뉴 그랜저에 ‘e hi-pass’ 전용 eSE 칩 국내 최초 공급
# 출력된 종목: []
#
# === 뉴스 28 ===
# 제목: 강원랜드가 만든 슬롯머신, 필리핀에 수출된다
# 출력된 종목: ['강원랜드', 'GKL']
#
# === 뉴스 29 ===
# 제목: 금융당국 “회사채·CP금리 개선세 확연…비우량물 지원 강화”
# 출력된 종목: []
#
# === 뉴스 30 ===
# 제목: 삼성제약, 상호 도용 업체 형사 고소...유사 상품 각별 주의
# 출력된 종목: ['삼성제약']
#
# === 뉴스 31 ===
# 제목: 거래소 파산 위험 없이 비트코인 투자하세요...삼성자산운용, 선물ETF 홍콩 상장
# 출력된 종목: []
#
# === 뉴스 32 ===
# 제목: 삼성증권에서 해외ETF 정보를 실시간으로 조회하세요
# 출력된 종목: ['삼성증권']
#
# === 뉴스 33 ===
# 제목: 바디텍메드, ‘흡입형 치료기’ 신성장동력 삼는다
# 출력된 종목: []
#
# === 뉴스 34 ===
# 제목: 고금리에 훨훨…타이거CD금리 ETF 순자산 4조 돌파
# 출력된 종목: []
#
# === 뉴스 35 ===
# 제목: “이제 풀리나 했더니”…중국 발길 다시 끊기자 화장품주 시들
# 출력된 종목: ['한국화장품', '한국화장품제조', 'LG생활건강', '코스맥스', '아모레퍼시픽', '토니모리']
#
# === 뉴스 36 ===
# 제목: “끝난줄 알았는데 어느 새 2배 벌었다”...되살아난 OTT공룡
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 37 ===
# 제목: 노후자산 현금으로만 10억원… ‘연금 부자’ 통장이 궁금해 [신화!머니?］
# 출력된 종목: ['미래에셋증권', 'ESR켄달스퀘어리츠', '신한알파리츠', '맥쿼리인프라', '제이알글로벌리츠']
#
# === 뉴스 38 ===
# 제목: 위기의 애플 구한 잡스의 ‘선택과 집중’…아이맥은 여기서 나왔다 [오기자의 테크株 흥망사]
# 출력된 종목: []
#
# === 뉴스 39 ===
# 제목: 배당 매력 부각에 외국인도 담았다...금융주, 증권가도 호평
# 출력된 종목: ['교보증권', '하나금융지주', 'KB금융', '현대차증권', '신한지주']
#
# === 뉴스 40 ===
# 제목: 보령바이오파마 매각 속도···내달 8일까지 LOI 접수
# 출력된 종목: []
#
# === 뉴스 41 ===
# 제목: 실적 부진한데 왜? 삼성전자·LG전자 주가 오히려 더 뛰었다
# 출력된 종목: ['삼성전자', 'LG전자']
#
# === 뉴스 42 ===
# 제목: ‘중국 VBP 최대 수혜주’...오스템임플란트, 횡령 오명 벗고 날아갈까
# 출력된 종목: ['대신증권', '다올투자증권']
#
# === 뉴스 43 ===
# 제목: 이복현 “사모펀드, 기업 구조개선에  주도적 역할 해달라”
# 출력된 종목: ['스틱인베스트먼트']
#
# === 뉴스 44 ===
# 제목: KB증권 “원자재 해외선물 거래하고 1+1+1 혜택까지”
# 출력된 종목: []
#
# === 뉴스 45 ===
# 제목: 코로나 확산에도 이만한 종목 없다…초고수가 꽂힌 ‘리오프닝’
# 출력된 종목: ['한국항공우주', '미래에셋증권', '엔씨소프트', 'HD현대', 'SK하이닉스', 'LG생활건강', '호텔신라']
#
# === 뉴스 46 ===
# 제목: 미래에셋 ‘일본판 배당귀족ETF’ 출시한다
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 47 ===
# 제목: 오아시스 상장 추진에 상한가 ‘터치’…지어소프트, 자회사 덕 볼까
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 48 ===
# 제목: 한 달 사이 25% 떨어지더니…배터리주 모처럼 기지개
# 출력된 종목: ['한화투자증권', 'LG에너지솔루션', '삼성증권', '삼성SDI']
#
# === 뉴스 49 ===
# 제목: 에스티큐브, 美 JP모건 헬스케어 콘퍼런스서 빅팜과 전략적 논의 구체화
# 출력된 종목: []
#
# === 뉴스 50 ===
# 제목: 막 오른 4분기 어닝 시즌…이익 모멘텀 주목받는 종목은
# 출력된 종목: ['신영증권', 'HD현대', '대한항공', '한전KPS', '삼성생명', '삼성전자', '화승엔터프라이즈', '녹십자', '아시아나항공', '파라다이스']
#
# === 뉴스 51 ===
# 제목: 車배터리 핵심부품 집중 美공장 2년 후 양산 목표
# 출력된 종목: ['대신증권', 'LG에너지솔루션']
#
# === 뉴스 52 ===
# 제목: 막 여는 실적 시즌…4분기 영업 성과 보다 ‘이것’이 핵심
# 출력된 종목: ['LG전자', 'KT', '삼성전자', 'LG디스플레이', 'LG생활건강', '삼성전기', 'LG이노텍']
#
# === 뉴스 53 ===
# 제목: 미래반도체·오브젠 16~17일 공모 청약
# 출력된 종목: ['삼성전자']
#
# === 뉴스 54 ===
# 제목: 실적·배당 화끈...4대 금융지주 폭등
# 출력된 종목: ['대신증권', '교보증권', '하나금융지주', '우리금융지주', 'KB금융', '신한지주']
#
# === 뉴스 55 ===
# 제목: 한달만에 2400 찍은 코스피 … "추가 상승 1분기 실적에 달렸다"
# 출력된 종목: ['신영증권', 'NH투자증권', '미래에셋증권']
#
# === 뉴스 56 ===
# 제목: UAE 40조원 ‘통큰 투자’에 또 다시 들썩이는 중동 개발株
# 출력된 종목: ['한미글로벌', '금호건설', '태영건설', '우진아이엔에스']
#
# === 뉴스 57 ===
# 제목: ‘금리 인상 마무리?’… CD금리 급락
# 출력된 종목: ['한국전력', '현대차증권', '삼성증권', '신세계']
#
# === 뉴스 58 ===
# 제목: 구리값 상승에 … 풍산·LS 주가 강세
# 출력된 종목: ['LS', '풍산', '현대차증권']
#
# === 뉴스 59 ===
# 제목: KB증권, 학생복지스토어와 제휴 ‘그 시작을 응원해!’ 이벤트 실시
# 출력된 종목: []
#
# === 뉴스 60 ===
# 제목: “37조원 중동 잭팟 터진다” 윤 대통령 순방 특수 누린 수소株
# 출력된 종목: ['일진하이솔루스', '효성화학', '코오롱인더', '유진투자증권', '두산퓨얼셀']
#
# === 뉴스 61 ===
# 제목: 외국인 쏟아져 들어온다...킹달러 힘잃자 수혜주로 떠오른 종목
# 출력된 종목: ['현대모비스', '현대차', '엔씨소프트', '롯데케미칼']
#
# === 뉴스 62 ===
# 제목: 바이오니아, 인니 인디카 에너지와 진단사업 합작법인 설립
# 출력된 종목: []
#
# === 뉴스 63 ===
# 제목: 평행선 걷는 회개개혁...개선안 도출 ‘난항’
# 출력된 종목: []
#
# === 뉴스 64 ===
# 제목: “실적바닥 찍고 오를 일만 남아”…초고수들이 찍은 이유있었네
# 출력된 종목: ['한국항공우주', '미래에셋증권', '현대로템', '크래프톤', '한화생명']
#
# === 뉴스 65 ===
# 제목: 큐브엔터, 라잇썸 X 빅터웨인산토 웨어러블 NFT ‘메타러브’ 16일 출시
# 출력된 종목: []
#
# === 뉴스 66 ===
# 제목: “장기채 모으자”...삼성 美30년물 ETF, 순자산 1000억원 넘었다
# 출력된 종목: []
#
# === 뉴스 67 ===
# 제목: KB자산운용 중국 ETF, 중국 테마 수익률 1위
# 출력된 종목: []
#
# === 뉴스 68 ===
# 제목: “중국 투자 알려드립니다” 미래에셋자산운용, 보고서 출간
# 출력된 종목: []
#
# === 뉴스 69 ===
# 제목: 폴짝폴짝 ‘BTS’ 따르면 돈번다?…토끼랠리 맞춤 투자전략은
# 출력된 종목: ['삼성증권']
#
# === 뉴스 70 ===
# 제목: 고려제약, 사업 다각화·재무 건전성 앞세워 위기관리 능력 키운다
# 출력된 종목: []
#
# === 뉴스 71 ===
# 제목: 금리 떨어지는데 주가는 왜…공모가에서 30% 빠진 쏘카 주주 ‘속앓이’
# 출력된 종목: ['쏘카', 'NAVER', '카카오', '삼성증권', '수산인더스트리', '바이오노트', '케이카']
#
# === 뉴스 72 ===
# 제목: “언제적 집콕”…주가 20% 넘게 빠진 CJ제일제당, 목표주가 하향
# 출력된 종목: ['CJ제일제당', '키움증권']
#
# === 뉴스 73 ===
# 제목: 빅파마, 향후 M&A 속도 낸다...바이오 업계 폭풍전야
# 출력된 종목: ['삼성바이오로직스', 'SK바이오사이언스']
#
# === 뉴스 74 ===
# 제목: 공모주 청약 경쟁률 '극과 극'
# 출력된 종목: ['삼성전자']
#
# === 뉴스 75 ===
# 제목: 벌써 다 올랐나...카카오 그룹株 우수수
# 출력된 종목: ['카카오', '한화투자증권', '키움증권', '카카오뱅크', '카카오페이']
#
# === 뉴스 76 ===
# 제목: 유통물량 23% 풀린다…LG엔솔 '긴장'
# 출력된 종목: ['LG화학', 'LG에너지솔루션', 'LG']
#
# === 뉴스 77 ===
# 제목: 치열한 경영권 분쟁에 주가는 롤러코스터
# 출력된 종목: ['고려아연', '한진칼', '화천기계']
#
# === 뉴스 78 ===
# 제목: 우리금융, 2천억대에 다올인베스트먼트 인수
# 출력된 종목: ['다올투자증권', '우리금융지주']
#
# === 뉴스 79 ===
# 제목: 경영권 분쟁 나면 당연히 주가 오른다?...“이때 되면 조심”
# 출력된 종목: ['고려아연', '한진칼', '화천기계']
#
# === 뉴스 80 ===
# 제목: 실적 우려 부각에 … 카카오 그룹株 '우수수'
# 출력된 종목: ['카카오', '한화투자증권', '키움증권', '카카오뱅크', '카카오페이']
#
# === 뉴스 81 ===
# 제목: 전세계 CEO 73%가 내놓은 암울한 전망...“1년 내 글로벌 경제 하락”
# 출력된 종목: []
#
# === 뉴스 82 ===
# 제목: 큐브엔터 ‘(여자)아이들’, ‘TOMBOY’(톰보이) M/V 조회 수 2억 뷰 돌파
# 출력된 종목: []
#
# === 뉴스 83 ===
# 제목: 한국투자증권, 뱅키스 계좌 채권 잔고 1조원 돌파
# 출력된 종목: []
#
# === 뉴스 84 ===
# 제목: 이지스자산운용, 비브스튜디오스와 엔터산업 맞춤형 공간 개발
# 출력된 종목: []
#
# === 뉴스 85 ===
# 제목: “호텔신라, 올해는 면세점 성장이 고무적인 해”…목표가↑
# 출력된 종목: ['호텔신라', '유진투자증권']
#
# === 뉴스 86 ===
# 제목: 코오롱인더, 1분기 바닥으로 실적 개선 전망...목표가↓
# 출력된 종목: ['코오롱인더']
#
# === 뉴스 87 ===
# 제목: 메드팩토, 강세…“백토서팁, 골육종서 美FDA 패스트트랙 지정”
# 출력된 종목: []
#
# === 뉴스 88 ===
# 제목: “하이브, 뉴진스 흥행에…BTS 단체활동 부재 무색”
# 출력된 종목: ['하이브', 'NH투자증권']
#
# === 뉴스 89 ===
# 제목: “주가 상승 여력 적다”…증권사 분석에 카카오 2%↓
# 출력된 종목: ['키움증권', '카카오', '카카오뱅크', '카카오페이']
#
# === 뉴스 90 ===
# 제목: ‘재벌집 막내아들’ 제작사 래몽래인, 경영권 분쟁 소식에 15%대 강세
# 출력된 종목: []
#
# === 뉴스 91 ===
# 제목: 온라인 채널 강화로 매출액 증가 전망…한샘, 증권사 호평에 2%대 강세
# 출력된 종목: ['유안타증권', '한샘']
#
# === 뉴스 92 ===
# 제목: 메리츠증권, 매일 이자주는 ‘슈퍼 365 계좌’ SNS 이벤트 실시
# 출력된 종목: []
#
# === 뉴스 93 ===
# 제목: 세뱃돈 받으면 투자할 미국 주식...부모는 테슬라, 자녀는 애플
# 출력된 종목: ['삼성증권']
#
# === 뉴스 94 ===
# 제목: 예보, MG손보 공개매각 절차 시동
# 출력된 종목: []
#
# === 뉴스 95 ===
# 제목: 15년만에 수탁액 100배 미래에셋 인도서 통했다
# 출력된 종목: []
#
# === 뉴스 96 ===
# 제목: 日보복여행 폭증에 … 저가항공 고공비행
# 출력된 종목: ['티웨이항공', '대한항공', '제주항공', '진에어']
#
# === 뉴스 97 ===
# 제목: 韓PEF 소유 테일러메이드, 골프황제와 맞손
# 출력된 종목: []
#
# === 뉴스 98 ===
# 제목: 日보복여행 폭증에 … 저가항공 고공비행
# 출력된 종목: ['티웨이항공', '대한항공', '제주항공', '진에어']
#
# === 뉴스 99 ===
# 제목: 韓PEF 소유 테일러메이드, 골프황제와 맞손
# 출력된 종목: []
#
# === 뉴스 100 ===
# 제목: 차명투자 의혹 강방천 前회장, 직무정지 중징계 확정
# 출력된 종목: []
#
# === 뉴스 101 ===
# 제목: “국내증시에 환멸이”...동학개미, 이 종목 제일 많이 팔았다
# 출력된 종목: ['카카오', 'KB금융', 'SK하이닉스', '삼성전자', '하나금융지주', '신한지주']
#
# === 뉴스 102 ===
# 제목: “5천 넣으면 1억 꽂힌다”…‘투자자 울린’ 주식 리딩방, 과태료 추진
# 출력된 종목: []
#
# === 뉴스 103 ===
# 제목: 2개월만에 추천 투자전략 바꾼 삼성증권…“지금은 주식 사야할 때”
# 출력된 종목: ['카카오', '삼성증권', '맥쿼리인프라', '삼성전기', 'KB금융', '기아']
#
# === 뉴스 104 ===
# 제목: 토종 PEF 센트로이드가 품은 테일러메이드 , ‘골프황제’ 타이거 우즈도 찜한 美 골프레저社에 수백억 투자
# 출력된 종목: []
#
# === 뉴스 105 ===
# 제목: ‘패션+K팝’ 꿀조합에 베팅…주식 초고수가 찍은 이 종목
# 출력된 종목: ['미래에셋증권', '현대로템', 'NAVER', '카카오', '넷마블', '카카오뱅크', '한국화장품제조', '씨에스윈드', '한국전력']
#
# === 뉴스 106 ===
# 제목: “여성 CEO 기업 주가가 더 오른다”…ETF까지 나와
# 출력된 종목: []
#
# === 뉴스 107 ===
# 제목: 골드만삭스 ‘어닝쇼크’에 금융株 동반 약세
# 출력된 종목: ['제주은행', '카카오뱅크', '하나금융지주', '우리금융지주', 'KB금융', '신한지주']
#
# === 뉴스 108 ===
# 제목: “신작 쏟아진다”…엔씨소프트, 올해 실적 기대감에 강세
# 출력된 종목: ['신영증권', '엔씨소프트']
#
# === 뉴스 109 ===
# 제목: “코스맥스, 2분기 기점으로 中 매출 성장세”…목표가↑
# 출력된 종목: ['코스맥스', '키움증권']
#
# === 뉴스 110 ===
# 제목: 삼전·SK하이닉스 사도 될까...“반도체, 1분기 바닥” KB증권
# 출력된 종목: ['SK하이닉스', '삼성전자']
#
# === 뉴스 111 ===
# 제목: 中 증시 훈풍에…ETF 수익률도 ‘방긋’
# 출력된 종목: []
#
# === 뉴스 112 ===
# 제목: 곡물가 하락하면 뜬다더니… 대상·CJ제일제당 '먹구름' 왜
# 출력된 종목: ['CJ제일제당', '키움증권', '한화투자증권']
#
# === 뉴스 113 ===
# 제목: “절묘한 시기에 호재 뜨더니”...먹튀 의심받는 사례 손본다
# 출력된 종목: []
#
# === 뉴스 114 ===
# 제목: AI 반도체 스타트업 ‘퓨리오사AI’, 2000억 투자 유치 추진
# 출력된 종목: ['삼성전자']
#
# === 뉴스 115 ===
# 제목: 삼정KPMG “감사委 지휘 하 실무지원조직 10% 미만”
# 출력된 종목: []
#
# === 뉴스 116 ===
# 제목: "조단위 뭉칫돈 들어온다"… SK·롯데·다올 자금압박 벗어나
# 출력된 종목: ['LG화학', '효성화학', '신세계푸드', '다올투자증권', 'SK하이닉스', 'SK이노베이션', 'KT', 'LG유플러스', 'SK', '태영건설', '한국전력', 'OCI']
#
# === 뉴스 117 ===
# 제목: IMM, 슈퍼리치 돈모아 투자 나선다
# 출력된 종목: []
#
# === 뉴스 118 ===
# 제목: “GD가 돌아온다…와이지엔터, 확신 가져볼 시점” NH증권
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 119 ===
# 제목: [CXO라운지] "고품질 분리막 최고 자부…헝가리공장 내년 가동"
# 출력된 종목: ['삼성SDI']
#
# === 뉴스 120 ===
# 제목: 바이오니아, 전자동 대량 분자진단장비 2개 모델 식약처 인증
# 출력된 종목: []
#
# === 뉴스 121 ===
# 제목: 해외 문 열리더니 ‘이것’까지 겹호재…날아오른 항공株
# 출력된 종목: ['진에어', '티웨이항공', '제주항공', '유진투자증권', '에어부산']
#
# === 뉴스 122 ===
# 제목: 中큰손들 몰려온다...올 들어 18% 올라 테슬라 제친 LVMH
# 출력된 종목: []
#
# === 뉴스 123 ===
# 제목: 올해 상장 1호 한주라이트메탈, 코스닥 상장 첫날 ‘上’
# 출력된 종목: ['현대차']
#
# === 뉴스 124 ===
# 제목: 상금 1억원의 주인공은? 삼성증권, 실전투자대회 진행
# 출력된 종목: ['삼성증권']
#
# === 뉴스 125 ===
# 제목: 中서 철강주문 밀려드니…뜨거운 포스코·현대제철
# 출력된 종목: ['동국제강', '키움증권', '대신증권', '현대제철', '유진투자증권']
#
# === 뉴스 126 ===
# 제목: “현금보다 더 쏠쏠할 게다”…세배 받은 아버지가 건네준 것은
# 출력된 종목: ['미래에셋증권', '카카오', '엔씨소프트', 'NH투자증권', '삼성전자', 'SK', '한화솔루션', '삼성전기']
#
# === 뉴스 127 ===
# 제목: 부동산 발목 잡혔던 증권주, 드디어 날갯짓?…‘신중 또 신중’
# 출력된 종목: ['미래에셋증권', '삼성증권', 'SK증권', '한화투자증권', '유안타증권', '키움증권', 'NH투자증권', '한국금융지주', '유진투자증권']
#
# === 뉴스 128 ===
# 제목: "세뱃돈으로 삼성전자·카카오·애플 1주씩"
# 출력된 종목: ['미래에셋증권', '엔씨소프트', '카카오', 'NH투자증권', '삼성전자', '한화솔루션', '삼성전기']
#
# === 뉴스 129 ===
# 제목: 배당확대 훈풍 탄 은행주 … 반값에 '줍줍' 해볼까
# 출력된 종목: ['SK하이닉스', '삼성전자', '하나금융지주', '우리금융지주']
#
# === 뉴스 130 ===
# 제목: 오스템임플란드 압박하는 강성부…“사외이사나 감사 자리 달라”
# 출력된 종목: []
#
# === 뉴스 131 ===
# 제목: 에스엠, 얼라인파트너스 제안 전격 수용…주주가치 제고 협력
# 출력된 종목: []
#
# === 뉴스 132 ===
# 제목: 올해 상장 1호 한주라이트메탈, 코스닥 상장 이틀째도 급등
# 출력된 종목: []
#
# === 뉴스 133 ===
# 제목: 역대 최대 감원 나선 글로벌 빅테크...효과는 천차만별, 왜?
# 출력된 종목: ['NH투자증권', '카카오', '한화투자증권']
#
# === 뉴스 134 ===
# 제목: 증권가 목표가 줄줄이 올리자…현대건설, 4%대 강세
# 출력된 종목: ['한화투자증권', 'NH투자증권', '현대건설']
#
# === 뉴스 135 ===
# 제목: 군인공제회, 윤리경영 선포식 개최
# 출력된 종목: []
#
# === 뉴스 136 ===
# 제목: “SK바사, 코로나 외 신규 모멘텀 필요”...목표가↓
# 출력된 종목: ['삼성증권', 'SK바이오사이언스']
#
# === 뉴스 137 ===
# 제목: 신세계인터내셔날, 내수 소비 둔화 속 마케팅 투자 지속...목표가↓
# 출력된 종목: ['신세계인터내셔날', '현대차증권']
#
# === 뉴스 138 ===
# 제목: “대한항공, 코로나 이전 대비 견조한 실적 유지” 유진
# 출력된 종목: ['대한항공', '유진투자증권']
#
# === 뉴스 139 ===
# 제목: 삼성 비트코인ETF, 일주일 만 수익률 10%
# 출력된 종목: []
#
# === 뉴스 140 ===
# 제목: 1.4% 확률 뚫고 주가 10배 상승 … 고진감래株 찾아라
# 출력된 종목: ['엘앤에프', '카카오', 'LG전자', 'LG', '한샘', '호텔신라', 'SK텔레콤']
#
# === 뉴스 141 ===
# 제목: 공모주 시장 볕들까?…설 연휴 후 주목할 할 새내기는
# 출력된 종목: ['LG']
#
# === 뉴스 142 ===
# 제목: 네카오 주가 전망 두고 증권가도 ‘갈팡질팡’…누가 맞을까?
# 출력된 종목: ['다올투자증권', 'NAVER', '카카오']
#
# === 뉴스 143 ===
# 제목: 상장 철회한 마켓컬리…이틈에 ‘이커머스 1호’ 거머쥘 이 회사
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 144 ===
# 제목: 비상 걸린 LG엔솔 주가…3.6조 물량 풀린다
# 출력된 종목: ['LG화학', '신영증권', 'LG에너지솔루션', '유안타증권', '삼성전자']
#
# === 뉴스 145 ===
# 제목: 벌써 50조 시장…국적 상관없이 다 오르는 ‘대세’ 산업됐다 [박윤예의 글로벌주 열전]
# 출력된 종목: ['미래에셋증권', '삼성증권', 'LG전자', '삼성전자', 'LG']
#
# === 뉴스 146 ===
# 제목: “올해는 달라질까”…개미들 1월에 산 톱10 종목 수익률은
# 출력된 종목: ['한국항공우주', 'SK증권', 'NH투자증권', '삼성SDI', 'CJ제일제당', '삼성바이오로직스', 'LIG넥스원', '한국전력', 'SK텔레콤', '한국가스공사']
#
# === 뉴스 147 ===
# 제목: "오스템임플란트 지분 25% 살것" MBK·유니슨, 백기사로 나섰다
# 출력된 종목: ['삼성증권', 'SK']
#
# === 뉴스 148 ===
# 제목: "에스파 언니들과 톡 할래요" 디어유 시총 1조 돌파 코앞
# 출력된 종목: ['키움증권', '엔씨소프트']
#
# === 뉴스 149 ===
# 제목: "강달러 땐 좋았는데" 한세실업 목표가 뚝
# 출력된 종목: ['다올투자증권', '대신증권', 'NH투자증권', '한세실업', '영원무역']
#
# === 뉴스 150 ===
# 제목: "작년 4분기 '어닝 쇼크'보다 6개월후 실적이 관건"
# 출력된 종목: ['카카오', 'LG전자', 'SK하이닉스', 'LG에너지솔루션', '삼성전자', 'LG디스플레이', 'SK', '삼성전기', 'LG이노텍']
#
# === 뉴스 151 ===
# 제목: 실적 시즌 돌입...‘어닝 쇼크’에도 증시 낙관론 점점 커져
# 출력된 종목: ['카카오', 'SK바이오사이언스', 'LG전자', 'SK하이닉스', 'LG에너지솔루션', 'NH투자증권', '삼성전자', '삼성전기', 'LG이노텍']
#
# === 뉴스 152 ===
# 제목: 이러다 폭발할라 … 가스株 이상한 급등
# 출력된 종목: ['서울가스', 'SK증권', '대성홀딩스', '유진투자증권', '삼천리']
#
# === 뉴스 153 ===
# 제목: 개인투자자 “금리 3% 이하로 안정되면 주식 늘리겠다”
# 출력된 종목: ['삼성증권']
#
# === 뉴스 154 ===
# 제목: “강달러 시절 좋았는데”…영원무역·한세실업 목표가 줄 하향
# 출력된 종목: ['다올투자증권', '대신증권', 'NH투자증권', '한세실업', '영원무역']
#
# === 뉴스 155 ===
# 제목: “우리회사 주가 떨어질 것같아요”...‘이유 모를 상승’ 도시가스주
# 출력된 종목: ['서울가스', 'SK증권', '대성홀딩스', '유진투자증권', '삼천리']
#
# === 뉴스 156 ===
# 제목: “뜨는 사업은 다 한다”...EPS 상향률 1위 LS, 눈길
# 출력된 종목: ['LS', '애경산업', '키움증권', 'SNT모티브', '현대코퍼레이션']
#
# === 뉴스 157 ===
# 제목: 에스파 니쥬 트와이스 다 있다...올해 주가 37% 오른 디어유
# 출력된 종목: ['키움증권', '엔씨소프트', '삼성증권']
#
# === 뉴스 158 ===
# 제목: “라면 안 팔아요” “자전거 회사 아녜요”...회사 이름 헷갈리네
# 출력된 종목: ['동원산업', '동원수산', '삼양식품', '삼양사', '삼천리', '한국가스공사']
#
# === 뉴스 159 ===
# 제목: 30년 만에…외국인 투자등록제 폐지한다
# 출력된 종목: []
#
# === 뉴스 160 ===
# 제목: 오스템임플란트 주당 19만원 공개매수...주가 급등
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 161 ===
# 제목: '연금 거짓말' 끊은 日, 백년 뒤에도 떼일 걱정 없다
# 출력된 종목: []
#
# === 뉴스 162 ===
# 제목: 선거참패 불사한 日연금개혁 … 20년 지난 지금, 누구나 "옳았다"
# 출력된 종목: []
#
# === 뉴스 163 ===
# 제목: "선물·스타트업까지 투자 확대 … 100년 내다보고 운용"
# 출력된 종목: []
#
# === 뉴스 164 ===
# 제목: '공개매수 약발' 오스템임플란트 15% 급등
# 출력된 종목: []
#
# === 뉴스 165 ===
# 제목: 롯데케미칼 1.2兆 유증 성공
# 출력된 종목: ['롯데케미칼']
#
# === 뉴스 166 ===
# 제목: 중국 리오프닝 기대에 화장품·여행·호텔株 ‘훨훨’
# 출력된 종목: ['한국화장품', '삼성증권', '진에어', '하나투어', 'LG생활건강', '티웨이항공', '제주항공', '호텔신라', '한국콜마', '아모레퍼시픽', '에어부산']
#
# === 뉴스 167 ===
# 제목: “회계사 시장도 한파?” 합격 정원 증원에도 지원자 찔끔 늘어
# 출력된 종목: []
#
# === 뉴스 168 ===
# 제목: 설 연휴 끝나자 반도체 대장주 강세...삼전 2%↑, SK하이닉스 4%↑
# 출력된 종목: ['미래에셋증권', 'SK하이닉스', '삼성전자']
#
# === 뉴스 169 ===
# 제목: 작년 주식 발행액 전년비 24.6%감소…회사채 발행도 위축
# 출력된 종목: []
#
# === 뉴스 170 ===
# 제목: 與 당대표 가상 양자대결서 안철수 우세...안랩 21% 급등
# 출력된 종목: []
#
# === 뉴스 171 ===
# 제목: “19만원에 매입합니다”…오스템임플란트, 공개매수 소식에 급등
# 출력된 종목: []
#
# === 뉴스 172 ===
# 제목: 유니슨·MBK 공개매수 나선다…오스템임플란트 15% 급등
# 출력된 종목: []
#
# === 뉴스 173 ===
# 제목: “대한항공, 화물운임 하락에 실적 기대 못 미쳐”...목표가↓
# 출력된 종목: ['대한항공', '아시아나항공']
#
# === 뉴스 174 ===
# 제목: 에스엠, 이사회서 임시사추위 위원 3인 확정 및 주주환원정책 의결
# 출력된 종목: ['대한항공', '한솔홀딩스', '현대글로비스']
#
# === 뉴스 175 ===
# 제목: “이마트, 4분기 실적은 부진하나…규제 완화에 주목해야”
# 출력된 종목: ['이마트']
#
# === 뉴스 176 ===
# 제목: 미래에셋의 뚝심, 글로벌 위기에도 살아남은 유일한 외국계운용사
# 출력된 종목: []
#
# === 뉴스 177 ===
# 제목: [공모주 투자노트] "상장후 신선식품 새벽배송 전국으로 확대"
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 178 ===
# 제목: LB인베스트먼트, 증권신고서 제출…상장 절차 본격 돌입
# 출력된 종목: ['미래에셋증권', '하이브', 'LG전자']
#
# === 뉴스 179 ===
# 제목: 플랫폼파트너스 조직개편…마케팅 강화
# 출력된 종목: []
#
# === 뉴스 180 ===
# 제목: 북미·중동 뭉칫돈 몰린 PEF … 기업들 사업재편 주도
# 출력된 종목: ['스틱인베스트먼트']
#
# === 뉴스 181 ===
# 제목: 삼성SDS 작년 매출 17조 '역대 최대'
# 출력된 종목: []
#
# === 뉴스 182 ===
# 제목: 부동산 경착륙 경고에도 … 올들어 리츠 7% 깜짝 상승
# 출력된 종목: ['신한서부티엔디리츠', '삼성증권', '대신증권', '삼성전자', 'SK', 'SK리츠', 'KB스타리츠', '제이알글로벌리츠']
#
# === 뉴스 183 ===
# 제목: 또 다시 반도체株의 시대?...연일 강세에 바닥론 솔솔
# 출력된 종목: ['SK하이닉스', '삼성전자']
#
# === 뉴스 184 ===
# 제목: “LG이노텍, 영업익 부진하나 아이폰 교체 수요 발생”...목표가↓
# 출력된 종목: ['LG이노텍']
#
# === 뉴스 185 ===
# 제목: 마테크 전문기업 오브젠 “IPO 혹한기에 기술성장특례 상장 정면돌파”
# 출력된 종목: []
#
# === 뉴스 186 ===
# 제목: 삼성SDS 작년 매출 17조...역대 최대 실적
# 출력된 종목: []
#
# === 뉴스 187 ===
# 제목: “콘텐트리중앙, 4분기 부진하나 올해 턴어라운드”
# 출력된 종목: []
#
# === 뉴스 188 ===
# 제목: ‘동장군 급습’에 난방비 폭탄...이 종목은 웃었다
# 출력된 종목: ['경동도시가스', '인천도시가스', '대성에너지']
#
# === 뉴스 189 ===
# 제목: “카카오게임즈, 4분기 실적은 부진…신작 효과에 기대”
# 출력된 종목: []
#
# === 뉴스 190 ===
# 제목: 지난해 자산유동화증권 44조원 발행…전년 대비 28.7% 감소
# 출력된 종목: []
#
# === 뉴스 191 ===
# 제목: 테슬라 가격 인하 수혜 기대감에 엘앤에프 3%대 강세
# 출력된 종목: ['엘앤에프', '한화투자증권']
#
# === 뉴스 192 ===
# 제목: 물가 오르면 임대료도 오른다…올 7% 상승 리츠 주목
# 출력된 종목: ['신한서부티엔디리츠', '삼성증권', '대신증권', '삼성전자', 'SK', 'SK리츠', 'KB스타리츠', '제이알글로벌리츠']
#
# === 뉴스 193 ===
# 제목: 포스코 영업이익 반토막났지만...최악 지났다고 보는 까닭
# 출력된 종목: ['포스코인터내셔널']
#
# === 뉴스 194 ===
# 제목: 영업이익 반토막 포스코 "저점 지났다"
# 출력된 종목: ['포스코인터내셔널']
#
# === 뉴스 195 ===
# 제목: LG디스플레이 영업적자 2조
# 출력된 종목: ['LG전자', 'LG디스플레이']
#
# === 뉴스 196 ===
# 제목: 금융당국 한마디에...잘 나가던 금융지주株 급브레이크
# 출력된 종목: ['KB금융', '하나금융지주']
#
# === 뉴스 197 ===
# 제목: 바이오니아, 결핵·다제내성 결핵균 검사키트 식약처 수출허가 획득
# 출력된 종목: []
#
# === 뉴스 198 ===
# 제목: 김소영 금융위 부위원장 “ESG 공시제도 구체화해야”
# 출력된 종목: []
#
# === 뉴스 199 ===
# 제목: LG엔솔, 4조 규모 보호예수 해제 임박...투자자 ‘긴장’
# 출력된 종목: ['LG에너지솔루션', '유안타증권']
#
# === 뉴스 200 ===
# 제목: 매각 기대감 HMM, 9% 이상 급등
# 출력된 종목: ['HMM']
#
# === 뉴스 201 ===
# 제목: ‘작년 2조원대 손실’ LG디스플레이, 어닝 쇼크에 약세
# 출력된 종목: ['LG디스플레이']
#
# === 뉴스 202 ===
# 제목: 진에어, 가톨릭아동청소년재단과 업무 협약 체결
# 출력된 종목: ['진에어']
#
# === 뉴스 203 ===
# 제목: KB증권 “기다리는 조정 없어...‘8만전자’ 간다”
# 출력된 종목: ['삼성전자']
#
# === 뉴스 204 ===
# 제목: “카카오페이, 수급이 주가 상승 견인 중”…목표가↑
# 출력된 종목: ['카카오페이', '카카오']
#
# === 뉴스 205 ===
# 제목: 미래반도체, 코스닥 상장 첫날 ‘따상’ 성공...올해 처음
# 출력된 종목: ['삼성전자']
#
# === 뉴스 206 ===
# 제목: “신고가 찍었지만 갈길 멀다”…초고수가 찜한 은행주 ‘원픽’
# 출력된 종목: ['미래에셋증권', '제주은행', '현대로템', 'LG전자', '삼성전자', 'HMM']
#
# === 뉴스 207 ===
# 제목: ‘배터리 전쟁’ 안 뛰어든 나라 없다…배터리株 최후의 승자는 [박윤예의 글로벌주 열전]
# 출력된 종목: ['LG에너지솔루션']
#
# === 뉴스 208 ===
# 제목: 송중기부터 뉴진스까지…증권사 리포트에 등장하는 까닭은
# 출력된 종목: ['미래에셋증권', '삼성증권', '다올투자증권', '교보증권', '하이브', '삼성바이오로직스']
#
# === 뉴스 209 ===
# 제목: “개발만 잘하면 뭘 해?”…잡스를 살린 ‘팀 쿡 효과’ [오기자의 테크株 흥망사]
# 출력된 종목: []
#
# === 뉴스 210 ===
# 제목: 한섬·신세계인터 ‘찐내수주’, 경기침체 직격탄
# 출력된 종목: ['신세계인터내셔날', '현대홈쇼핑', '키움증권', '한섬', '현대차증권']
#
# === 뉴스 211 ===
# 제목: 한섬·신세계인터, 내수침체 직격탄
# 출력된 종목: ['신세계인터내셔날', '한섬', '신세계', '현대홈쇼핑']
#
# === 뉴스 212 ===
# 제목: 머니업/“주식·채권 늘리고 부동산은 관망” 엠플러스 머니업콘서트 성황
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 213 ===
# 제목: 자진상폐한다는 오스템임플란트, 투자자 수익 낼수도 있다는데
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 214 ===
# 제목: 회사채 발행 7년만에 최대...BBB급도 첫 도전
# 출력된 종목: ['LG화학', '효성화학', '한화투자증권', 'SK하이닉스', '키움증권', 'KT', '호텔신라', '롯데쇼핑', 'CJ대한통운', 'LG이노텍', '현대차증권']
#
# === 뉴스 215 ===
# 제목: 秋부총리, IB와 비공개 간담회
# 출력된 종목: []
#
# === 뉴스 216 ===
# 제목: 물동량 회복에…현대글로비스 영업익 60% 껑충
# 출력된 종목: ['NH투자증권', '현대글로비스']
#
# === 뉴스 217 ===
# 제목: GS건설 지난해 16조 수주 '사상최대'
# 출력된 종목: ['삼성중공업', 'GS', 'GS건설']
#
# === 뉴스 218 ===
# 제목: LG엔솔, 보호예수 해제에도 상승
# 출력된 종목: ['LG에너지솔루션']
#
# === 뉴스 219 ===
# 제목: [M&A 매물장터] 매출 300억 알루미늄 관련 제조사 매물로
# 출력된 종목: []
#
# === 뉴스 220 ===
# 제목: 현대글로비스 작년 영업익 59% 늘어난 1조 7985억
# 출력된 종목: ['NH투자증권', '현대글로비스']
#
# === 뉴스 221 ===
# 제목: GS건설, 한해 16조 수주 창사이래 최대...지난해 영업익 14.2% 감소
# 출력된 종목: ['GS건설']
#
# === 뉴스 222 ===
# 제목: 어닝 쇼크에도 주가는 웃는다...왜?
# 출력된 종목: ['미래에셋증권', '신영증권', '삼성증권', 'LG전자', 'LG에너지솔루션', '현대차', 'SNT모티브', '삼성전자', '현대건설', 'LX세미콘', '삼성바이오로직스', 'LG이노텍', '유진투자증권', '기아']
#
# === 뉴스 223 ===
# 제목: LG생활건강 목표가 90만원 ‘쑥’…황제주 노린다
# 출력된 종목: ['LG생활건강']
#
# === 뉴스 224 ===
# 제목: “유럽 향하는 투자자 관심”... 삼성중공업·LG이노텍 주목
# 출력된 종목: ['LG이노텍', '삼성중공업']
#
# === 뉴스 225 ===
# 제목: [단독] 몸값 4조 무신사 수천억대 투자 유치 추진
# 출력된 종목: []
#
# === 뉴스 226 ===
# 제목: 유안타증권 ‘해외주식 CFD’ 서비스 오픈
# 출력된 종목: ['유안타증권']
#
# === 뉴스 227 ===
# 제목: “더 간다” VS “곧 꼭지”…토끼랠리에 놀란 증권사도 와글와글
# 출력된 종목: ['대신증권', '한국전력', '삼성증권']
#
# === 뉴스 228 ===
# 제목: LCC株, 강세…해외여행 이연수요 폭발 ‘수혜’
# 출력된 종목: ['티웨이항공', '진에어', '제주항공', '에어부산']
#
# === 뉴스 229 ===
# 제목: 남궁견 회장 “휴마시스 인수로 신규사업 진출 … 진단키트 사업 매진”
# 출력된 종목: []
#
# === 뉴스 230 ===
# 제목: “호텔신라, 뻔하지만 강력한 리오프닝”…목표가 상향
# 출력된 종목: ['호텔신라']
#
# === 뉴스 231 ===
# 제목: ‘챗GPT 수혜 기대’ 이수페타시스, 급등…“현저한 저평가”
# 출력된 종목: ['유안타증권', '이수페타시스']
#
# === 뉴스 232 ===
# 제목: 증권가 눈높이 높였다…LG전자, 5개월만 ‘10만원’ 터치
# 출력된 종목: ['키움증권', 'LG전자']
#
# === 뉴스 233 ===
# 제목: 4조 물량 풀린 LG에너지솔루션, 장 초반 50만원선 붕괴
# 출력된 종목: ['LG에너지솔루션']
#
# === 뉴스 234 ===
# 제목: 마케팅 업체 오브젠, 코스닥 입성 첫날 ‘따상’ 성공
# 출력된 종목: []
#
# === 뉴스 235 ===
# 제목: VIG파트너스, 이스타항공 인수 거래 마무리
# 출력된 종목: ['아시아나항공', '에어부산']
#
# === 뉴스 236 ===
# 제목: LG엔솔, 그 날이 왔다…792만주 보호예수 해제에 주가 약세
# 출력된 종목: ['LG에너지솔루션']
#
# === 뉴스 237 ===
# 제목: 1700조 굴리는 美 ‘인싸’ 회장님의 공격본능 그녀의 게임은 이제 막 시작됐다
# 출력된 종목: []
#
# === 뉴스 238 ===
# 제목: KB통중국 펀드, 4차산업 펀드 중 수익률 1위
# 출력된 종목: []
#
# === 뉴스 239 ===
# 제목: 삼전도 투자한 로봇 테마...ETF 수익률1위
# 출력된 종목: ['LG이노텍', '두산', '삼성전자', 'LG전자']
#
# === 뉴스 240 ===
# 제목: “이수페타시스, 챗GPT 찐수혜…현저한 저평가”
# 출력된 종목: ['유안타증권', '이수페타시스']
#
# === 뉴스 241 ===
# 제목: 행정공제회, 창립 48주년 기념...윤리경영 선포식 개최
# 출력된 종목: []
#
# === 뉴스 242 ===
# 제목: 미국처럼 주주보다 배당금 먼저 정한다...금융당국 “배당제도 개편”
# 출력된 종목: []
#
# === 뉴스 243 ===
# 제목: 거래재개 후 폭등하더니…개미지옥된 신라젠·코오롱티슈진
# 출력된 종목: []
#
# === 뉴스 244 ===
# 제목: 이복현 금감원장 “유동성 문제 증권사, 성과급·배당에 신중해야”
# 출력된 종목: []
#
# === 뉴스 245 ===
# 제목: 제일기획 영업익 25% 급증...“올해도 전망 좋다”
# 출력된 종목: ['키움증권', '제일기획']
#
# === 뉴스 246 ===
# 제목: '챗GPT' 덕 본 엔비디아 … 올해 주가 34% 폭풍 질주 [월가월부]
# 출력된 종목: []
#
# === 뉴스 247 ===
# 제목: 타다-아이엠택시 합병 추진
# 출력된 종목: ['쏘카']
#
# === 뉴스 248 ===
# 제목: 초코파이 이젠 베트남 러시아서도 잘 팔린다…오리온 주가 탄력
# 출력된 종목: ['오리온']
#
# === 뉴스 249 ===
# 제목: [공모주 인사이드] 나노팀 "獨 장악한 전기차 방열소재 국산화"
# 출력된 종목: ['LG화학', '현대차', '삼성전자']
#
# === 뉴스 250 ===
# 제목: 블루코브운용, 남산 하얏트 호텔 품는다
# 출력된 종목: ['IHQ', '제이에스코퍼레이션']
#
# === 뉴스 251 ===
# 제목: “바닥탈출 보인다”…‘목표가 상향’ 가장 많이 쏟아진 이 기업은
# 출력된 종목: ['삼성증권', 'LG전자', 'NH투자증권', '롯데케미칼', '호텔신라', '삼성전기', '셀트리온', '코스맥스', '한미약품', '아모레퍼시픽']
#
# === 뉴스 252 ===
# 제목: 美서 1년에 라면 8억5천만개 만든다...신라면 덕에  농심 주가 ‘쑥’
# 출력된 종목: ['NH투자증권', '농심', 'SK증권']
#
# === 뉴스 253 ===
# 제목: 게임주 투자하려면...알아야 할 10대 트렌드
# 출력된 종목: ['넷마블']
#
# === 뉴스 254 ===
# 제목: 현대글로비스, 배당 대폭 늘린다…중장기 배당정책 발표
# 출력된 종목: ['현대글로비스']
#
# === 뉴스 255 ===
# 제목: ‘어닝쇼크’ 맞은 삼성전자 주가 약세…감산카드 꺼낼까
# 출력된 종목: ['현대차증권', '삼성전자']
#
# === 뉴스 256 ===
# 제목: “삼양라면 짜짜로니 아니었네”…삼양식품 주가 쥐락펴락하는 매운맛
# 출력된 종목: ['삼양식품']
#
# === 뉴스 257 ===
# 제목: “티웨이항공, 수요 회복 기대 이미 충분히 반영”...목표가 ↓
# 출력된 종목: ['티웨이항공', 'NH투자증권']
#
# === 뉴스 258 ===
# 제목: 해외 수주에 삼성엔지니어링 4분기 ‘어닝 서프라이즈’
# 출력된 종목: []
#
# === 뉴스 259 ===
# 제목: “현대로템, K2 전차 노르웨이 수출 더 가까워져”…목표가 상향
# 출력된 종목: ['현대로템', 'NH투자증권']
#
# === 뉴스 260 ===
# 제목: “국민연금과 차원이 다르다”...세계 최고의 공격수 싱가포르 테마섹
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 261 ===
# 제목: “포스코케미칼, 중장기 이익 기대감...IRA 명확한 수혜주”
# 출력된 종목: ['LG에너지솔루션', '삼성SDI']
#
# === 뉴스 262 ===
# 제목: 큐브엔터, 멀티체인 미들웨어 플랫폼 바이프로스트와 업무협약 체결
# 출력된 종목: []
#
# === 뉴스 263 ===
# 제목: 엘브이엠씨홀딩스, 카카오모빌리티와 스마트 모빌리티 사업 가속화
# 출력된 종목: ['엘브이엠씨홀딩스']
#
# === 뉴스 264 ===
# 제목: “세계 경제 성장세 약화...역풍장범(逆風張帆) 자세로 극복”
# 출력된 종목: []
#
# === 뉴스 265 ===
# 제목: 3월 기대되는 종목 현대오토레버 OCI...이유는
# 출력된 종목: ['한진칼', 'OCI', '현대오토에버', '이마트']
#
# === 뉴스 266 ===
# 제목: KB증권, 해외주식 CFD 거래 서비스 오픈 기념 ‘특가수수료’ 이벤트
# 출력된 종목: []
#
# === 뉴스 267 ===
# 제목: 삼성중공업, 적자 끝…흑자 전환 기대감에 8%대 강세
# 출력된 종목: ['교보증권', '삼성중공업']
#
# === 뉴스 268 ===
# 제목: 하이브, AI 오디오 기업 수퍼톤 인수
# 출력된 종목: ['하이브']
#
# === 뉴스 269 ===
# 제목: [단독]버버리 핸드백 만드는 JS코퍼, 남산 하얏트호텔 품는다
# 출력된 종목: ['IHQ', '제이에스코퍼레이션']
#
# === 뉴스 270 ===
# 제목: SM라이프디자인, “올해 신사업 추가…실적개선세 지속 전망”
# 출력된 종목: []
#
# === 뉴스 271 ===
# 제목: 작년 사상 최대 실적 에쓰오일 “올해도 문제없다”
# 출력된 종목: []
#
# === 뉴스 272 ===
# 제목: AB자산운용 “우량 성장주 10년래 가장 싸다...실적 잘 따져봐야”
# 출력된 종목: []
#
# === 뉴스 273 ===
# 제목: “양극재 올해 기대된다” 에코프로비엠 포스코케미칼 강세
# 출력된 종목: ['LG화학', '유안타증권', '삼성SDI', '코스모화학', '현대차증권']
#
# === 뉴스 274 ===
# 제목: F＆F, 작년 영업익 5224억원...전년비 61.9% 증가
# 출력된 종목: []
#
# === 뉴스 275 ===
# 제목: 사상최대 실적 에쓰오일…"올해 정제마진도 강세"
# 출력된 종목: ['아모레퍼시픽']
#
# === 뉴스 276 ===
# 제목: 쭉쭉 오른다는데…여전히 투자자 골머리라는 이 종목은
# 출력된 종목: ['하이브']
#
# === 뉴스 277 ===
# 제목: 싸늘한 IPO시장 … 급등장서도 공모주펀드 수익률 2% 불과
# 출력된 종목: ['신영증권', 'LG에너지솔루션', '카카오뱅크', '카카오페이']
#
# === 뉴스 278 ===
# 제목: 삼성운용 아시아 반도체 ETF
# 출력된 종목: []
#
# === 뉴스 279 ===
# 제목: 올해도 대어·따상 없다...IPO 침체에 공모주 펀드서 발돌리는 투자자
# 출력된 종목: ['신영증권', 'LG에너지솔루션', '카카오뱅크', '카카오페이']
#
# === 뉴스 280 ===
# 제목: 아모레퍼시픽, 작년 영업익 2142억…전년 대비 37.6% 감소
# 출력된 종목: ['아모레퍼시픽']
#
# === 뉴스 281 ===
# 제목: 금감원, 투자자문사들 제재...‘대주주 신용공여 위반’
# 출력된 종목: []
#
# === 뉴스 282 ===
# 제목: "배터리 핵심은 양극재"… 에코프로비엠 9% 급등
# 출력된 종목: ['LG화학', '엘앤에프', '유안타증권', '삼성SDI', '코스모화학', '현대차증권']
#
# === 뉴스 283 ===
# 제목: “공사할수록 돈을 쓸어담는다”...매출 20% 껑충 뛴 캐터필러
# 출력된 종목: []
#
# === 뉴스 284 ===
# 제목: 러시아 문 닫아도, 물가 아무리 치솟아도...먹을수밖에 없는 맥도날드 호실적
# 출력된 종목: []
#
# === 뉴스 285 ===
# 제목: 오늘부터 서울 택시 기본요금 4800원…지하철·버스도 곧 인상
# 출력된 종목: []
#
# === 뉴스 286 ===
# 제목: “한국전력, 올해 적자폭은 10조원…장기적으로 접근해야”
# 출력된 종목: ['신영증권', '한국전력']
#
# === 뉴스 287 ===
# 제목: [속보] SK하이닉스 작년 4분기 영업손실 1조7천억 ‘적자전환’
# 출력된 종목: ['SK하이닉스']
#
# === 뉴스 288 ===
# 제목: LG생활건강, 18년만 역성장에 7%대 약세
# 출력된 종목: ['LG생활건강']
#
# === 뉴스 289 ===
# 제목: “LG전자, 유럽 경기회복 최대 수혜주”
# 출력된 종목: ['LG전자']
#
# === 뉴스 290 ===
# 제목: 한국·대만·일본 반도체 집중 투자하는 ETF 출시
# 출력된 종목: []
#
# === 뉴스 291 ===
# 제목: “올해 20% 올랐지만 더 간다”…초고수 상승랠리 이종목 더 담았다
# 출력된 종목: ['미래에셋증권', '삼성전자', 'LG생활건강', '호텔신라', '효성티앤씨']
#
# === 뉴스 292 ===
# 제목: 750억 자사주 매입 소식에…셀트리온 삼형제 나란히 강세
# 출력된 종목: ['셀트리온']
#
# === 뉴스 293 ===
# 제목: 신성씨에스, ‘프로지캐드’ 플라인소프트와 제조기업 디지털전환 MOU
# 출력된 종목: ['신성이엔지']
#
# === 뉴스 294 ===
# 제목: 미래에셋 채권형 2종 ETF 신규 상장 이벤트
# 출력된 종목: []
#
# === 뉴스 295 ===
# 제목: 18년간 매출 증가했던 괴력의 회사...성장 멈추자 주가 된서리
# 출력된 종목: ['LG생활건강']
#
# === 뉴스 296 ===
# 제목: [단독]BGF그룹, KNW 인수 우협 선정···반도체 특수가스 시장 진출 잰걸음
# 출력된 종목: ['BGF']
#
# === 뉴스 297 ===
# 제목: “1월에만 연간 목표치 24% 채웠다” 한국조선해양 주가 빛보나
# 출력된 종목: ['신영증권']
#
# === 뉴스 298 ===
# 제목: KB증권 마이데이터가 N페이(네이버페이) 쏩니다!
# 출력된 종목: []
#
# === 뉴스 299 ===
# 제목: 대우조선해양, 고부가 LNG선 수주 집중...한화 시너지 기대감에 주가 급등
# 출력된 종목: []
#
# === 뉴스 300 ===
# 제목: [IB명가에 듣는다] "오스템임플란트 M&A 등 빅딜로 역량 입증"
# 출력된 종목: ['한화솔루션', '메리츠금융지주', 'NH투자증권']
#
# === 뉴스 301 ===
# 제목: 8년만의 흑자전환 기대감에 삼성중공업 상승세
# 출력된 종목: ['신영증권', '삼성중공업', '삼성증권']
#
# === 뉴스 302 ===
# 제목: 공격적 자산 배분 캘퍼스 … 年평균 7.7% '달콤한 노후' 선물
# 출력된 종목: []
#
# === 뉴스 303 ===
# 제목: 고부가 선박 수주 싹쓸이…조선주 쾌속질주
# 출력된 종목: ['삼성중공업']
#
# === 뉴스 304 ===
# 제목: 1월 한 달 외인 웃고…이 종목에 개미도 모처럼 ‘함박웃음’
# 출력된 종목: ['한국항공우주', '현대로템', 'SK하이닉스', 'NH투자증권', '삼성전자', '하나금융지주', 'CJ제일제당', '삼성바이오로직스', 'LIG넥스원', '신한지주', '한국전력', 'SK텔레콤']
#
# === 뉴스 305 ===
# 제목: 화장품 전문기업 뷰티스킨 상장예비심사 청구
# 출력된 종목: []
#
# === 뉴스 306 ===
# 제목: 에스티큐브, 넬마스토바트 글로벌 임상 1상 성공…“면역항암제 도전장”
# 출력된 종목: []
#
# === 뉴스 307 ===
# 제목: 증시불황 뚫은 메리츠증권 사상 첫 '영업익 1조 클럽'
# 출력된 종목: []
#
# === 뉴스 308 ===
# 제목: 삼성전자·하이닉스 볕들날 오나...금리인상 막바지 기대감에
# 출력된 종목: ['SK하이닉스', '삼성전자']
#
# === 뉴스 309 ===
# 제목: 흥국화재, 당기순이익 1465억 사상 최대 실적…전년比 136.2%↑
# 출력된 종목: ['흥국화재']
#
# === 뉴스 310 ===
# 제목: “아모레퍼시픽, 2분기부터 본격적인 실적 회복세”
# 출력된 종목: ['키움증권', '아모레퍼시픽']
#
# === 뉴스 311 ===
# 제목: “LS ELECTRIC, IRA·리쇼어링·스마트팩토리 투자 수혜”
# 출력된 종목: ['키움증권']
#
# === 뉴스 312 ===
# 제목: 바이오니아 탈모방지 기능성 화장품, 英 화장품 인증 포털 SCPN 등록 완료
# 출력된 종목: []
#
# === 뉴스 313 ===
# 제목: “49조원 어치 주식 사들이겠다”…저커버그 깜짝 발표에19% 폭등
# 출력된 종목: ['LG에너지솔루션', '삼성바이오로직스', 'SK하이닉스', '삼성전자']
#
# === 뉴스 314 ===
# 제목: “SK하이닉스, 3분기부터 실적 개선…주가는 바닥 통과”
# 출력된 종목: ['SK하이닉스']
#
# === 뉴스 315 ===
# 제목: 갤럭시아머니트리, 카르도와 STO 플랫폼 구축…신사업 본격 가동
# 출력된 종목: []
#
# === 뉴스 316 ===
# 제목: “美베이비스텝 최고 수혜주는”…주식 초고수 매수 몰린 이 종목
# 출력된 종목: ['미래에셋증권', '현대로템', 'SK증권']
#
# === 뉴스 317 ===
# 제목: 올 실적 개선 기대감...아모레 퍼시픽 주가 껑충
# 출력된 종목: ['키움증권', '아모레퍼시픽']
#
# === 뉴스 318 ===
# 제목: “우리도 영업익 1조클럽”…메리츠증권, 증시 불황에도 작년 첫 가입
# 출력된 종목: []
#
# === 뉴스 319 ===
# 제목: “금리상승세 한풀 꺾이나”…네이버·카카오 동반 강세
# 출력된 종목: ['카카오', 'NAVER']
#
# === 뉴스 320 ===
# 제목: KB증권, ‘부메랑 리워드 시즌1 이벤트’ 실시
# 출력된 종목: []
#
# === 뉴스 321 ===
# 제목: MBK파트너스 日 노인요양업체 3700억원에 인수
# 출력된 종목: []
#
# === 뉴스 322 ===
# 제목: “나도 공모주 청약해볼까”...새내기주 강세에 IPO시장 술렁
# 출력된 종목: ['LG에너지솔루션']
#
# === 뉴스 323 ===
# 제목: SM, 멀티 제작센터·레이블 체계 도입 통해 SM 3.0시대 열어나갈 것
# 출력된 종목: []
#
# === 뉴스 324 ===
# 제목: 작년 하락장서도 30% 오르더니…올 들어 힘 못쓰는 릴리·머크
# 출력된 종목: []
#
# === 뉴스 325 ===
# 제목: MBK파트너스, 日 노인의료 서비스 기업 3700억에 인수
# 출력된 종목: []
#
# === 뉴스 326 ===
# 제목: 이래서 전기료 올릴 수 있겠나…‘난방비 폭탄’에 한전 주가도 11%↓
# 출력된 종목: ['한국전력']
#
# === 뉴스 327 ===
# 제목: “매장 또 문 닫는다”...스타벅스에 무슨 일이?
# 출력된 종목: []
#
# === 뉴스 328 ===
# 제목: 한국타이어, 역대 최대 실적에 7%대 강세
# 출력된 종목: ['한국타이어앤테크놀로지']
#
# === 뉴스 329 ===
# 제목: 삼기이브이, 상장 첫날 ‘따상’… LG엔솔 고객사 보유
# 출력된 종목: ['LG에너지솔루션', '삼성SDI']
#
# === 뉴스 330 ===
# 제목: “CJ CGV, 중국 박스오피스 사업 회복 전환”…목표가 상향
# 출력된 종목: ['삼성증권']
#
# === 뉴스 331 ===
# 제목: 삼성전자, ‘8만전자’ 되나...증권가 “반도체 상승사이클 진입”
# 출력된 종목: ['대신증권', '삼성전자']
#
# === 뉴스 332 ===
# 제목: “에어부산, 여행 수요 랠리…실적 턴어라운드”
# 출력된 종목: ['에어부산']
#
# === 뉴스 333 ===
# 제목: 대한제강, 6일 온라인 주주간담회...지주사 전환 등 설명
# 출력된 종목: ['대한제강']
#
# === 뉴스 334 ===
# 제목: 푸틴은 울고 투자자는 웃고…올해 150% 수익난 종목은
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 335 ===
# 제목: 테슬라 가격 인하 약발 통했다···1월 中판매량 18%↑
# 출력된 종목: []
#
# === 뉴스 336 ===
# 제목: 아마존 ‘엎친 데 덮친격’ 주가 8%↓···실적쇼크에 반독점 소송 우려까지
# 출력된 종목: []
#
# === 뉴스 337 ===
# 제목: 테슬라 52% 뛸때 테슬라ETF 수익률은 18% 왜?
# 출력된 종목: ['삼성전자']
#
# === 뉴스 338 ===
# 제목: 미술품 부동산 음원.....이르면 내년 조각투자 허용
# 출력된 종목: []
#
# === 뉴스 339 ===
# 제목: 실적 악화에도 … 韓美 성장주 동반강세
# 출력된 종목: ['NH투자증권', '카카오', '삼성증권']
#
# === 뉴스 340 ===
# 제목: “직원들 의리있네”...오버행 이슈 벗어난 LG엔솔, 주가 날개달까
# 출력된 종목: ['LG에너지솔루션', '교보증권']
#
# === 뉴스 341 ===
# 제목: 볕 드는 이 종목…ETE도 한 달새 무려 26% ‘껑충’
# 출력된 종목: ['LG에너지솔루션', '교보증권', '현대차', '삼성SDI', '기아']
#
# === 뉴스 342 ===
# 제목: 시진핑 한마디에 울고 웃는다...올 40% 뛴 엔비디아 [박윤예의 글로벌주 열전]
# 출력된 종목: ['삼성전자']
#
# === 뉴스 343 ===
# 제목: 동원산업, 한국맥도날드 품나
# 출력된 종목: ['동원산업']
#
# === 뉴스 344 ===
# 제목: 영업익 급증 롯데칠성 '함박웃음'
# 출력된 종목: ['롯데칠성']
#
# === 뉴스 345 ===
# 제목: 애플에 죽고 애플에 산다…애플페이 올라탈 종목은
# 출력된 종목: ['삼성증권', 'LG전자', 'LG에너지솔루션', '삼성전자', 'LG디스플레이', 'LG', 'LG이노텍']
#
# === 뉴스 346 ===
# 제목: 슈퍼리치 "비상장주식·사모투자도 유용한 투자 수단"
# 출력된 종목: ['삼성증권']
#
# === 뉴스 347 ===
# 제목: 100억 슈퍼리치는 '60대 사업가'
# 출력된 종목: ['삼성증권']
#
# === 뉴스 348 ===
# 제목: 원자재 채굴용 기계 수요 늘어 현대건설기계 영업익 1706억
# 출력된 종목: ['HD현대']
#
# === 뉴스 349 ===
# 제목: 출범 2년 덩치 키운 LX그룹 …"물류·반도체 실적 개선 기대"
# 출력된 종목: ['LX홀딩스', '삼성증권', '유안타증권', '현대차', 'LX하우시스', 'LX세미콘', 'LX인터내셔널', '기아']
#
# === 뉴스 350 ===
# 제목: 석유화학 업황 악화 직격탄 SKC 작년 영업익 45% 급감
# 출력된 종목: ['SKC', 'SK아이이테크놀로지']
#
# === 뉴스 351 ===
# 제목: 증시 '애생애사'… 이번엔 전자결제株
# 출력된 종목: ['삼성증권', 'LG전자', 'LG에너지솔루션', 'LG디스플레이', 'LG', 'LG이노텍', 'NICE']
#
# === 뉴스 352 ===
# 제목: [M&A매물장터] 인테리어 등 건축 관련 中企 매물로
# 출력된 종목: []
#
# === 뉴스 353 ===
# 제목: 연이은 ‘따상’ IPO 한파에도 소형주 웃었다
# 출력된 종목: ['유진투자증권']
#
# === 뉴스 354 ===
# 제목: KB증권 ‘해외 상장 ETF/ETN 거래고객 리워드’ 이벤트 실시
# 출력된 종목: []
#
# === 뉴스 355 ===
# 제목: 삼정KPMG “넷제로 이행, 천연가스·원자력 적극 활용해야”
# 출력된 종목: []
#
# === 뉴스 356 ===
# 제목: 바이오니아 ‘코스메르나 드림팀’ 무역센터에 띄운다
# 출력된 종목: []
#
# === 뉴스 357 ===
# 제목: “높은 금리 덕본다”…만기매칭형 채권 ETF에 뭉칫돈
# 출력된 종목: ['삼성증권']
#
# === 뉴스 358 ===
# 제목: 비트나인, 글로벌 R&D 센터 확장...“글로벌 사업 확대로 연결”
# 출력된 종목: []
#
# === 뉴스 359 ===
# 제목: 우리사주 물량 폭탄 이겨내니…LG엔솔 공매도도 ‘주춤’
# 출력된 종목: ['LG화학', 'LG에너지솔루션', 'SK하이닉스', '삼성전자', '카카오뱅크', 'LG생활건강']
#
# === 뉴스 360 ===
# 제목: “서치GPT 기대…네이버 목표가 13% 상향”
# 출력된 종목: ['NAVER']
#
# === 뉴스 361 ===
# 제목: “주가 지지부진하네, 팔자”...23만 동학개미 삼성전자 떠났다
# 출력된 종목: ['LG화학', 'LG에너지솔루션', '삼성바이오로직스', '삼성전자']
#
# === 뉴스 362 ===
# 제목: “우리도 이제 나서볼까” 회사채 시장 노크하는 건설사
# 출력된 종목: ['롯데케미칼', '한국토지신탁', '삼성증권']
#
# === 뉴스 363 ===
# 제목: “우리가 숨겨진 원자재 관련주” 현대건설기계 작년 실적 쑥
# 출력된 종목: []
#
# === 뉴스 364 ===
# 제목: “잘 팔리는 음료에 주가도 활짝”...제로 탄산음료 덕에 롯데칠성 쑥
# 출력된 종목: ['롯데칠성']
#
# === 뉴스 365 ===
# 제목: 한달새 60% 오르더니 그새 35% 빠졌다…래몽래인 “남은 카드는 이영애”
# 출력된 종목: []
#
# === 뉴스 366 ===
# 제목: KB금융, 작년 순이익 4조4133억...역대 최대
# 출력된 종목: ['KB금융']
#
# === 뉴스 367 ===
# 제목: [단독] 골드만삭스, 6.5조원 ‘제1호 그로스펀드’ 결성…韓투자 기대
# 출력된 종목: []
#
# === 뉴스 368 ===
# 제목: 글로벌 태양광 수혜 … OCI 영업이익 9806억
# 출력된 종목: ['OCI']
#
# === 뉴스 369 ===
# 제목: 롯데정밀화학 영업익 67% 늘어
# 출력된 종목: ['롯데정밀화학']
#
# === 뉴스 370 ===
# 제목: 카카오, SM 2대주주로 이수만 "위법행위" 반발
# 출력된 종목: ['카카오']
#
# === 뉴스 371 ===
# 제목: 3대 핵심사업 모두 '선방'… HD현대, 올해도 실적순항 모드
# 출력된 종목: ['HD현대']
#
# === 뉴스 372 ===
# 제목: GS리테일, 영업익 180% 늘어난 853억
# 출력된 종목: ['GS리테일', '한섬', '이노션']
#
# === 뉴스 373 ===
# 제목: GS리테일 지난해 영업익 11.7% 증가
# 출력된 종목: ['GS리테일', '한섬', '이노션']
#
# === 뉴스 374 ===
# 제목: 삼정KPMG-보난자그룹, 자금세탁방지·이상거래탐지 고도화 MOU
# 출력된 종목: ['카카오뱅크']
#
# === 뉴스 375 ===
# 제목: 판매가 상승 덕에...롯데정밀화학 작년 영업익 67% 증가
# 출력된 종목: ['롯데정밀화학']
#
# === 뉴스 376 ===
# 제목: 갤럭시S23 나온 거 맞나…낮아진 기대치에 잠잠한 부품주들
# 출력된 종목: ['비에이치', '삼성전기', '삼성전자', '엠씨넥스']
#
# === 뉴스 377 ===
# 제목: 전 세계 23조 시장...STO 놓고 증권업계 선점 ‘잰걸음’
# 출력된 종목: ['미래에셋증권', 'SK증권', '대신증권', '교보증권', 'NH투자증권']
#
# === 뉴스 378 ===
# 제목: 여전히 저평가된 주가…증권사들, LG그룹주 목표가↑
# 출력된 종목: ['LG화학', '삼성증권', 'LG전자', 'LG에너지솔루션', 'LG', 'LG생활건강']
#
# === 뉴스 379 ===
# 제목: “불확실성 시대의 자산운용업, 성장 견인을 위한 선순환 구조 강화해야”
# 출력된 종목: []
#
# === 뉴스 380 ===
# 제목: IPO 시장 살아나나…스튜디오미르, 올해 세번째 ‘따상’ 성공
# 출력된 종목: ['유진투자증권']
#
# === 뉴스 381 ===
# 제목: 현대건설기계, 4분기 어닝쇼크에 약세...4%대↓
# 출력된 종목: ['HD현대', '현대건설']
#
# === 뉴스 382 ===
# 제목: ‘지배구조 싹 고쳤다’ 에스엠, 3%대 강세
# 출력된 종목: ['삼성증권', 'SK증권']
#
# === 뉴스 383 ===
# 제목: 오아시스, IPO 한파 녹일까...8일까지 공모
# 출력된 종목: []
#
# === 뉴스 384 ===
# 제목: 트러스톤운용 “태광산업 이사회 구성은 위법”
# 출력된 종목: ['태광산업']
#
# === 뉴스 385 ===
# 제목: 오딘 우마무스메 잘 나가네....카카오게임즈 사상 최대 매출 영업이익
# 출력된 종목: []
#
# === 뉴스 386 ===
# 제목: 작년에 4곳이었는데 올해 벌써 3곳 ‘따상’…IPO 열풍 살아나나
# 출력된 종목: ['LG에너지솔루션', '유진투자증권']
#
# === 뉴스 387 ===
# 제목: 금호석화 작년 영업이익 52% 뚝...“올 고부가 제품 주력”
# 출력된 종목: ['금호석유화학']
#
# === 뉴스 388 ===
# 제목: “중국서 잘 나간다는데”…휠라홀딩스 펄펄 F&F는 시들, 왜?
# 출력된 종목: []
#
# === 뉴스 389 ===
# 제목: 두산퓨얼셀 영업익 59% 감소...수주 물량은 급증
# 출력된 종목: ['두산퓨얼셀']
#
# === 뉴스 390 ===
# 제목: [MK시그널] '생큐 블랙핑크' YG플러스 강세
# 출력된 종목: ['삼성전자', '우리금융지주']
#
# === 뉴스 391 ===
# 제목: 오딘 잘나가네…카카오게임즈 영업익 59% 급증
# 출력된 종목: ['엔씨소프트', '크래프톤', '다올투자증권']
#
# === 뉴스 392 ===
# 제목: 서학개미 24시간 내내 미국주식 살수 있다
# 출력된 종목: ['미래에셋증권', '키움증권', 'NH투자증권', '삼성증권']
#
# === 뉴스 393 ===
# 제목: 국민고통 눈감고 이자 장사 … 4대금융지주 순익 16조
# 출력된 종목: ['KB금융', '카카오뱅크']
#
# === 뉴스 394 ===
# 제목: “게임체인저 등장?”...챗GPT 등장에 이 종목 250% 폭등했다
# 출력된 종목: ['미래에셋증권', '삼성증권']
#
# === 뉴스 395 ===
# 제목: 서학개미 더 바빠지겠네...24시간 거래 가능해진다
# 출력된 종목: ['미래에셋증권', '키움증권', 'NH투자증권', '삼성증권']
#
# === 뉴스 396 ===
# 제목: 카카오와 ‘경영권 분쟁’ 시작된 에스엠...9%대 강세
# 출력된 종목: ['카카오', '다올투자증권']
#
# === 뉴스 397 ===
# 제목: 호실적에 주주환원책까지…크래프톤 주가 쑥
# 출력된 종목: ['엔씨소프트', '크래프톤', '다올투자증권']
#
# === 뉴스 398 ===
# 제목: “이 돈 내고 먹기엔 좀”...가격 올렸다가 낭패본 음식 체인점은
# 출력된 종목: []
#
# === 뉴스 399 ===
# 제목: “GS리테일, 편의점과 비편의점 사업 모두 실적 개선”…목표가 상향
# 출력된 종목: ['NH투자증권', 'GS리테일']
#
# === 뉴스 400 ===
# 제목: “하나투어, 출국자수 급증에도 실적 회복 더뎌…고평가 구간”
# 출력된 종목: ['현대차증권', '하나투어']
#
# === 뉴스 401 ===
# 제목: “피엔에이치테크, 하반기 성장 모멘텀 재개…퀀텀 점프”
# 출력된 종목: ['키움증권']
#
# === 뉴스 402 ===
# 제목: 이수만도 움직인다…경영권 갈등 커지는 SM 주가 급등
# 출력된 종목: ['카카오']
#
# === 뉴스 403 ===
# 제목: 희림, 세계 최대 중국건설사와 업무협약 체결
# 출력된 종목: []
#
# === 뉴스 404 ===
# 제목: “카카오, 에스엠 2대 주주 등극에 시너지 기대”...목표가↑
# 출력된 종목: ['카카오페이', '카카오', '현대차증권', '카카오뱅크']
#
# === 뉴스 405 ===
# 제목: 크래프톤, 4분기 호실적 밀고 주주환원 끌고…7%대 강세
# 출력된 종목: ['크래프톤', '다올투자증권']
#
# === 뉴스 406 ===
# 제목: “뉴스에 팔아라” 격언대로…주식 초고수 이 종목 던졌다
# 출력된 종목: ['미래에셋증권', '카카오']
#
# === 뉴스 407 ===
# 제목: 교보증권, 해외선물 투자세미나 개최
# 출력된 종목: ['교보증권']
#
# === 뉴스 408 ===
# 제목: KB자산운용 장기채ETF, 채권ETF 수익률 1위
# 출력된 종목: []
#
# === 뉴스 409 ===
# 제목: “세금 폭탄 맞을라”...돈 잘 벌고도 웃지 못하는 기업은
# 출력된 종목: []
#
# === 뉴스 410 ===
# 제목: TV광고 매출 급감에...CJ ENM 영업익 53% 줄어
# 출력된 종목: ['CJ']
#
# === 뉴스 411 ===
# 제목: 삼정KPMG, 16일 ‘2023년도 개정세법 설명회’ 개최
# 출력된 종목: []
#
# === 뉴스 412 ===
# 제목: 판매가 인상 덕에...한온시스템 4분기 영업익 71% 쑥
# 출력된 종목: ['한온시스템']
#
# === 뉴스 413 ===
# 제목: 삼일PwC, ESG 통합 솔루션 ‘ESG 데이터 플랫폼’ 개발
# 출력된 종목: []
#
# === 뉴스 414 ===
# 제목: 코로나 3년 끝이 보인다...강원랜드 작년 흑자 전환
# 출력된 종목: ['강원랜드']
#
# === 뉴스 415 ===
# 제목: 구글 챗봇 ‘바드’ 오답 논란에 AI 관련주 ‘휘청’....한국 빅테크 눈돌려볼까
# 출력된 종목: ['카카오', '키움증권', 'KT', '유진투자증권', '유엔젤', 'SK텔레콤']
#
# === 뉴스 416 ===
# 제목: 두산 '깜짝 실적'…3년만에 영업익 1조 돌파
# 출력된 종목: ['CJ', '두산에너빌리티', '두산밥캣', '두산', '넷마블']
#
# === 뉴스 417 ===
# 제목: BGF리테일, 작년 영업익 2593억원… 전년比 30%↑
# 출력된 종목: ['BGF리테일']
#
# === 뉴스 418 ===
# 제목: "초고령화는 기회 … 韓日 실버케어 투자 확대할 것"
# 출력된 종목: []
#
# === 뉴스 419 ===
# 제목: 풍산 울고, LIG넥스원 활짝
# 출력된 종목: ['풍산홀딩스', '풍산', 'LIG넥스원']
#
# === 뉴스 420 ===
# 제목: 전기차 질주 … 한온시스템 호실적
# 출력된 종목: ['한온시스템']
#
# === 뉴스 421 ===
# 제목: 끝 보이는 코로나 강원랜드 흑자전환
# 출력된 종목: ['강원랜드']
#
# === 뉴스 422 ===
# 제목: 하이브, SM 경영권 분쟁 참전하나...“지분 인수 검토중”
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 423 ===
# 제목: 얼라인 “SM, 이수만 기획사에 로열티 지급 중단해야”
# 출력된 종목: ['카카오']
#
# === 뉴스 424 ===
# 제목: 두산 3년만에 영업익 1조 회복
# 출력된 종목: ['두산', '두산에너빌리티', '두산밥캣']
#
# === 뉴스 425 ===
# 제목: 행정공제회, 아태지역 최우수 기관투자가상 수상
# 출력된 종목: []
#
# === 뉴스 426 ===
# 제목: 한국투자증권, 작년 영업익 4409억원…전년비 65.9%↓
# 출력된 종목: ['한국금융지주']
#
# === 뉴스 427 ===
# 제목: 자동차 할부금리 급등에...케이카 작년 4분기 영업익 32% 줄어
# 출력된 종목: ['현대차', 'NH투자증권', '삼성증권', '케이카']
#
# === 뉴스 428 ===
# 제목: 트러스톤운용 “태광산업 배당성향 20%로 높이고 액면분할해야”
# 출력된 종목: ['태광산업']
#
# === 뉴스 429 ===
# 제목: ‘챗봇 망신살’ 알파벳이 끌어내린 빅테크 투심…디즈니, 7000명 해고 계획 [월가월부]
# 출력된 종목: []
#
# === 뉴스 430 ===
# 제목: “오리온, 가격 인상에도 수요 감소 없어”
# 출력된 종목: ['NH투자증권', '오리온']
#
# === 뉴스 431 ===
# 제목: “그렇게 재밌어?”…iMBC, ‘피지컬: 100’ 흥행에 10%대 강세
# 출력된 종목: []
#
# === 뉴스 432 ===
# 제목: 스타크래프트·오버워치 ‘블리자드 90조원딜’ 또 막혔다…이번엔 英 반대
# 출력된 종목: []
#
# === 뉴스 433 ===
# 제목: KODEX 채권ETF, 순자산 10조원 돌파
# 출력된 종목: []
#
# === 뉴스 434 ===
# 제목: 금리 인하 시기 채권값 살펴보니...장기채 레버리지 담아볼까
# 출력된 종목: []
#
# === 뉴스 435 ===
# 제목: “크래프톤, 주주환원보다 프로젝트 투자 필요”...투자의견·목표가↓
# 출력된 종목: ['크래프톤']
#
# === 뉴스 436 ===
# 제목: “이럴 때 안사면 바보”...주식 초고수들 흥분하게 한 호재
# 출력된 종목: ['미래에셋증권', '카카오', '가온전선', 'CJ', 'JB금융지주', '하이브', '한화솔루션']
#
# === 뉴스 437 ===
# 제목: “오늘도 올랐네”…한달만에 60% 수익률 낸 이 종목은
# 출력된 종목: ['LG화학']
#
# === 뉴스 438 ===
# 제목: 보령바이오파마 인수전 ‘흥행’…동원그룹 출사표
# 출력된 종목: ['동원산업']
#
# === 뉴스 439 ===
# 제목: 어피너티 “신창재 회장, 모순된 주장 대신 법원 판결 승복해야”
# 출력된 종목: []
#
# === 뉴스 440 ===
# 제목: “직원 7000명 줄이겠다”...잘 나가는 이 기업, 해고하겠다는 이유는
# 출력된 종목: ['삼성증권']
#
# === 뉴스 441 ===
# 제목: 미래에셋 만기매칭형 채권 ETF 순자산 3천억 돌파
# 출력된 종목: []
#
# === 뉴스 442 ===
# 제목: “우리도 2차 전지주” 나노신소재 17% 급등
# 출력된 종목: ['유안타증권', '삼성SDI', 'LG에너지솔루션']
#
# === 뉴스 443 ===
# 제목: 유아가구 기업 꿈비, 코스닥 상장 첫날 ‘따상’ 성공
# 출력된 종목: []
#
# === 뉴스 444 ===
# 제목: 팬오션 작년 영업익 37% 증가한 7896억원
# 출력된 종목: ['팬오션']
#
# === 뉴스 445 ===
# 제목: 삼성자산운용, 개인 펀드 직판 서비스 ‘R2’ 단계적 축소
# 출력된 종목: []
#
# === 뉴스 446 ===
# 제목: 렌털 사업 덕에...SK네트웍스 작년 영업이익 26% 늘어
# 출력된 종목: ['SK네트웍스']
#
# === 뉴스 447 ===
# 제목: CJ프레시웨이, 작년 영업익 978억원...전년 대비 75.8% 증가
# 출력된 종목: []
#
# === 뉴스 448 ===
# 제목: 현대百 인적분할 무산 … 신사업 추진 급제동
# 출력된 종목: ['현대백화점', '지누스', '현대리바트', '현대지에프홀딩스', '현대그린푸드']
#
# === 뉴스 449 ===
# 제목: “수익률 플러스 전환됐다”...200슬라 복귀에 ‘테슬람’ 환호
# 출력된 종목: ['한화투자증권']
#
# === 뉴스 450 ===
# 제목: 일본 가는 여행객 급증...티웨이항공 작년 4분기 영업익 209% 증가
# 출력된 종목: ['티웨이항공', '제주항공', '진에어']
#
# === 뉴스 451 ===
# 제목: 팬오션 영업이익 38% 늘어 7896억
# 출력된 종목: ['팬오션']
#
# === 뉴스 452 ===
# 제목: “재벌집 막내아들 쏠쏠했는데”...마냥 웃지만 못하는 의외의 기업
# 출력된 종목: []
#
# === 뉴스 453 ===
# 제목: “한 지붕 르세라핌·에스파”…하이브 끌자 에스엠 주가 ‘고공행진’
# 출력된 종목: ['하이브', 'NH투자증권', '카카오']
#
# === 뉴스 454 ===
# 제목: NHN 매출 2조 첫 돌파…영업익은 58.4％ 급감
# 출력된 종목: ['NHN']
#
# === 뉴스 455 ===
# 제목: 하이브, 에스엠 최대주주 됐다…동반 급등
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 456 ===
# 제목: 한국증권금융, 튀르키예 지진 피해 지원 성금 1억원 기부
# 출력된 종목: []
#
# === 뉴스 457 ===
# 제목: “이제 가격 그만 올릴게”...비싸게 팔아도 잘 나간 펩시코
# 출력된 종목: []
#
# === 뉴스 458 ===
# 제목: 하이브, SM 인수에 엔터주 동반 급등
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 459 ===
# 제목: “SM엔터 분쟁 승자는 방시혁?”…초고수, 에스엠 팔고 하이브 베팅
# 출력된 종목: ['LG화학', '미래에셋증권', '카카오', 'LG에너지솔루션', '하이브', 'KB금융']
#
# === 뉴스 460 ===
# 제목: 엉터리 답변 내놓은 AI...챗GPT 관련주 줄줄이 하락
# 출력된 종목: ['유엔젤']
#
# === 뉴스 461 ===
# 제목: 하이브, SM 인수…방시혁은 왜 ‘이수만 백기사’로 나섰나
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 462 ===
# 제목: “농심, 외형 고성장으로 기대치 이상 실적”...목표가↑
# 출력된 종목: ['농심']
#
# === 뉴스 463 ===
# 제목: “스튜디오드래곤, 4분기 실적 부진…‘더 글로리’ 파트2 남았다”
# 출력된 종목: []
#
# === 뉴스 464 ===
# 제목: 방시혁, 이수만 백기사로···하이브, 공개매수로 SM엔터 경영권 인수 나서
# 출력된 종목: ['하이브', '삼성증권']
#
# === 뉴스 465 ===
# 제목: 하이브, SM 전격 인수…이수만 지분 14.8% 매입 1대 주주로
# 출력된 종목: ['하이브']
#
# === 뉴스 466 ===
# 제목: 국민연금 기금운용본부 이달 의결권 행사 설명회
# 출력된 종목: []
#
# === 뉴스 467 ===
# 제목: "리스크 큰 고금리 환경 … 부실채권에 주목해야"
# 출력된 종목: []
#
# === 뉴스 468 ===
# 제목: 해외수주 급증에 … GS·대우건설 훨훨
# 출력된 종목: ['GS건설', '현대건설', 'GS', '삼성물산', '대우건설']
#
# === 뉴스 469 ===
# 제목: “변동성이 높은 고금리 환경, 부실채권에 주목해야”
# 출력된 종목: []
#
# === 뉴스 470 ===
# 제목: ‘애플페이’ 국내 도입 앞두고 수혜주 롤러코스터...지금 사도 될까
# 출력된 종목: ['삼성증권']
#
# === 뉴스 471 ===
# 제목: 술 마시지 말고 酒주식 사볼까 [박윤예의 글로벌주 열전]
# 출력된 종목: ['삼성증권']
#
# === 뉴스 472 ===
# 제목: BTS·에스파 한가족될까…‘하이브+SM’ 마지막 관문은?
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 473 ===
# 제목: 교보증권, 미국주식 ‘주간거래’ 서비스 개시
# 출력된 종목: ['교보증권']
#
# === 뉴스 474 ===
# 제목: 주총 앞두고 … 국민연금, 위탁사에 '의결권 적극 행사' 요구
# 출력된 종목: ['현대백화점']
#
# === 뉴스 475 ===
# 제목: 한화솔루션, 갤러리아 인적분할 … 3세 경영 속도
# 출력된 종목: ['한화갤러리아', '한화', '한화솔루션', '한화생명', '한화에어로스페이스']
#
# === 뉴스 476 ===
# 제목: 컬리 이어 오아시스도 … 결국 상장 철회
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 477 ===
# 제목: 이커머스 1호 자리 노린 오아시스, 결국 상장 철회
# 출력된 종목: []
#
# === 뉴스 478 ===
# 제목: 컬리 전철 밟나...오아시스, 수요예측 부진에도 상장 강행할까
# 출력된 종목: []
#
# === 뉴스 479 ===
# 제목: “너도나도 챗GPT 달려간다”...상한가 치솟은 이 종목
# 출력된 종목: ['SK하이닉스', '유진투자증권', '삼성전자', '현대차']
#
# === 뉴스 480 ===
# 제목: “쳇, 하향은 없고 상향만 있네”…실제 뜯어보니 이 종목 제일 낮췄다
# 출력된 종목: ['LG이노텍', '엔씨소프트', '삼성증권', '크래프톤']
#
# === 뉴스 481 ===
# 제목: “한국인 명품사랑은 못 말려”...불경기에도 최대 매출 달성한 현대백화점
# 출력된 종목: ['현대백화점', '지누스']
#
# === 뉴스 482 ===
# 제목: “주가는 언제 떨어질지 불안해서” 1년새 20배 넘게 자금 몰린 ETF
# 출력된 종목: []
#
# === 뉴스 483 ===
# 제목: 결국 오아시스 마저 상장 철회...계속되는 올 IPO 대어 잔혹사
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 484 ===
# 제목: “韓 증시 저평가...삼전 하이닉스 수급 개선될것”
# 출력된 종목: ['SK하이닉스', '삼성전자']
#
# === 뉴스 485 ===
# 제목: “대기업 지주사 중 가장 저평가됐다”...증권가 추천하는 종목
# 출력된 종목: ['삼성전자', '삼성물산', '호텔신라', '삼성바이오로직스', '두산', '두산로보틱스']
#
# === 뉴스 486 ===
# 제목: KB자산운용, 국채 30년 레버리지ETF 출시
# 출력된 종목: []
#
# === 뉴스 487 ===
# 제목: 베트남 투자가 뜬다...한투신 베트남 투자 콘텐츠 인기
# 출력된 종목: []
#
# === 뉴스 488 ===
# 제목: ‘시총 상위종목 투자’ KODEX TR ETF, 순자산 유입 1위
# 출력된 종목: []
#
# === 뉴스 489 ===
# 제목: 메디톡스, 대웅제약 상대 ‘보톡스 전쟁’ 승소에 장중 신고가
# 출력된 종목: ['대웅제약']
#
# === 뉴스 490 ===
# 제목: 하이브 손잡은 에스엠…연일 동반 강세
# 출력된 종목: ['하이브', '키움증권', '현대차증권']
#
# === 뉴스 491 ===
# 제목: “카카오, 주가 상승 여력 감소...투자의견 하향” 신한증권
# 출력된 종목: ['카카오']
#
# === 뉴스 492 ===
# 제목: “하이브, K-POP 무적함대로 가는 길”…목표가 상향
# 출력된 종목: ['키움증권']
#
# === 뉴스 493 ===
# 제목: “해외파 잘 나가네”…세계무대 호령하는 한국기업은
# 출력된 종목: ['GS건설', '현대건설', 'GS', '삼성물산', '대우건설']
#
# === 뉴스 494 ===
# 제목: 메리츠증권, 미국주식 주간거래 시작…‘365 올 데이’
# 출력된 종목: ['삼성증권']
#
# === 뉴스 495 ===
# 제목: 서학개미 테슬라와 헤어질 결심?...주식 팔고 인버스 산다
# 출력된 종목: []
#
# === 뉴스 496 ===
# 제목: KAI, 민간 항공 수요 회복에 날았다 … 영업익 143% 급증
# 출력된 종목: ['한국항공우주', 'KCC']
#
# === 뉴스 497 ===
# 제목: 마취제 판매 급증...역대 최대 매출 휴온스 주가 쑥
# 출력된 종목: []
#
# === 뉴스 498 ===
# 제목: 이마트 매출 30조 육박 … 영업이익은 스벅에 '발목'
# 출력된 종목: ['이마트']
#
# === 뉴스 499 ===
# 제목: SM 경영권 분쟁 디어유 '최대수혜'
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 500 ===
# 제목: “나 벌써 80% 먹었잖아”...한국인이 사랑한다는 이 종목은
# 출력된 종목: []
#
# === 뉴스 501 ===
# 제목: [유가증권시장 공시] HMM / 현대모비스 / 이마트 등
# 출력된 종목: ['현대모비스', 'HMM']
#
# === 뉴스 502 ===
# 제목: NH證, 친환경기업 포이엔과 온실가스 감축 투자 계약
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 503 ===
# 제목: [코스닥 공시] 탑머티리얼 / 하림지주
# 출력된 종목: []
#
# === 뉴스 504 ===
# 제목: “10년간 돈 계속 나간다”…스타벅스가 방해꾼 신세라니
# 출력된 종목: ['이마트']
#
# === 뉴스 505 ===
# 제목: 외국인 밀려든다…카지노株 껑충
# 출력된 종목: ['파라다이스', 'GKL', '롯데관광개발']
#
# === 뉴스 506 ===
# 제목: 새해에도 겁나게 팔아치우는 연기금…이 종목은 폭풍 매수
# 출력된 종목: ['현대모비스', 'NAVER', 'LG에너지솔루션', '삼성전자', 'CJ제일제당', 'LG생활건강', '유진투자증권']
#
# === 뉴스 507 ===
# 제목: 딜로이트 안진, 자금사고 징후 진단 탐지 솔루션 ‘라이트하우스’ 출시
# 출력된 종목: []
#
# === 뉴스 508 ===
# 제목: 싸우는건 SM, 이득은 이곳이…경영권 분쟁 최대 수혜기업은
# 출력된 종목: ['하이브', '키움증권', '카카오']
#
# === 뉴스 509 ===
# 제목: “CJ제일제당, 원가 부담 1분기까지 지속”...목표가 ↓
# 출력된 종목: ['CJ제일제당', 'CJ대한통운']
#
# === 뉴스 510 ===
# 제목: “적대적 M&A 시도, 하이브 아닌 카카오” SM 사내변호사 일침
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 511 ===
# 제목: 두달 전엔 원금 까먹을까 걱정했는데...테슬라·H지수 ELS 다시 는다
# 출력된 종목: ['유안타증권']
#
# === 뉴스 512 ===
# 제목: “실적 회복 예상보다 더 빠를 것”…LG전자, 4%대 강세
# 출력된 종목: ['NH투자증권', 'LG전자']
#
# === 뉴스 513 ===
# 제목: “물 들어올때 노젓자”…2월에도 회사채 발행 봇물
# 출력된 종목: ['LS', 'HD현대', '삼성증권', 'GS건설', '롯데지주', '한국토지신탁', '현대건설', '한신공영', 'SK', 'SK디스커버리', 'SK케미칼', '현대차증권']
#
# === 뉴스 514 ===
# 제목: 끝내 IPO 철회...그날 오아시스 이사회에선 무슨 일이?
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 515 ===
# 제목: NH證, 바이오차 생산기업 포이엔과 온실가스 감축사업 투자계약
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 516 ===
# 제목: 고양이와 스프 덕에...네오위즈 작년 영업익 16% 늘어
# 출력된 종목: ['삼성증권']
#
# === 뉴스 517 ===
# 제목: 투자자 손실에 발목 잡힌 오아시스 상장
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 518 ===
# 제목: 실리콘 사업 효자 됐네...KCC 영업익 20% 증가
# 출력된 종목: ['KCC']
#
# === 뉴스 519 ===
# 제목: 실적시즌 커지는 신용등급 하향 우려
# 출력된 종목: ['넷마블', '롯데케미칼', 'LG디스플레이']
#
# === 뉴스 520 ===
# 제목: ‘돈잔치’ 벌일 땐 좋았는데…은행권, 공공의 적 취급에 전전긍긍
# 출력된 종목: ['KT', 'LG유플러스', '하나금융지주', '우리금융지주', 'KB금융', 'SK텔레콤', '신한지주']
#
# === 뉴스 521 ===
# 제목: 공개매수가 넘어선 SM … 가처분 결과따라 주가 요동칠듯
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 522 ===
# 제목: "돈잔치 그만" 압박에 날벼락 맞은 은행株
# 출력된 종목: ['KT', 'LG유플러스', '하나금융지주', '우리금융지주', 'KB금융', 'SK텔레콤', '신한지주']
#
# === 뉴스 523 ===
# 제목: 스틱인베, 일진머티리얼즈 2대주주로
# 출력된 종목: ['스틱인베스트먼트', '롯데케미칼']
#
# === 뉴스 524 ===
# 제목: "AI가 해외주식 뉴스 번역" 미래에셋證, 20일 서비스
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 525 ===
# 제목: 스틱, 일진머티리얼즈 2대주주로
# 출력된 종목: ['스틱인베스트먼트', '롯데케미칼']
#
# === 뉴스 526 ===
# 제목: “리오프닝 수혜주 아니었어?”...목표주가 11% 떨어진 이 종목
# 출력된 종목: ['현대백화점', '한화투자증권', '지누스', '대신증권', '현대그린푸드']
#
# === 뉴스 527 ===
# 제목: 파라다이스, 작년 영업익 104억원 ‘흑자전환’
# 출력된 종목: ['파라다이스']
#
# === 뉴스 528 ===
# 제목: LNG선 덕에...대한해운, 작년 영업익 2676억원, 31% 쑥
# 출력된 종목: ['대한해운']
#
# === 뉴스 529 ===
# 제목: “우리 철강주 아니에요”…2차전지로 울고웃는 포스코홀딩스
# 출력된 종목: ['POSCO홀딩스', '동국제강', 'KG스틸', '코스모화학', '현대제철', '유진투자증권']
#
# === 뉴스 530 ===
# 제목: SK에코플랜트 회사채에 5000억원 몰려
# 출력된 종목: ['GS건설', '한국토지신탁', '현대건설', '한신공영', '대우건설']
#
# === 뉴스 531 ===
# 제목: 리튬이 끌고 테슬라가 밀고 … 포스코홀딩스 '기세등등'
# 출력된 종목: ['동국제강', 'KG스틸', '코스모화학', '현대제철', '유진투자증권']
#
# === 뉴스 532 ===
# 제목: 이유 없이 15배 뛰더니…한달 반 만에 삼분의 일 토막난 종목은
# 출력된 종목: ['한국ANKOR유전', '삼성물산']
#
# === 뉴스 533 ===
# 제목: 살얼음판 걷는 SM 주가…법원 판단 따라 급락 가능성도
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 534 ===
# 제목: “이마트, 할인점 턴어라운드에 주목”…신한증권, 목표가 ↑
# 출력된 종목: ['이마트']
#
# === 뉴스 535 ===
# 제목: “네오위즈, 하반기 신작 모멘텀으로 퀀텀점프 기대”...목표가↑
# 출력된 종목: ['삼성증권']
#
# === 뉴스 536 ===
# 제목: 에스엠, 주가 12만원 돌파…하이브 공개매수 차질
# 출력된 종목: ['하이브', '카카오', 'CJ']
#
# === 뉴스 537 ===
# 제목: 하이브 방시혁 2조5천억 1위...BTS 전원 ‘100억 클럽’
# 출력된 종목: ['하이브']
#
# === 뉴스 538 ===
# 제목: AI보안 샌즈랩, 코스닥 상장 첫날 ‘따상’ 터치
# 출력된 종목: []
#
# === 뉴스 539 ===
# 제목: AI가 해외주식 뉴스 한국어 요약...미래에셋증권 20일부터 도입
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 540 ===
# 제목: “그렇게 돈 벌고서는”...가격 또 올린다고 공언한 이 제품은
# 출력된 종목: []
#
# === 뉴스 541 ===
# 제목: 최광욱 더제이자산운용 대표 “1등기업 투자로 공모펀드 부활 주도”
# 출력된 종목: []
#
# === 뉴스 542 ===
# 제목: 현대차증권, ELS·DLS 가입 이벤트
# 출력된 종목: ['삼성전자', '현대차증권']
#
# === 뉴스 543 ===
# 제목: BTS도 100억 이상 주식 부자…하이브 방시혁 2조5000억원 1위
# 출력된 종목: ['카카오', '현대차', '하이브', '셀트리온', '아모레퍼시픽']
#
# === 뉴스 544 ===
# 제목: "의료용소재로 사업 확장 … 美·유럽 진출 속도"
# 출력된 종목: []
#
# === 뉴스 545 ===
# 제목: EY한영 “국내 기업인들, 경기침체에 대비한 경영전략 재정비에 나서”
# 출력된 종목: []
#
# === 뉴스 546 ===
# 제목: 공인회계사회, 소규모기업 감사기준 제정...“절차 간소화”
# 출력된 종목: []
#
# === 뉴스 547 ===
# 제목: 씨앤씨인터내셔널 작년 4분기 영업익 46억
# 출력된 종목: ['삼성증권']
#
# === 뉴스 548 ===
# 제목: 너무 올랐나…코스피 공매도 이달 21% 늘었다
# 출력된 종목: ['대신증권', '카카오뱅크', '하나금융지주', '크래프톤', '효성', 'BNK금융지주', '호텔신라', '우리금융지주', 'SKC', '넷마블', '아모레퍼시픽', '신한지주']
#
# === 뉴스 549 ===
# 제목: “한국증시, 이제 떨어질걸?”...공매도 늘려가는 외국인들
# 출력된 종목: ['대신증권', '효성', '호텔신라', 'SKC', '아모레퍼시픽']
#
# === 뉴스 550 ===
# 제목: [PEF 포트폴리오 돋보기] 3년째 두자릿수 성장 … 메타버스까지 진출
# 출력된 종목: []
#
# === 뉴스 551 ===
# 제목: 대기업 경영권 방어엔 역부족 …"美·日처럼 '포이즌필' 필요"
# 출력된 종목: ['BYC', 'KT', '태광산업', 'JB금융지주']
#
# === 뉴스 552 ===
# 제목: "경영권 사수" 황금낙하산 챙기는 기업들
# 출력된 종목: []
#
# === 뉴스 553 ===
# 제목: “도대체 누구인가”...SM 경영권 분쟁 최대 미스터리, 3% 누가 샀나
# 출력된 종목: ['하이브', '키움증권', '카카오']
#
# === 뉴스 554 ===
# 제목: 증권금융 "3조원 유동성 지원 올해도 지속"
# 출력된 종목: []
#
# === 뉴스 555 ===
# 제목: 코스콤, 빌리어네어즈와 ‘투자자 커뮤니티 플랫폼’ 추진
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 556 ===
# 제목: “70% 넘게 챙겼잖아”…SM 경영권 분쟁에 남몰래 웃은 기업
# 출력된 종목: ['하이브', '카카오', 'CJ']
#
# === 뉴스 557 ===
# 제목: 증권금융 “금융시장 안심은 일러...3조 유동성 지원 지속”
# 출력된 종목: []
#
# === 뉴스 558 ===
# 제목: “위메이드, 신작 쏟아진다…2분기 흑자전환”
# 출력된 종목: []
#
# === 뉴스 559 ===
# 제목: 대어 줄줄이 상장 미루자 중소형주 활개...9곳 중 6곳 ‘따상’
# 출력된 종목: []
#
# === 뉴스 560 ===
# 제목: 통신요금 잡기 나선 윤 대통령에…통신주 일제히 ‘시들’
# 출력된 종목: ['KT', 'SK텔레콤', 'LG유플러스']
#
# === 뉴스 561 ===
# 제목: 팬덤코리아, ‘마이클 잭슨 미완성 앨범’ 프로젝트 협력...국내외 유통 예정
# 출력된 종목: []
#
# === 뉴스 562 ===
# 제목: ‘IPO 재수생’ 제이오, 상장 첫날 강세...공모가 60%↑
# 출력된 종목: []
#
# === 뉴스 563 ===
# 제목: “HD현대, 주주환원 재원 확대될 것”…목표가↑
# 출력된 종목: ['HD현대']
#
# === 뉴스 564 ===
# 제목: 교보증권, ‘박세익 투자설명회’ 개최
# 출력된 종목: ['교보증권']
#
# === 뉴스 565 ===
# 제목: “에스파 곡에 ‘나무심기’ 단어 넣으라 지시”…이수만 직격한 SM 대표
# 출력된 종목: ['하이브']
#
# === 뉴스 566 ===
# 제목: ‘헤지펀드의 황제’라는 이 남자…급락한 테슬라 줍줍했네
# 출력된 종목: []
#
# === 뉴스 567 ===
# 제목: HD현대 회사채 수요예측서 6000억원 몰려
# 출력된 종목: ['HD현대']
#
# === 뉴스 568 ===
# 제목: 트러스톤운용, BYC에 배당확대·감사선임 등 주주제안
# 출력된 종목: ['BYC']
#
# === 뉴스 569 ===
# 제목: 시스코, 네트워킹 매출 확대에 주가 쑥
# 출력된 종목: []
#
# === 뉴스 570 ===
# 제목: 중국은 이제 내부 검토하는데...한국선 규제설에 테마주 급등
# 출력된 종목: ['고려아연', 'LG화학']
#
# === 뉴스 571 ===
# 제목: 김소영 금융위 부위원장 “선진국 규제강화…ESG 금융제도 본격 검토”
# 출력된 종목: []
#
# === 뉴스 572 ===
# 제목: IBK투자證 사장에 서정학
# 출력된 종목: ['기업은행']
#
# === 뉴스 573 ===
# 제목: 공개매수가 훌쩍 넘긴 SM…6일만에 하락
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 574 ===
# 제목: 코로나 특수 사라지자 씨젠 영업익 92% 급락
# 출력된 종목: ['대신증권']
#
# === 뉴스 575 ===
# 제목: '희토류 테마주' 이상과열
# 출력된 종목: ['고려아연']
#
# === 뉴스 576 ===
# 제목: ‘코로나 특수’ 걷어낸 씨젠, 매출 70% 급감
# 출력된 종목: ['대신증권']
#
# === 뉴스 577 ===
# 제목: SM 평직원 208명 “이수만·하이브 결탁한 적대적 M&A 반대”
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 578 ===
# 제목: “에코프로비엠, 올해도 외형성장 이어가”…목표가↑
# 출력된 종목: []
#
# === 뉴스 579 ===
# 제목: 5일 내내 오르더니...이제야 숨고르기 들어간 이 종목은
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 580 ===
# 제목: “언제쯤 볕들까”...개인 담은 종목들, 올해도 일제히 마이너스
# 출력된 종목: ['현대로템', '강원랜드', 'POSCO홀딩스', 'SK이노베이션', 'CJ제일제당', 'LG생활건강', '한국전력', 'SK텔레콤']
#
# === 뉴스 581 ===
# 제목: IBK투자증권 사장에 서정학 IBK저축은행장 내정
# 출력된 종목: ['기업은행']
#
# === 뉴스 582 ===
# 제목: “주가 더 오를까” 가격 할인 테슬라, 7천만원 모델도 판매 급증
# 출력된 종목: []
#
# === 뉴스 583 ===
# 제목: “한국투자 때 가장 믿을 만”...외국인 투자자 1년새 1.3조 산 ETF
# 출력된 종목: []
#
# === 뉴스 584 ===
# 제목: “배민은 약과였네”...한달 배달주문만 1억3천만건이라는 이 기업은
# 출력된 종목: []
#
# === 뉴스 585 ===
# 제목: 에스엠 자회사 키이스트, 지분 매각설에 17%대 급등
# 출력된 종목: []
#
# === 뉴스 586 ===
# 제목: 하이브 CEO, 이수만 역외탈세 의혹에...“결코 일어날수 없는 시나리오”
# 출력된 종목: ['하이브']
#
# === 뉴스 587 ===
# 제목: 신한자산운용,  누버거버먼 미국가치주 펀드 판매사 확대
# 출력된 종목: ['미래에셋증권', '삼성증권']
#
# === 뉴스 588 ===
# 제목: 돌아온 강달러 … 외국인 '폭풍매수' 멈췄다
# 출력된 종목: ['대신증권', '카카오', '카카오뱅크']
#
# === 뉴스 589 ===
# 제목: [IB명가에 듣는다] "올 M&A시장 화두는 AI … 하반기 IPO 회복"
# 출력된 종목: ['LG에너지솔루션', '삼성바이오로직스', 'SK텔레콤', 'SK']
#
# === 뉴스 590 ===
# 제목: 돌아온 강달러…외국인 ‘폭풍매수’ 멈췄다
# 출력된 종목: ['카카오', 'POSCO홀딩스', '대신증권', '카카오뱅크', '신세계']
#
# === 뉴스 591 ===
# 제목: 재고 확 줄어든 LG엔솔 현금흐름 '청신호'
# 출력된 종목: ['LG화학', 'SK하이닉스', '삼성전자', 'LG에너지솔루션']
#
# === 뉴스 592 ===
# 제목: 中 리오프닝 수혜주 옥석 가려라...경기민감주, 소비주 주목
# 출력된 종목: ['대한해운', '동국제강', '유안타증권', 'LG생활건강', '호텔신라', '오리온', '팬오션', '롯데관광개발', '아모레퍼시픽']
#
# === 뉴스 593 ===
# 제목: 3대 대장주 현금흐름 봤더니…빨간불 켜진 종목 보이네
# 출력된 종목: ['LG화학', 'SK하이닉스', '삼성전자', 'LG에너지솔루션']
#
# === 뉴스 594 ===
# 제목: “미치게 뛴 이 종목, 이것 때문이라고?”
# 출력된 종목: []
#
# === 뉴스 595 ===
# 제목: “게임 잘 안풀리네”…목표가 하향 보고서 줄줄이, 언제 볕들까
# 출력된 종목: ['미래에셋증권', '현대백화점', '엔씨소프트', '삼성증권', '상상인증권', '크래프톤', 'LG이노텍', '대웅제약']
#
# === 뉴스 596 ===
# 제목: 매출 70억 식품용 플라스틱 용기 제조사 매물로
# 출력된 종목: []
#
# === 뉴스 597 ===
# 제목: 스쳐도 40%, 잘 맞으면 6연상…‘흥행 보증수표’ 삼성스팩이 뭐길래
# 출력된 종목: []
#
# === 뉴스 598 ===
# 제목: 오스템임플란트 공개매수 순항 … "MBK·유니슨, 지분 60% 확보"
# 출력된 종목: []
#
# === 뉴스 599 ===
# 제목: '황금알' 동박 품고…SKC·일진머티리얼즈 날았다
# 출력된 종목: ['SKC', '롯데케미칼', '유진투자증권']
#
# === 뉴스 600 ===
# 제목: "소주값 오른다" 주류株 강세
# 출력된 종목: ['보해양조', '하이트진로', '무학']
#
# === 뉴스 601 ===
# 제목: 쏟아지는 '안전지향 ELS'
# 출력된 종목: ['유안타증권']
#
# === 뉴스 602 ===
# 제목: 얼라인 지분매수에 SBS 급등
# 출력된 종목: []
#
# === 뉴스 603 ===
# 제목: [M&A 매물장터] 식품용 플라스틱 용기 제조업체 매물로
# 출력된 종목: []
#
# === 뉴스 604 ===
# 제목: “소맥 가격 오른다는데 주류주 한 번 사볼까?”…일제히 강세
# 출력된 종목: ['보해양조', '하이트진로홀딩스', '하이트진로', '무학']
#
# === 뉴스 605 ===
# 제목: SM 주가 6.3% 급락...공개매수 분기점
# 출력된 종목: ['하이브', '카카오']
#
# === 뉴스 606 ===
# 제목: KB증권, 신용융자·주식담보대출 이자율 낮춘다
# 출력된 종목: []
#
# === 뉴스 607 ===
# 제목: [단독] 오스템임플란트 공개매수 순항...“MBK·유니슨 이미 60% 이상 확보”
# 출력된 종목: []
#
# === 뉴스 608 ===
# 제목: “올해 8만전자 갈까”...증권가에 삼성전자 ‘핑크빛 전망’ 솔솔
# 출력된 종목: ['신영증권', '다올투자증권', '대신증권', '유안타증권', '삼성전자', '유진투자증권', '현대차증권']
#
# === 뉴스 609 ===
# 제목: 에스엠, 4분기 영업익 전년比 70% 증가…어닝서프라이즈
# 출력된 종목: []
#
# === 뉴스 610 ===
# 제목: “네오위즈, ‘P의 거짓’ 출시까지 긍정적 모멘텀”...목표가↑
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 611 ===
# 제목: ‘황금알을 낳는 거위’...손자회사 덕에 주가 급등하는 SKC
# 출력된 종목: ['SKC']
#
# === 뉴스 612 ===
# 제목: 펀드 혹한기에 1조원 넘게 들어왔다...무슨 펀드길래?
# 출력된 종목: []
#
# === 뉴스 613 ===
# 제목: 하이브 “공개매수가 인상 없다” 입장에 에스엠 5%대 급락
# 출력된 종목: ['하이브']
#
# === 뉴스 614 ===
# 제목: “바이오·헬스케어 집중한다” HLB 21% 급등
# 출력된 종목: []
#
# === 뉴스 615 ===
# 제목: 소주·맥주 가격 오른다...주류株 일제 상승
# 출력된 종목: ['보해양조', '하이트진로', '무학']
#
# === 뉴스 616 ===
# 제목: “LG화학, 美 리튬광산 투자는 탈중국에 방점”
# 출력된 종목: ['LG화학', 'LG에너지솔루션']
#
# === 뉴스 617 ===
# 제목: 신한 SOL 월배당 ETF, 순자산 1000억원 돌파
# 출력된 종목: []
#
# === 뉴스 618 ===
# ...
#
# === 뉴스 8804 ===
# 제목: '5조 대어' DN솔루션즈 상장 철회 … 공모시장 찬바람
# 출력된 종목: ['서울보증보험', 'LG']
#
# === 뉴스 8805 ===
# 제목: KB금융 이달 자사주 1조 소각
# 출력된 종목: ['KB금융']
#
# === 뉴스 8806 ===
# 제목: 한화오션 품은 한화에어로 영업익 3060%↑
# 출력된 종목: ['현대글로비스', '한화시스템', '한화오션', '두산에너빌리티', '삼성물산', '현대위아', '두산', '한화에어로스페이스']
#
# === 뉴스 8807 ===
# 제목: [속보] 이명희, ㈜신세계 지분 10% 딸 정유경에게 증여
# 출력된 종목: []
#
# === 뉴스 8808 ===
# 제목: 서울 광화문 우량 오피스 ‘센터포인트 광화문’ 입찰전 흥행…원매자 8곳 인수 도전장
# 출력된 종목: []
#
# === 뉴스 8809 ===
# 제목: 효성화학의 베트남법인 살리기, 3년 시간 벌었다
# 출력된 종목: ['효성화학', '효성티앤씨']
#
# === 뉴스 8810 ===
# 제목: “5조 대어도 발 뺐다”…찬바람 부는 공모시장, 이 회사도 상장 철회
# 출력된 종목: ['서울보증보험', 'LG']
#
# === 뉴스 8811 ===
# 제목: 유한양행 자회사 이뮨온시아, 공모가 상단 3600원 확정
# 출력된 종목: ['유한양행']
#
# === 뉴스 8812 ===
# 제목: 한국SGI, 미얀마 지진 피해 구호 후원금 기탁…유엔난민기구 통해 긴급 지원
# 출력된 종목: []
#
# === 뉴스 8813 ===
# 제목: “크래프톤, 시장의 우려와는 달리 고성장 가능성 높아”…목표가↑
# 출력된 종목: ['크래프톤']
#
# === 뉴스 8814 ===
# 제목: 싸이토젠, 美암학회서 전립선암·다발성 골수종 연구성과 발표…글로벌 사업 확장 본격화
# 출력된 종목: []
#
# === 뉴스 8815 ===
# 제목: 신한투자증권, 글로벌 AI 학회에 논문 2건 등재
# 출력된 종목: []
#
# === 뉴스 8816 ===
# 제목: JLL “올 1분기 아·태지역 상업용 부동산 투자 규모 늘어”
# 출력된 종목: []
#
# === 뉴스 8817 ===
# 제목: 한투파PE, 오아시스 지분 매각 추진
# 출력된 종목: []
#
# === 뉴스 8818 ===
# 제목: 크라우드웍스, ‘리얼 월드 엔터프라이즈 AI’ 컨퍼런스 성료
# 출력된 종목: ['유안타증권']
#
# === 뉴스 8819 ===
# 제목: “다음달 물량 쏟아진다”…더본코리아 등 68개사 5.6억주 의무보유 해제
# 출력된 종목: ['HLB글로벌', '카프로', '더본코리아', '삼부토건']
#
# === 뉴스 8820 ===
# 제목: 웅진, ‘상조 1위’ 프리드라이프 인수 소식에 15%대 급등
# 출력된 종목: ['웅진씽크빅', '웅진']
#
# === 뉴스 8821 ===
# 제목: (여자)아이들 우기·미연 中서도 ‘쌍끌이’ 인기… 음원 발매만으로 현지 차트 1위 석권
# 출력된 종목: []
#
# === 뉴스 8822 ===
# 제목: “에코프로비엠, 하반기 불확실성 확대 전망”…목표가↓
# 출력된 종목: []
#
# === 뉴스 8823 ===
# 제목: 주가 올리려는 삼성전자의 고민…OPI 이어 LTI도 자사주로?
# 출력된 종목: ['삼성전자']
#
# === 뉴스 8824 ===
# 제목: 현대차증권, 여의도 본사사옥 셰어딜 방식으로 투자한다
# 출력된 종목: ['현대차증권']
#
# === 뉴스 8825 ===
# 제목: “주가 99만원 찍었다”…사상 첫 ‘황제주’ 등극 노리는 이 식품회사
# 출력된 종목: ['한화시스템', '대신증권', '키움증권', 'NH투자증권', '삼양식품', '유진투자증권']
#
# === 뉴스 8826 ===
# 제목: 퇴직연금대상 미래에셋증권
# 출력된 종목: ['미래에셋증권', 'NH투자증권', '삼성생명']
#
# === 뉴스 8827 ===
# 제목: 롯데글로벌로지스 IPO 연기 수요 예측 부진에 상장 철회
# 출력된 종목: []
#
# === 뉴스 8828 ===
# 제목: 롯데글로벌로지스, 수요예측 부진에 코스피 상장 자진철회
# 출력된 종목: []
#
# === 뉴스 8829 ===
# 제목: 뷰티 IPO 연이은 흥행… 바이오비쥬, 공모가 상단 9100원 확정
# 출력된 종목: ['대신증권']
#
# === 뉴스 8830 ===
# 제목: “삼성전자, 1분기 아쉬운 실적…하반기 눈높이 낮춰야”
# 출력된 종목: ['삼성전자']
#
# === 뉴스 8831 ===
# 제목: 신한투자증권, 증권업계 최초 고객행동데이터 플랫폼 오픈
# 출력된 종목: []
#
# === 뉴스 8832 ===
# 제목: 아이들, 19일 미니 8집 컴백 확정…큐브엔터 재계약, 리브랜딩 후 첫 완전체 컴백
# 출력된 종목: []
#
# === 뉴스 8833 ===
# 제목: 이재명 관련주 지고 한덕수 뜨고…정치테마주 널뛰기
# 출력된 종목: ['형지엘리트', '오리엔트바이오']
#
# === 뉴스 8834 ===
# 제목: JKL파트너스, 콘텐트리중앙 투자금 회수 나서
# 출력된 종목: ['콘텐트리중앙']
#
# === 뉴스 8835 ===
# 제목: K뷰티 인기덕에 러브콜 받는 ODM
# 출력된 종목: ['코스맥스', '한국콜마', '아모레퍼시픽']
#
# === 뉴스 8836 ===
# 제목: 美빅테크 AI투자 확대에 기지개 켜는 전력기기주
# 출력된 종목: ['산일전기', '효성중공업', 'HD현대일렉트릭']
#
# === 뉴스 8837 ===
# 제목: ‘바이오 소재’ 지에프씨생명과학, 코스닥 상장 위한 증권신고서 제출
# 출력된 종목: ['대신증권']
#
# === 뉴스 8838 ===
# 제목: 다시 시동거는 전력기기
# 출력된 종목: ['산일전기', '효성중공업', 'HD현대일렉트릭']
#
# === 뉴스 8839 ===
# 제목: 자산재평가 후 부채비율 '뚝'… 유통·레저주 날개
# 출력된 종목: ['대신증권', '호텔신라', '롯데쇼핑', '롯데관광개발', '유진투자증권']
#
# === 뉴스 8840 ===
# 제목: “한국제품만 쓰고 싶어요”...외국여성들 홀려버린 K뷰티, 주가도 수출도 승승장구
# 출력된 종목: ['코스맥스', '한국콜마', '아모레퍼시픽']
#
# === 뉴스 8841 ===
# 제목: “한국 오고 싶었어요, 특히 여기는 더”...외국인 발길 늘었지만 여전히 울상인 곳
# 출력된 종목: []
#
# === 뉴스 8842 ===
# 제목: “매년 건물 1~2채씩 사겠다”...큰손 되겠다고 선언한 신한알파리츠, 배당족 심장 울려
# 출력된 종목: ['신한알파리츠']
#
# === 뉴스 8843 ===
# 제목: “2280억원 아깝지 않습니다”...거금 투입해 건물 사들인 한국토지신탁, 제2 판교에 선제투자
# 출력된 종목: ['삼성전자', '한국토지신탁', '삼성SDI']
#
# === 뉴스 8844 ===
# 제목: 부동산은 배신하지 않았다...불황에 울던 유통·레저주, 주가 오른 이유는
# 출력된 종목: ['대신증권', '호텔신라', '롯데쇼핑', '롯데관광개발', '유진투자증권']
#
# === 뉴스 8845 ===
# 제목: 올해 주총시즌 주주제안 2배 증가...“소액주주 플랫폼이 핵심동인”
# 출력된 종목: ['고려아연', '유엔젤', '콜마홀딩스']
#
# === 뉴스 8846 ===
# 제목: “올해는 달라”…‘관세 무풍지대’ 엔터주에 봄날이 왔다
# 출력된 종목: []
#
# === 뉴스 8847 ===
# 제목: 대선앞 '한탕민국'… 정치테마株 기승
# 출력된 종목: ['태양금속', '평화홀딩스', '형지엘리트', '갤럭시아에스엠']
#
# === 뉴스 8848 ===
# 제목: “지금 아니면 못사”...흥분 못 감추는 투자자들, 정치테마주 빚투 급증
# 출력된 종목: []
#
# === 뉴스 8849 ===
# 제목: 한국투자증권, 골드만삭스와 손잡았다 ··· 펀드판매 등 협력
# 출력된 종목: []
#
# === 뉴스 8850 ===
# 제목: 한국투자증권, 골드만삭스와 손잡았다
# 출력된 종목: []
#
# === 뉴스 8851 ===
# 제목: KODEX 美ETF 유보배당금 삼성운용, 15분기 나눠 분배
# 출력된 종목: []
#
# === 뉴스 8852 ===
# 제목: 신성이엔지, 청송군 산불 피해 주민 돕기 위해 1000만원 기부
# 출력된 종목: ['신성이엔지']
#
# === 뉴스 8853 ===
# 제목: 수성웹툰, 1분기 영업활동 현금흐름 70억 원으로 사상 최대
# 출력된 종목: []
#
# === 뉴스 8854 ===
# 제목: 한국투자증권, 뉴욕에서 글로벌 IR 행사 ‘KIS Night in New York 2025’ 개최
# 출력된 종목: []
#
# === 뉴스 8855 ===
# 제목: “공모주 한파 이겨낼까”…‘K뷰티 기대주’ 등 3곳 일반청약
# 출력된 종목: ['유한양행', '대신증권', '유진투자증권', '미래에셋증권']
#
# === 뉴스 8856 ===
# 제목: 삼성운용 “KODEX 미국 대표지수 ETF 2종 유보 배당금 15분기 동안 분배”
# 출력된 종목: []
#
# === 뉴스 8857 ===
# 제목: 신한투자증권, 삼성전자 투자하는 공모 ELB 3571호 모집
# 출력된 종목: ['삼성전자']
#
# === 뉴스 8858 ===
# 제목: “2주 내 의약품 관세 발표” 트럼프 한마디에…바이오株 출렁
# 출력된 종목: []
#
# === 뉴스 8859 ===
# 제목: “JYP Ent., 1Q 영업익 시장 기대치 하회 전망…2Q 기대”
# 출력된 종목: ['대신증권']
#
# === 뉴스 8860 ===
# 제목: 젬백스, PSP 치료제 FDA 패스트트랙 지정
# 출력된 종목: []
#
# === 뉴스 8861 ===
# 제목: 달바글로벌, 수요예측 대흥행… “글로벌 투자자 다수 참여”
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 8862 ===
# 제목: 大魚 대신 알짜 … IPO시장 달굴 제약·바이오
# 출력된 종목: ['유한양행', '녹십자홀딩스', 'NH투자증권', '녹십자']
#
# === 뉴스 8863 ===
# 제목: 타임폴리오운용, 차이나AI테크액티브 ETF 상장
# 출력된 종목: []
#
# === 뉴스 8864 ===
# 제목: “제2의 반도체 산업 될 것”…‘염블리’가 콕 집은 유망 업종은 [서울머니쇼]
# 출력된 종목: ['삼성바이오로직스']
#
# === 뉴스 8865 ===
# 제목: “다 아는 곳이네”...숨은 강자들 쏟아지는 공모주 시장, 제약·바이오가 이끈다
# 출력된 종목: ['유한양행', 'NH투자증권', '녹십자']
#
# === 뉴스 8866 ===
# 제목: 해외법인 역대 최대실적에...미래에셋 1분기 영업익 28%증가
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 8867 ===
# 제목: 하나증권, 서울맹학교 아이들과 세번째 행복한 봄나들이
# 출력된 종목: []
#
# === 뉴스 8868 ===
# 제목: 바디텍메드 1분기 매출 전년 대비 18% 증가
# 출력된 종목: []
#
# === 뉴스 8869 ===
# 제목: 한투운용, ACE 미국배당퀄리티 시리즈 3종 동시 상장
# 출력된 종목: []
#
# === 뉴스 8870 ===
# 제목: K게임 계보 이을 자 누구인가…“넷마블, 더블유게임즈 주목”
# 출력된 종목: ['넷마블', '더블유게임즈', '엔씨소프트', '크래프톤']
#
# === 뉴스 8871 ===
# 제목: 삼성자산운용, ‘KODEX 증여 가이드북’ 발간
# 출력된 종목: []
#
# === 뉴스 8872 ===
# 제목: ‘반도체 디자인’ 싸이닉솔루션, 코스닥 상장 위한 증권신고서 제출
# 출력된 종목: ['대신증권']
#
# === 뉴스 8873 ===
# 제목: 이정재가 대주주인 이 회사, 대박난 ‘재벌집 막내아들’ 시즌2 만든다
# 출력된 종목: []
#
# === 뉴스 8874 ===
# 제목: LG헬로비전, 1분기 매출 3135억·영업이익 71억…전년比 17.3%·73.1% ↑
# 출력된 종목: ['LG헬로비전']
#
# === 뉴스 8875 ===
# 제목: “진짜 오래 기다렸다”...드디어 완전체로 돌아오는 BTS, 하이브도 두근두근
# 출력된 종목: ['삼성증권', 'SK하이닉스', 'NH투자증권', '삼성전자', '두산에너빌리티', '하이브', '두산', '아모레퍼시픽']
#
# === 뉴스 8876 ===
# 제목: 엑스플러스, ‘아몬드브리즈’와 협업한 갤럭시 버즈3 시리즈 케이스 3종 출시
# 출력된 종목: ['삼성전자']
#
# === 뉴스 8877 ===
# 제목: 나우로보틱스, 코스닥 상장 첫날 150%대 급등
# 출력된 종목: []
#
# === 뉴스 8878 ===
# 제목: “롯데칠성, 뼈아픈 음료사업 부진”…목표가↓
# 출력된 종목: ['롯데칠성']
#
# === 뉴스 8879 ===
# 제목: “카카오게임즈, 1Q 적자전환에 신작 성과 가시화 필요”…목표가↓
# 출력된 종목: ['대신증권']
#
# === 뉴스 8880 ===
# 제목: SK증권, ‘2025 서울머니쇼’ KRX 금현물시장 부스 참여
# 출력된 종목: ['SK증권']
#
# === 뉴스 8881 ===
# 제목: 영풍·MBK “박기덕 고려아연 대표 취임 반대” vs 고려아연 “강성두·김광일 사임해야”
# 출력된 종목: ['고려아연', '영풍']
#
# === 뉴스 8882 ===
# 제목: 노머스, 1분기 영업이익 전년동기대비 385%…“역대급 실적”
# 출력된 종목: []
#
# === 뉴스 8883 ===
# 제목: “한 달도 안돼 13번 상한가라니”…정치테마주 포모현상 ‘주의보’
# 출력된 종목: ['평화홀딩스', '오리엔트바이오']
#
# === 뉴스 8884 ===
# 제목: 고려아연, 자사주 연내 전량 소각 발표에 주가 9%대 오름세
# 출력된 종목: []
#
# === 뉴스 8885 ===
# 제목: ‘새내기주’ 원일티엔아이 80% 상승… 오가노이드사이언스도 강세
# 출력된 종목: []
#
# === 뉴스 8886 ===
# 제목: 신한투자증권, 넥스트레이드 대체거래소 약정액 크게 늘어
# 출력된 종목: []
#
# === 뉴스 8887 ===
# 제목: 이지스운용, 오산세교2지구 M1BL 토지비 완납…44층 랜드마크 사업 본격 착수
# 출력된 종목: ['키움증권']
#
# === 뉴스 8888 ===
# 제목: ‘뇌 질환 진단’ 뉴로핏, 코스닥 상장 예비심사 승인
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 8889 ===
# 제목: ‘성공적 신고식’ 원일티엔아이, 상장 첫날 80%대 급등…‘따블’ 기록도
# 출력된 종목: []
#
# === 뉴스 8890 ===
# 제목: 넷마블, ‘어닝서프라이즈’ 발표에 장초반 13%대 급등
# 출력된 종목: ['넷마블', '유진투자증권']
#
# === 뉴스 8891 ===
# 제목: KB자산운용, 한부모가족시설 봉사활동 펼쳐
# 출력된 종목: []
#
# === 뉴스 8892 ===
# 제목: GRESB, 한국그린빌딩협회와 대체투자 지속가능성 공동 협력 MOU 체결
# 출력된 종목: []
#
# === 뉴스 8893 ===
# 제목: “BGF리테일, 최악의 소비환경 지나도 반등 요인 부족”…목표가↓
# 출력된 종목: ['DB증권', 'BGF리테일']
#
# === 뉴스 8894 ===
# 제목: 한솔홀딩스, 한솔피엔에스 지분 15.86% 공개매수 추진
# 출력된 종목: ['한솔제지', 'NH투자증권', '한솔홀딩스']
#
# === 뉴스 8895 ===
# 제목: '더라운지' 운영 이브릿지…7년새 기업가치 4배
# 출력된 종목: []
#
# === 뉴스 8896 ===
# 제목: 케이스톤 인수한 이브릿지, 공항 필수어플 ‘더라운지’로 기업가치 ‘쑥쑥’ [PEF 포트폴리오 돋보기]
# 출력된 종목: []
#
# === 뉴스 8897 ===
# 제목: 편의점 너마저 ··· 실적 쇼크로 주가 급락
# 출력된 종목: ['DB증권', '상상인증권', 'BGF리테일', 'GS리테일']
#
# === 뉴스 8898 ===
# 제목: “여기는 무조건 성공”...7조 몰리며 청약 흥행한 달바글로벌, 승무원 미스트 뭐길래
# 출력된 종목: []
#
# === 뉴스 8899 ===
# 제목: 현대백화점, 깜짝 실적에 10%대 급등
# 출력된 종목: ['대신증권', '현대백화점', '현대그린푸드', '지누스']
#
# === 뉴스 8900 ===
# 제목: “SKT 위기, 우리에겐 기회”…‘해킹 사태’에 주가희비 엇갈린 통신株
# 출력된 종목: ['미래에셋증권', '신영증권', 'KT', 'LG유플러스', 'SK텔레콤', '현대차증권']
#
# === 뉴스 8901 ===
# 제목: 최태원 사촌형 최신원, SK(주) 주식 모두 팔았다
# 출력된 종목: ['SK디스커버리', 'SK네트웍스', 'SK']
#
# === 뉴스 8902 ===
# 제목: ‘ADC 플랫폼’ 인투셀, 공모가 희망범위 상단 1.7만원 확정
# 출력된 종목: ['미래에셋증권']
#
# === 뉴스 8903 ===
# 제목: '승무원 미스트' 달바글로벌 일반 청약에 7조 몰려 흥행
# 출력된 종목: []
#
# === 뉴스 8904 ===
# 제목: 호반, 한진칼 지분 추가매입 조원태일가 1.5%P差 '위협'
# 출력된 종목: ['한진칼', '아시아나항공', '대한항공']
#
# === 뉴스 8905 ===
# 제목: [M&A 매물장터] 연매출 150억원 극저온 배관업체 매물로
# 출력된 종목: []
#
# === 뉴스 8906 ===
# 제목: 현대百 깜짝실적에 주가 10%↑
# 출력된 종목: ['대신증권', '현대백화점', '현대그린푸드', '지누스']
#
# === 뉴스 8907 ===
# 제목: SKT 영업익 14% 늘었지만 … 유심대란 손실은 2분기 반영
# 출력된 종목: ['SK텔레콤', '한국앤컴퍼니']
#
# === 뉴스 8908 ===
# 제목: 최신원, SK 지분 전량 팔았다
# 출력된 종목: ['SK네트웍스', 'SK']
#
# === 뉴스 8909 ===
# 제목: 스맥, 유상증자 금감원 문턱 넘어···현대위아 공작기계사업부 인수 9부 능선 넘었다
# 출력된 종목: ['화천기공', '현대위아']
#
# === 뉴스 8910 ===
# 제목: 로킷헬스케어 첫날 주가 34% 급등마감
# 출력된 종목: []
#
# === 뉴스 8911 ===
# 제목: 로킷헬스케어 상장 첫 날 주가 급등
# 출력된 종목: []
#
# === 뉴스 8912 ===
# 제목: [MK시그널] HD현대, 고부가가치 선박에 대한 글로벌 수요 증가에 주가 상승세···MK시그널 추천 후 상승률 8.73% 기록
# 출력된 종목: ['HD현대']
#
# === 뉴스 8913 ===
# 제목: 국내 유일 대부업 상장사 리드코프, 메이슨캐피탈 경영권 인수···제4인터넷뱅킹 진출 노린다
# 출력된 종목: []
#
# === 뉴스 8914 ===
# 제목: SK증권x메타클럽, 제휴 이벤트 진행
# 출력된 종목: ['SK증권']
#
# === 뉴스 8915 ===
# 제목: 한투운용, 한국투자미국분할매수빌드업목표전환 펀드 출시
# 출력된 종목: []
#
# === 뉴스 8916 ===
# 제목: KB자산운용, ‘RISE 테슬라·팔란티어고정테크100 ETF’ 출시
# 출력된 종목: []
#
# === 뉴스 8917 ===
# 제목: 알에프텍 자회사 한주에이알티 “대구일색 1호점 월 매출 1억 넘기며 외식사업 안착”
# 출력된 종목: []
#
# === 뉴스 8918 ===
# 제목: 에이스바이옴, 정부 ‘2025년도 자원봉사진흥 시행계획’ 세부 추진 과주 우수 사례 공식 수록
# 출력된 종목: []
#
# === 뉴스 8919 ===
# 제목: 로킷헬스케어, 상장 첫 날 70% 이상 급등
# 출력된 종목: []
#
# === 뉴스 8920 ===
# 제목: [MK시그널] 플라야 호텔&리조트 매도신호 포착, 수익률 68% 달성
# 출력된 종목: []
#
# === 뉴스 8921 ===
# 제목: [MK 골든크로스 돌파종목 : 마음AI(377480) & 전진바이오팜(110020)]
# 출력된 종목: []
#
# === 뉴스 8922 ===
# 제목: 삼성운용, KODEX 차이나휴머노이드로봇 ETF 신규 상장
# 출력된 종목: []
#
# === 뉴스 8923 ===
# 제목: 국힘 대선 후보 확정된 김문수, 관련주 급등… 한덕수 테마주는 급락 [특징주]
# 출력된 종목: ['대영포장', '평화홀딩스', '평화산업']
#
# === 뉴스 8924 ===
# 제목: 주가 장중 100만원 넘었다…‘불닭 열풍’ 삼양식품 황제주 등극
# 출력된 종목: ['삼성바이오로직스', '삼양식품']
#
# === 뉴스 8925 ===
# 제목: “셀트리온, 1분기 실적 아쉽지만 2분기부터 기대”…목표가↓
# 출력된 종목: ['유안타증권', '셀트리온']
#
# === 뉴스 8926 ===
# 제목: “롯데쇼핑, 해외사업 좋은 성과로 유통사 주가 흐름 양호”…목표가↑
# 출력된 종목: ['롯데쇼핑']
#
# === 뉴스 8927 ===
# 제목: “형님, 돌아오셨습니까”...한국경제 대들보 반도체·자동차, 관세 우려 줄자 기지개
# 출력된 종목: ['한국항공우주', 'HD현대중공업', '삼성증권', '한화시스템', 'SK하이닉스', '에이피알', '현대차', '한화오션', '한화에어로스페이스', '삼성중공업', 'LIG넥스원', 'HD한국조선해양', '기아']
#
# === 뉴스 8928 ===
# 제목: “반도체주부터 담자”…미중 관세완화에 돌아온 외국인
# 출력된 종목: ['SK하이닉스', '삼성전자', '삼성증권']
#
# === 뉴스 8929 ===
# 제목: [속보] 포스코퓨처엠, 1조1000억원 규모 유상증자 결정
# 출력된 종목: ['포스코퓨처엠']
#
# === 뉴스 8930 ===
# 제목: [단독] 홈플러스 사태 원흉으로 지목받은 MBK…“과도한 투자금 회수로 부실 초래”
# 출력된 종목: []
#
# === 뉴스 8931 ===
# 제목: 전기료 올리니 … 한전, 8년만에 최대 실적
# 출력된 종목: []
#
# === 뉴스 8932 ===
# 제목: 삼성운용, KODEX 미국머니마켓액티브 ETF 신규 상장
# 출력된 종목: []
#
# === 뉴스 8933 ===
# 제목: 관세우려 덜자…반도체 뜨고 방산주 '비실'
# 출력된 종목: ['한국항공우주', 'HD현대중공업', '삼성증권', '한화시스템', 'SK하이닉스', '에이피알', '현대차', '한화에어로스페이스', '삼성중공업', 'LIG넥스원', 'HD한국조선해양', '기아']
#
# === 뉴스 8934 ===
# 제목: 군인공제회, 14일 자회사 엠플러스자산운용 매각 재입찰 나선다
# 출력된 종목: []
#
# === 뉴스 8935 ===
# 제목: ‘컴백 D-6’ 아이들 ‘Girlfriend’ MV 중국 QQ 뮤직 차트 1위…글로벌 인기 증명
# 출력된 종목: []
#
# === 뉴스 8936 ===
# 제목: 한진칼, 호반건설 지분 추가매입 소식에 ‘上’…경영권 분쟁 가능성
# 출력된 종목: ['한진칼', '아시아나항공', '대한항공']
#
# === 뉴스 8937 ===
# 제목: “LG전자, ‘B2B 사업’ 성패 관건”…목표가↓
# 출력된 종목: ['상상인증권', 'LG전자']
#
# === 뉴스 8938 ===
# 제목: “SK텔레콤, 해킹 여파에 신규가입 재개 여부가 관건”…목표가↓
# 출력된 종목: ['SK텔레콤']
#
# === 뉴스 8939 ===
# 제목: “이제는 내부가 더 위험하다”…상식깬 SKT 해킹사태, 보안 패러다임 바뀔때
# 출력된 종목: ['SK텔레콤']
#
# === 뉴스 8940 ===
# 제목: 국내 유일 대형항공사 대한한공 경영권 분쟁 가능성에 ··· 대한항공 모회사 한진칼 상한가 직행 [특징주]
# 출력된 종목: ['고려아연', '대한항공', '아시아나항공', '한진칼']
#
# === 뉴스 8941 ===
# 제목: “지금이라도 들어가야 하나”…이틀 연속 상한가 찍은 한진칼, 추격매수 주의보
# 출력된 종목: ['대한전선', '고려아연', '대한항공', '아시아나항공', '한진칼', '한진']
#
# === 뉴스 8942 ===
# 제목: [단독] ‘사업 조정’ 총력전 나선 롯데...2000억짜리 물류센터도 판다
# 출력된 종목: ['롯데웰푸드', '롯데케미칼', '롯데지주']
#
# === 뉴스 8943 ===
# 제목: 한국금융지주 순이익 34% 껑충
# 출력된 종목: ['메리츠금융지주', '한국금융지주', '삼성증권', '아시아나항공']
#
# === 뉴스 8944 ===
# 제목: '한진칼 백기사' 쟁탈전 … 거래량 10배 폭발
# 출력된 종목: ['고려아연', '대한항공', '아시아나항공', '한진칼', '한진']
#
# === 뉴스 8945 ===
# 제목: [단독] 롯데물산, 경기 이천∙안성 물류센터 매각 추진…2000억 현금 확보 나선다
# 출력된 종목: ['롯데웰푸드', '롯데렌탈', '롯데케미칼', '롯데지주']
#
# === 뉴스 8946 ===
# 제목: 한국투자증권, 1분기 당기순이익 21% 늘어난 4482억원
# 출력된 종목: []
#
# === 뉴스 8947 ===
# 제목: 코스맥스, 올해 1분기 매출·영업이익 상승세 주가 11%대 오름세
# 출력된 종목: ['코스맥스', 'NH투자증권', '미래에셋증권', '삼성증권']
#
# === 뉴스 8948 ===
# 제목: 쿠시먼 “유럽 찾는 관광객 늘자…우량 호텔 투자 많아졌다”
# 출력된 종목: []
#
# === 뉴스 8949 ===
# 제목: ‘푸룬 주스’ 테일러팜스, 코스닥 상장 추진… 대신證 주관
# 출력된 종목: ['대신증권']
#
# === 뉴스 8950 ===
# 제목: 창해개발, 하이퍼엑셀과 AI 데이터센터·캠퍼스 조성 MOU 체결
# 출력된 종목: []
#
# === 뉴스 8951 ===
# 제목: 리드코프에 인수된 메이슨캐피탈, 신기사로 4년만에 기업가치 1.4배 ‘밸류업’
# 출력된 종목: []
#
# === 뉴스 8952 ===
# 제목: 한국투자증권, 뱅키스 고객 대상 개인연금 이벤트
# 출력된 종목: []
#
# === 뉴스 8953 ===
# 제목: 간밤에 불어온 ‘엔비디아 훈풍’ 타고...SK하이닉스 3%대 급등
# 출력된 종목: ['한미반도체', 'SK하이닉스', '삼성전자']
#
# === 뉴스 8954 ===
# 제목: 대신밸류리츠, IPO 전 해외 투자자금 유치 위해 싱가포르 간다
# 출력된 종목: ['대신증권', '삼성증권']
#
# === 뉴스 8955 ===
# 제목: KODEX 200타겟위클리커버드콜 누적 개인순매수 3천억 돌파
# 출력된 종목: []
#
# === 뉴스 8956 ===
# 제목: 한투운용 혼합자산형 ACE ETF 4종, 순자산액 8000억원 돌파
# 출력된 종목: []
#
# === 뉴스 8957 ===
# 제목: 엑스페릭스, 초슬림 지문스캐너 ‘Real Scan SG10’ FBI Apeendix F인증 취득
# 출력된 종목: []
#
# === 뉴스 8958 ===
# 제목: “포스코퓨처엠, 유증 따른 주가 희석 우려”…목표가↓
# 출력된 종목: ['포스코퓨처엠']
#
# === 뉴스 8959 ===
# 제목: “신세계, 면세업 주가 상승세지만 내수 불황은 장기화”…목표가↑
# 출력된 종목: ['DB증권', '신세계']
#
# === 뉴스 8960 ===
# 제목: 삼익제약 IPO 도전장…스팩합병으로 코스닥 노린다
# 출력된 종목: []
#
# === 뉴스 8961 ===
# 제목: ‘AI 인프라’ 아크릴, 코스닥 상장 예비심사 청구
# 출력된 종목: []
#
# === 뉴스 8962 ===
# 제목: GC지놈 “글로벌 유전체 진단 선도 기업으로 도약”
# 출력된 종목: ['삼성증권']
#
# === 뉴스 8963 ===
# 제목: [단독] 유미캐피탈대부, 마스턴캐피탈 인수 무산…우선협상대상자 지위 해지
# 출력된 종목: ['NH투자증권']
#
# === 뉴스 8964 ===
# 제목: 다올투자증권, 1분기 영업익 126억원으로 흑자전환
# 출력된 종목: ['다올투자증권']
#
# === 뉴스 8965 ===
# 제목: 공개매수 절반이 흥행 실패, 왜?
# 출력된 종목: ['케이씨텍', '한솔홀딩스', '케이씨']
#
# === 뉴스 8966 ===
# 제목: 공개매수 10건 중 절반은 목표달성 실패 ··· 목표수량·가격 할증 적정선 제시해야 성공
# 출력된 종목: ['케이씨텍', '한솔홀딩스', '케이씨']
#
# === 뉴스 8967 ===
# 제목: “K뷰티 믿는다”…탄탄한 실적에 잘나가는 화장품 ODM株
# 출력된 종목: ['미래에셋증권', '삼성증권', '한화투자증권', '다올투자증권', 'NH투자증권', '유진투자증권', '코스맥스', '한국콜마']
#
# === 뉴스 8968 ===
# 제목: "고령화로 커지는 검진시장 혈액검사 기술로 선도할것"
# 출력된 종목: ['삼성증권']
#
# === 뉴스 8969 ===
# 제목: '전력망 소재' 티씨머티리얼즈 코스닥 상장
# 출력된 종목: ['HD현대일렉트릭', '효성중공업']
#
# === 뉴스 8970 ===
# 제목: [단독] 교보AIM자산운용, 서울 광화문 우량 오피스 ‘센터포인트 광화문’ 품는다
# 출력된 종목: ['KT']
#
# === 뉴스 8971 ===
# 제목: 교보증권, 1분기 영업이익 671억원…전년비 67% 상승
# 출력된 종목: ['교보증권']
#
# === 뉴스 8972 ===
# 제목: “계절적 성수기에 접어든 롯데관광개발, 연이은 성장세”
# 출력된 종목: ['유진투자증권', '롯데관광개발']
#
# === 뉴스 8973 ===
# 제목: 싸이토젠, 1분기 연결 매출 606% 증가 역대 최대 분기 실적 경신
# 출력된 종목: []
#
# === 뉴스 8974 ===
# 제목: 역대최대 매출에 롯데관광개발 주가 ‘쑥’
# 출력된 종목: ['유진투자증권', '롯데관광개발']
#
# === 뉴스 8975 ===
# 제목: 본주는 하락하는데 급등 이어가는 한진칼 우선주
# 출력된 종목: ['한진칼']
#
# === 뉴스 8976 ===
# 제목: “한국금융지주, 창립 이래 최대 실적 달성”…목표가↑
# 출력된 종목: ['대신증권', '한국금융지주']
#
# === 뉴스 8977 ===
# 제목: “LIG넥스원, 1분기 우수한 수익성 확인했으나 증명 필요”…목표가↑
# 출력된 종목: ['대신증권', 'LIG넥스원']
#
# === 뉴스 8978 ===
# 제목: 엑스페릭스, 에이뉴트 투자 및 고객 맞춤형 AI솔루션 공동 사업 추진 MOU 체결
# 출력된 종목: []
#
# === 뉴스 8979 ===
# 제목: 한국투자신탁운용, ACE 미국S&P500 ETF 순자산액 2조원 돌파
# 출력된 종목: []
#
# === 뉴스 8980 ===
# 제목: “롯데관광개발, 사상 최대 실적에 방문객 수도 유의미하게 증가”
# 출력된 종목: ['롯데관광개발']
#
# === 뉴스 8981 ===
# 제목: 삼성자산운용, KODEX AI반도체 순자산 2000억 돌파
# 출력된 종목: ['한미반도체', 'SK하이닉스', '삼성전자']
#
# === 뉴스 8982 ===
# 제목: “스트레이키즈 투어로 분위기 달라진다”...2Q 최대실적 전망 JYP엔터 7%대 급등
# 출력된 종목: []
#
# === 뉴스 8983 ===
# 제목: ‘차량 보안’ 아우토크립트, 코스닥 상장 본격화
# 출력된 종목: []
#
# === 뉴스 8984 ===
# 제목: “개미 10명중 7명 넘게 투자 폭망하는데”…우르르 몰리는 ‘이 주식’ 어쩌나
# 출력된 종목: []
#
# === 뉴스 8985 ===
# 제목: 한국투자증권, 퇴직연금 디폴트옵션 수익률 ‘트리플 크라운’
# 출력된 종목: []
#
# === 뉴스 8986 ===
# 제목: [유가증권시장 공시] HDC현대산업개발
# 출력된 종목: []
#
# === 뉴스 8987 ===
# 제목: “한국 매운맛에 정신 못차려”…해외 품귀현상 ‘불닭반도체’ 삼양식품을 황제로
# 출력된 종목: ['오뚜기', '농심', '한화투자증권', '키움증권', 'NH투자증권', '삼성바이오로직스', '삼양식품']
#
# === 뉴스 8988 ===
# 제목: 서학개미 보름새 1조 팔았다
# 출력된 종목: []
#
# === 뉴스 8989 ===
# 제목: LS, 한진 백기사로 '反 호반 전선' 강화
# 출력된 종목: ['LS', '대한항공', '한진칼', '대한전선']
#
# === 뉴스 8990 ===
# 제목: ‘우듬지팜 자회사’ 우듬지E&C, 50억 첫 수주…“글로벌 시장 확대 기대”
# 출력된 종목: []
#
# === 뉴스 8991 ===
# 제목: 베인캐피탈, 인천 인스파이어리조트 매각 절차 착수…영국법상 소유권 이전 위한 조치
# 출력된 종목: []
#
# === 뉴스 8992 ===
# 제목: 어피니티, 서브원 9500억 리파이낸싱
# 출력된 종목: []
#
# === 뉴스 8993 ===
# 제목: 美 LNG 개발 소식에 ‘강관주’ 줄급등…넥스틸, 6%대 강세
# 출력된 종목: ['하이스틸', 'SK오션플랜트', '넥스틸', '한국가스공사', '동양철관']
#
# === 뉴스 8994 ===
# 제목: 어피니티, 9500억원 서브원 리파이낸싱 완료
# 출력된 종목: ['SK']
#
# === 뉴스 8995 ===
# 제목: KKR, 서울역 인근 남산소월타워 매각 속도
# 출력된 종목: ['SK텔레콤']
#
# === 뉴스 8996 ===
# 제목: 삼성운용, ‘삼성글로벌CoreAI목표전환형 펀드 제2호’ 출시
# 출력된 종목: ['미래에셋증권', 'NH투자증권', '삼성증권']
#
# === 뉴스 8997 ===
# 제목: “과소평가해서 미안”…‘황제주’ 삼양식품, 깜짝 실적에 20%대 급등
# 출력된 종목: ['한화투자증권', '키움증권', 'NH투자증권', '삼양식품']
#
# === 뉴스 8998 ===
# 제목: ‘아이스크림의 계절’ 코앞인데...빙그레 목표가 하향, 왜?
# 출력된 종목: ['빙그레']
#
# === 뉴스 8999 ===
# 제목: “엔씨소프트, 1분기 영업이익 시장 기대치 하회”…목표가↓
# 출력된 종목: ['엔씨소프트']
#
# === 뉴스 9000 ===
# 제목: “올 1분기 서울 오피스 거래 규모 4.8兆에 달해”
# 출력된 종목: []
#
# === 뉴스 9001 ===
# 제목: “버티면 본전”…이달 테슬라·애플 몰린 서학개미 ‘눈물의 물타기’ 통했나
# 출력된 종목: []
#
# === 뉴스 9002 ===
# 제목: “치킨값은 벌었으면”…‘몸값 8000억’ 달바글로벌 등 4곳 상장 대기
# 출력된 종목: ['유한양행', '에이피알']
#
# === 뉴스 9003 ===
# 제목: 7조원 넘게 몰려들며 대박 흥행…‘승무원 미스트’로 유명한 이 기업의 상장일은
# 출력된 종목: ['대신증권', '고려제강']
#
# === 뉴스 9004 ===
# 제목: '7조 흥행' 달바글로벌 22일 코스피 상장
# 출력된 종목: []
#
# === 뉴스 9005 ===
# 제목: “이 정도면 하늘과 땅 차이”…오답 투성이였던 실적 전망, 주가도 롤러코스터
# 출력된 종목: ['LG에너지솔루션', 'HD한국조선해양', '한전KPS', 'CJ']
